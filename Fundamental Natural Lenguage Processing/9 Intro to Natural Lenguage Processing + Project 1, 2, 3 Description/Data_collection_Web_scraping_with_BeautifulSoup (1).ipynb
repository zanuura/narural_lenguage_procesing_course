# %% [markdown]
# # List API berita Indonesia

# %% [markdown]
# https://github.com/farizdotid/DAFTAR-API-LOKAL-INDONESIA

# %% [markdown]
# https://github.com/Ucok23/detiknews_api

# %% [markdown]
# # Install the library

# %%
# !pip install requests beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %% [markdown]
# # Get data from a single page

# %% [markdown]
# ## Base code

# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://www.detik.com/tag/pendidikan'
base_url = 'https://www.detik.com/search/searchall?query='
query = 'pendidikan'

# Mengirim permintaan GET ke URL
response = requests.get(base_url + query)

# Mengecek status kode respons
if response.status_code == 200:
    # Mengubah respons menjadi objek BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
    berita_elements = soup.select('.content .list-berita article')

    # Mengiterasi setiap elemen berita
    for berita in berita_elements:
        # Mendapatkan judul dan URL berita
        judul = berita.select_one('.box_text .title').text.strip()
        url_berita = berita.select_one('a')['href']
        summary_berita = berita.select_one('p').text.strip()

        print('Judul:', judul)
        print('URL Berita:', url_berita)
        print('Summary Berita:', summary_berita)
        print('---')
else:
    print('Gagal mengambil data. Status kode:', response.status_code)
# Out:
# Judul: Gubes UI: Pendidikan Karakter Harus Sejak Dini, Bukan Calistung
# URL Berita: https://www.detik.com/edu/sekolah/d-6781739/gubes-ui-pendidikan-karakter-harus-sejak-dini-bukan-calistung
# Summary Berita: Guru besar Fakultas Psikologi UI menyebut pendidikan karakter harusnya diutamakan di pendidikan dasar. Bukan menjejali siswa dengan baca, tulis, dan hitung.
# ---
# Judul: Simak! Begini Cara Bikin Perencanaan Keuangan Yang Mudah di Umur 20an (1)
# URL Berita: https://finance.detik.com/perencanaan-keuangan/d-6782025/simak-begini-cara-bikin-perencanaan-keuangan-yang-mudah-di-umur-20an-1
# Summary Berita: Memasuki usia 20an bisa dibilang memasuki decade emas dalam kehidupan kita. Bagaimana cara mengelola keuangan yang bijak?
# ---
# Judul: Mengenal Iklan Baris: Jenis, Untung Rugi, dan Contohnya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6782011/mengenal-iklan-baris-jenis-untung-rugi-dan-contohnya
# Summary Berita: Iklan baris adalah strategi marketing memanfaatkan ruang sempit di media cetak. Metode ini dinilai efektif karena tidak mahal dan bisa dijangkau masyarakat.
# ---
# Judul: Tari Serampang XII: Pencipta, Sejarah dan Gerakannya
# URL Berita: https://www.detik.com/sumut/budaya/d-6781443/tari-serampang-xii-pencipta-sejarah-dan-gerakannya
# Summary Berita: Provinsi Sumut dikenal memiliki beragam budaya yang unik. Salah satunya adalah Tari Serampang XII, yuk ketahui sejarah dan gerakan tari tersebut.
# ---
# Judul: Apa yang Termasuk Kebutuhan Primer? Ini Pengertian dan Jenisnya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6782000/apa-yang-termasuk-kebutuhan-primer-ini-pengertian-dan-jenisnya
# Summary Berita: Kebutuhan primer adalah kebutuhan yang berkaitan dengan kelangsungan hidup manusia. Kebutuhan primer terdiri dari pangan, sandang, papan.
# ---
# Judul: Kondisi Memprihatinkan Jembatan Lalay di Sukabumi
# URL Berita: https://www.detik.com/jabar/berita/d-6781379/kondisi-memprihatinkan-jembatan-lalay-di-sukabumi
# Summary Berita: Kondisi Jembatan Lalay di Desa Sirnajaya, Kabupaten Sukabumi memprihatinkan. Padahal jembatan itu merupakan akses penting bagi warga.
# ---
# Judul: UM Surabaya Beri Beasiswa 2 Pemain Persebaya Kasim Botan dan M Iqbal
# URL Berita: https://www.detik.com/jatim/sepakbola/d-6781903/um-surabaya-beri-beasiswa-2-pemain-persebaya-kasim-botan-dan-m-iqbal
# Summary Berita: Dua pemain Persebaya Kasim Botan dan Muhammad Iqbal dapat beasiswa kuliah di UM Surabaya. Keduanya memilih Pendidikan Agama Islam dan Psikologi.
# ---
# Judul: Wisuda TK Jangan Jadi Beban Orang Tua
# URL Berita: https://www.detik.com/jabar/berita/d-6780664/wisuda-tk-jangan-jadi-beban-orang-tua
# Summary Berita: Pelaksanaan wisuda anak taman kanak-kanak jangan sampai membebani orang tua.
# ---
# Judul: Mengenal Visa: Definisi, Jenis, dan Cara Pembuatannya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6781795/mengenal-visa-definisi-jenis-dan-cara-pembuatannya
# Summary Berita: Visa merupakan salah satu dokumen untuk melakukan perjalanan ke luar negeri. Simak pengertian, jenis, cara membuat visa pada artikel ini.
# ---

# %% [markdown]
# ## Save the data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_single_page(base_url, query):

  # Mengirim permintaan GET ke URL
  response = requests.get(base_url + query)

  # Mengecek status kode respons
  if response.status_code == 200:
      # Mengubah respons menjadi objek BeautifulSoup
      soup = BeautifulSoup(response.text, 'html.parser')

      # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
      berita_elements = soup.select('.content .list-berita article')

      # Mengiterasi setiap elemen berita
      list_judul = []
      list_url = []
      list_summary = []
      for berita in berita_elements:
          # Mendapatkan judul dan URL berita
          judul = berita.select_one('.box_text .title').text.strip()
          url_berita = berita.select_one('a')['href']
          summary_berita = berita.select_one('p').text.strip()

          list_judul.append(judul)
          list_url.append(url_berita)
          list_summary.append(summary_berita)
  else:
      pass

  data = pd.DataFrame({
      'judul':list_judul,
      'url':list_url,
      'summary':list_summary
  })

  return data

# %%
df_single = get_single_page(base_url='https://www.detik.com/search/searchall?query=', query='chatgpt')
display(df_single.info())
display(df_single.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   judul    9 non-null      object
#  1   url      9 non-null      object
#  2   summary  9 non-null      object
# dtypes: object(3)
# memory usage: 344.0+ bytes
# None
#                                                judul  \
# 0  Awas! Aplikasi ChatGPT Palsu Bisa Ambil Alih H...
# 1  Karyawan Amazon Pakai ChatGPT Biar Kerjaan Cep...
# 2         Penampakan Terbaru Jack Ma Tersenyum Lebar
# 3  Era Jack Ma Meredup, Pulang ke China Kembali M...
# 4        Valuasi Microsoft Tembus Rp 38.857 Triliun!
#
#                                                  url  \
# 0  https://inet.detik.com/security/d-6781768/awas...
# 1  https://inet.detik.com/cyberlife/d-6780992/kar...
# 2  https://inet.detik.com/cyberlife/d-6780530/pen...
# 3  https://www.detik.com/jabar/berita/d-6778817/e...
# 4  https://inet.detik.com/business/d-6777961/valu...
#
#                                              summary
# 0  Aplikasi ChatGPT palsu masih banyak beredar di...
# 1  Pekerja Amazon menggunakan ChatGPT untuk mengh...
# 2  Lama tak muncul lagi semenjak kembali ke China...
# 3  Setelah mengkritik sistem keuangan negaranya s...
# 4  Pertumbuhan bisnis AI yang pesat membuat nilai...

# %% [markdown]
# # Get data from multiple pages

# %% [markdown]
# ## Base code

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'https://www.detik.com/search/searchall?'
query = 'pendidikan'
sort_by = 'time'
page_count = 1

for page in range(1, page_count+1):
    url = base_url + '&query=' + query + '&sortby=' + sort_by + '&page=' + str(page)

    # Mengirim permintaan GET ke URL
    response = requests.get(url)
    print('Page:', page)
    # Mengecek status kode respons
    if response.status_code == 200:
        # Mengubah respons menjadi objek BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
        berita_elements = soup.select('.content .list-berita article')

        # Mengiterasi setiap elemen berita
        for berita in berita_elements:
            # Mendapatkan judul dan URL berita
            judul = berita.select_one('.box_text .title').text.strip()
            url_berita = berita.select_one('a')['href']
            category = berita.select_one('span .date .category').text.strip()
            date = berita.select_one('span .date .category').find_next_sibling(string=True)
            summary_berita = berita.select_one('p').text.strip()

            print('Judul:', judul)
            print('URL Berita:', url_berita)
            print('Kategori:', category)
            print('Waktu Berita:', date)
            print('Summary Berita:', summary_berita)
            print('---')
    else:
        print('Gagal mengambil data. Status kode:', response.status_code)
# Out:
# Page: 1
# Judul: Gubes UI: Pendidikan Karakter Harus Sejak Dini, Bukan Calistung
# URL Berita: https://www.detik.com/edu/sekolah/d-6781739/gubes-ui-pendidikan-karakter-harus-sejak-dini-bukan-calistung
# Kategori: detikEdu
# Waktu Berita: Selasa, 20 Jun 2023 06:30 WIB
# Summary Berita: Guru besar Fakultas Psikologi UI menyebut pendidikan karakter harusnya diutamakan di pendidikan dasar. Bukan menjejali siswa dengan baca, tulis, dan hitung.
# ---
# Judul: Simak! Begini Cara Bikin Perencanaan Keuangan Yang Mudah di Umur 20an (1)
# URL Berita: https://finance.detik.com/perencanaan-keuangan/d-6782025/simak-begini-cara-bikin-perencanaan-keuangan-yang-mudah-di-umur-20an-1
# Kategori: detikFinance
# Waktu Berita: Selasa, 20 Jun 2023 06:30 WIB
# Summary Berita: Memasuki usia 20an bisa dibilang memasuki decade emas dalam kehidupan kita. Bagaimana cara mengelola keuangan yang bijak?
# ---
# Judul: Mengenal Iklan Baris: Jenis, Untung Rugi, dan Contohnya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6782011/mengenal-iklan-baris-jenis-untung-rugi-dan-contohnya
# Kategori: detikFinance
# Waktu Berita: Selasa, 20 Jun 2023 06:12 WIB
# Summary Berita: Iklan baris adalah strategi marketing memanfaatkan ruang sempit di media cetak. Metode ini dinilai efektif karena tidak mahal dan bisa dijangkau masyarakat.
# ---
# Judul: Tari Serampang XII: Pencipta, Sejarah dan Gerakannya
# URL Berita: https://www.detik.com/sumut/budaya/d-6781443/tari-serampang-xii-pencipta-sejarah-dan-gerakannya
# Kategori: detikSumut
# Waktu Berita: Selasa, 20 Jun 2023 06:01 WIB
# Summary Berita: Provinsi Sumut dikenal memiliki beragam budaya yang unik. Salah satunya adalah Tari Serampang XII, yuk ketahui sejarah dan gerakan tari tersebut.
# ---
# Judul: Apa yang Termasuk Kebutuhan Primer? Ini Pengertian dan Jenisnya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6782000/apa-yang-termasuk-kebutuhan-primer-ini-pengertian-dan-jenisnya
# Kategori: detikFinance
# Waktu Berita: Selasa, 20 Jun 2023 06:01 WIB
# Summary Berita: Kebutuhan primer adalah kebutuhan yang berkaitan dengan kelangsungan hidup manusia. Kebutuhan primer terdiri dari pangan, sandang, papan.
# ---
# Judul: Kondisi Memprihatinkan Jembatan Lalay di Sukabumi
# URL Berita: https://www.detik.com/jabar/berita/d-6781379/kondisi-memprihatinkan-jembatan-lalay-di-sukabumi
# Kategori: detikJabar
# Waktu Berita: Selasa, 20 Jun 2023 05:30 WIB
# Summary Berita: Kondisi Jembatan Lalay di Desa Sirnajaya, Kabupaten Sukabumi memprihatinkan. Padahal jembatan itu merupakan akses penting bagi warga.
# ---
# Judul: UM Surabaya Beri Beasiswa 2 Pemain Persebaya Kasim Botan dan M Iqbal
# URL Berita: https://www.detik.com/jatim/sepakbola/d-6781903/um-surabaya-beri-beasiswa-2-pemain-persebaya-kasim-botan-dan-m-iqbal
# Kategori: detikJatim
# Waktu Berita: Selasa, 20 Jun 2023 05:01 WIB
# Summary Berita: Dua pemain Persebaya Kasim Botan dan Muhammad Iqbal dapat beasiswa kuliah di UM Surabaya. Keduanya memilih Pendidikan Agama Islam dan Psikologi.
# ---
# Judul: Wisuda TK Jangan Jadi Beban Orang Tua
# URL Berita: https://www.detik.com/jabar/berita/d-6780664/wisuda-tk-jangan-jadi-beban-orang-tua
# Kategori: detikJabar
# Waktu Berita: Selasa, 20 Jun 2023 01:00 WIB
# Summary Berita: Pelaksanaan wisuda anak taman kanak-kanak jangan sampai membebani orang tua.
# ---
# Judul: Mengenal Visa: Definisi, Jenis, dan Cara Pembuatannya
# URL Berita: https://finance.detik.com/berita-ekonomi-bisnis/d-6781795/mengenal-visa-definisi-jenis-dan-cara-pembuatannya
# Kategori: detikFinance
# Waktu Berita: Senin, 19 Jun 2023 22:45 WIB
# Summary Berita: Visa merupakan salah satu dokumen untuk melakukan perjalanan ke luar negeri. Simak pengertian, jenis, cara membuat visa pada artikel ini.
# ---

# %% [markdown]
# ## Save the data

# %%
import requests
from bs4 import BeautifulSoup

def get_multiple_pages(base_url, query, sort_by, page_count):

    list_judul = []
    list_url = []
    list_kategori = []
    list_date = []
    list_summary = []

    for page in range(1, page_count+1):
        url = base_url + '&query=' + query + '&sortby=' + sort_by + '&page=' + str(page)

        # Mengirim permintaan GET ke URL
        response = requests.get(url)
        # Mengecek status kode respons
        if response.status_code == 200:
            # Mengubah respons menjadi objek BeautifulSoup
            soup = BeautifulSoup(response.text, 'html.parser')

            # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
            berita_elements = soup.select('.content .list-berita article')

            # Mengiterasi setiap elemen berita
            for berita in berita_elements:
                # Mendapatkan judul dan URL berita
                judul = berita.select_one('.box_text .title').text.strip()
                url_berita = berita.select_one('a')['href']
                category = berita.select_one('span .date .category').text.strip()
                date = berita.select_one('span .date .category').find_next_sibling(string=True)
                summary_berita = berita.select_one('p').text.strip()

                list_judul.append(judul)
                list_url.append(url_berita)
                list_kategori.append(category)
                list_date.append(date)
                list_summary.append(summary_berita)

        else:
            pass

    data = pd.DataFrame({
        'judul':list_judul,
        'url':list_url,
        'kategori':list_kategori,
        'tanggal':list_date,
        'summary':list_summary,

    })

    return data

# %%
df_multiple = get_multiple_pages(base_url='https://www.detik.com/search/searchall?', query='pendidikan', sort_by='time', page_count=3)
display(df_multiple.info())
display(df_multiple.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   judul     27 non-null     object
#  1   url       27 non-null     object
#  2   kategori  27 non-null     object
#  3   tanggal   27 non-null     object
#  4   summary   27 non-null     object
# dtypes: object(5)
# memory usage: 1.2+ KB
# None
#                                                judul  \
# 0  Gubes UI: Pendidikan Karakter Harus Sejak Dini...
# 1  Simak! Begini Cara Bikin Perencanaan Keuangan ...
# 2  Mengenal Iklan Baris: Jenis, Untung Rugi, dan ...
# 3  Tari Serampang XII: Pencipta, Sejarah dan Gera...
# 4  Apa yang Termasuk Kebutuhan Primer? Ini Penger...
#
#                                                  url      kategori  \
# 0  https://www.detik.com/edu/sekolah/d-6781739/gu...      detikEdu
# 1  https://finance.detik.com/perencanaan-keuangan...  detikFinance
# 2  https://finance.detik.com/berita-ekonomi-bisni...  detikFinance
# 3  https://www.detik.com/sumut/budaya/d-6781443/t...    detikSumut
# 4  https://finance.detik.com/berita-ekonomi-bisni...  detikFinance
#
#                          tanggal  \
# 0  Selasa, 20 Jun 2023 06:30 WIB
# 1  Selasa, 20 Jun 2023 06:30 WIB
# 2  Selasa, 20 Jun 2023 06:12 WIB
# 3  Selasa, 20 Jun 2023 06:01 WIB
# 4  Selasa, 20 Jun 2023 06:01 WIB
#
#                                              summary
# 0  Guru besar Fakultas Psikologi UI menyebut pend...
# 1  Memasuki usia 20an bisa dibilang memasuki deca...
# 2  Iklan baris adalah strategi marketing memanfaa...
# 3  Provinsi Sumut dikenal memiliki beragam budaya...
# 4  Kebutuhan primer adalah kebutuhan yang berkait...

# %% [markdown]
# # Get detail content

# %% [markdown]
# ## Base code

# %%
import requests
from bs4 import BeautifulSoup

base_url = 'https://www.detik.com/search/searchall?'
query = 'pendidikan'
sort_by = 'time'
page_count = 1

for page in range(1, page_count+1):
    url = base_url + '&query=' + query + '&sortby=' + sort_by + '&page=' + str(page)

    # Mengirim permintaan GET ke URL
    response = requests.get(url)
    print('Page:', page)
    # Mengecek status kode respons
    if response.status_code == 200:
        # Mengubah respons menjadi objek BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
        berita_elements = soup.select('.content .list-berita article')

        # Mengiterasi setiap elemen berita
        for berita in berita_elements:
            # Mendapatkan judul dan URL berita
            judul = berita.select_one('.box_text .title').text.strip()
            url_berita = berita.select_one('a')['href']
            category = berita.select_one('span .date .category').text.strip()
            date = berita.select_one('span .date .category').find_next_sibling(string=True)
            summary_berita = berita.select_one('p').text.strip()

            print('Judul:', judul)
            print('URL Berita:', url_berita)
            print('Kategori:', category)
            print('Waktu Berita:', date)
            print('Summary Berita:', summary_berita)

            response_detail = requests.get(url_berita)
            # Mengecek status kode respons halaman detail
            if response_detail.status_code == 200:
                soup_detail = BeautifulSoup(response_detail.text, 'html.parser')

                # Mencari elemen detail
                detail_berita = ' '.join([i.text.strip() for i in soup_detail.select_one('.itp_bodycontent').find_all('p')])
                author = soup_detail.find('meta', attrs={'name': 'dtk:author'})['content']

                print('Detail:', detail_berita)
                print('Penulis:', author)


            else:
                print('Gagal mengambil halaman detail. Status kode:', response.status_code)

            print('---')
    else:
        print('Gagal mengambil data. Status kode:', response.status_code)
# Out:
# Page: 1
# Judul: Gubes UI: Pendidikan Karakter Harus Sejak Dini, Bukan Calistung
# URL Berita: https://www.detik.com/edu/sekolah/d-6781739/gubes-ui-pendidikan-karakter-harus-sejak-dini-bukan-calistung
# Kategori: detikEdu
# Waktu Berita: Selasa, 20 Jun 2023 06:30 WIB
# Summary Berita: Guru besar Fakultas Psikologi UI menyebut pendidikan karakter harusnya diutamakan di pendidikan dasar. Bukan menjejali siswa dengan baca, tulis, dan hitung.
# Detail: Satu aspek yang perlu mendapatkan perhatian dalam kurikulum nasional adalah persoalan pendidikan karakter. Pendidikan karakter harus didahulukan ketimbang kemampuan akademik sebagai pondasi pembangunan bangsa. Guru Besar Psikologi Politik Universitas Indonesia, Hamdi Muluk menyampaikan banyak keluhan yang muncul tentang permasalahan korupsi yang seolah tidak ada habisnya. Menurutnya, akar permasalahan ini terjadi salah satunya adalah akibat dari permasalahan kurikulum pendidikan kita yang lemah menyasar aspek integritas bangsa. "Korupsi itu cerminan dari orang yang tidak berintegritas jadi ini dulu kita perbaiki. Kalau kita membiarkan ini berada di banyak orang akan merembet. Orang terbiasa naik motor lawan arus, buang sampah sembarangan, aturan dimanipulasi yang terjadi dari atas sampai bawah," ujarnya dalam Podcast Bung Karno Series 2023 di Youtube BKN PDI Perjuangan pada Sabtu (17/6/2023), ditulis Selasa (20/6/2023). ADVERTISEMENT SCROLL TO RESUME CONTENT Hamdi menyebut perilaku tersebut kemungkinan sistemik yang membuat negara ini menuai sistem yang tidak berintegritas. "Itu sebabnya korupsi susah banget diberantas. Jadi orang-orangnya nggak berintegritas, institusinya juga tidak berintegritas," ujarnya. Ia menambahkan, "Nah misalnya di sekolah ada tidak jujur contek itu juga bagian dari integritas, beli nilai, ada orang beli ijazah, joki itu kan contoh dari perilaku tidak berintegritas dalam akademik." Dosen yang lahir di Padang
ak, melakukan pembelian barang, hingga mengikuti pameran internasional. Visa ini diberikan kepada orang yang bermaksud untuk menetap di suatu negara dalam jangka waktu terbatas. Visa on arrival atau visa kedatangan berlaku di negara tertentu, di mana jenis visa ini baru dibuat saat tiba di negara tujuan. Pembuatan visa ini biasanya di bandara atau pelabuhan tempat kedatangan detikers. Visa ini berlaku bagi detikers yang melakukan transit di suatu negara, sebelum melanjutkan perjalanan ke negara tujuan. Visa transit diketahui ada yang berjenis biasa dan Airport Transit. Jenis visa ini diperuntukkan bagi orang yang menempuh pendidikan atau studi di luar negeri. Pembuatan visa ini perlu mengantongi surat izin bersekolah dari instansi pendidikan yang detikers tuju. Visa ini ditujukan bagi pebisnis yang akan menetap cukup lama di negara tujuan. Jenis visa bisnis cocok untuk detikers yang hendak membuka usaha di suatu negara dan memerlukan waktu menetap agak lama. Masih mengutip laman indonesia.go.id, detikers yang mau membuat visa untuk pergi ke luar negeri bisa ikuti langkah-langkah berikut: Pertama-tama detikers mendaftarkan diri untuk pengajuan visa di kedubes negara tujuan atau layanan visa center yang disediakan. Bisa melalui website resmi kedubes atau datang langsung ke kantornya. Kemudian cermati seluruh persyaratan yang diminta dalam pengajuan visanya. Biasanya detikers perlu mengisi formulir data diri yang disediakan kedubes negara tersebut. Setelah mendaftarkan di visa center, siapkan dokumen yang dibutuhkan sesuai persyaratan yang diminta. Biasanya sejumlah dokumen yang diperlukan yakni paspor, ktp, formulir permohonan, pasfoto, surat keterangan sponsor, surat keterangan sehat, jadwal perjalanan serta tiket pesawat. Setelah dokumen disiapkan, kemudian detikers akan menyerahkan lampiran dokumen dalam satu berkas pengajuan. Kekurangan dokumen yang diminta memungkinkan pengajuan visa akan ditolak. Untuk itu, perhatikan dan teliti lagi dokumen yang diserahkan. Setelah berkas pengajuan visa diserahkan ke kedubes negara tujuan, selanjutnya data akan dicek dan diverifikasi. Sesi wawancara dip ...
# Penulis: Azkia Nurfajrina
# ---

# %% [markdown]
# ## Save the data

# %%
import requests
from bs4 import BeautifulSoup

def get_multiple_pages(base_url, query, sort_by, page_count, get_detail=True):

    list_judul = []
    list_url = []
    list_kategori = []
    list_date = []
    list_summary = []
    list_detail_berita = []
    list_author = []

    for page in range(1, page_count+1):
        url = base_url + '&query=' + query + '&sortby=' + sort_by + '&page=' + str(page)

        # Mengirim permintaan GET ke URL
        response = requests.get(url)
        # Mengecek status kode respons
        if response.status_code == 200:
            # Mengubah respons menjadi objek BeautifulSoup
            soup = BeautifulSoup(response.text, 'html.parser')

            # Mencari elemen dengan class 'list-berita' yang berada di dalam div dengan class 'content'
            berita_elements = soup.select('.content .list-berita article')

            # Mengiterasi setiap elemen berita
            for berita in berita_elements:
                # Mendapatkan judul dan URL berita
                judul = berita.select_one('.box_text .title').text.strip()
                url_berita = berita.select_one('a')['href']
                category = berita.select_one('span .date .category').text.strip()
                date = berita.select_one('span .date .category').find_next_sibling(string=True)
                summary_berita = berita.select_one('p').text.strip()

                list_judul.append(judul)
                list_url.append(url_berita)
                list_kategori.append(category)
                list_date.append(date)
                list_summary.append(summary_berita)

                if get_detail:
                    response_detail = requests.get(url_berita)
                    # Mengecek status kode respons halaman detail
                    if response_detail.status_code == 200:
                        soup_detail = BeautifulSoup(response_detail.text, 'html.parser')

                        # Mencari elemen detail
                        detail_berita = ' '.join([i.text.strip() for i in soup_detail.select_one('.itp_bodycontent').find_all('p')])
                        author = soup_detail.find('meta', attrs={'name': 'dtk:author'})['content']

                        list_detail_berita.append(detail_berita)
                        list_author.append(author)

        else:
            pass

    data = pd.DataFrame({
        'judul':list_judul,
        'url':list_url,
        'kategori':list_kategori,
        'tanggal':list_date,
        'summary':list_summary,
        'isi_berita':list_detail_berita,
        'penulis':list_author,

    })

    return data

# %%
df_detail = get_multiple_pages(base_url='https://www.detik.com/search/searchall?', query='pendidikan', sort_by='time', page_count=2, get_detail=True)
display(df_detail.info())
display(df_detail.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   judul       18 non-null     object
#  1   url         18 non-null     object
#  2   kategori    18 non-null     object
#  3   tanggal     18 non-null     object
#  4   summary     18 non-null     object
#  5   isi_berita  18 non-null     object
#  6   penulis     18 non-null     object
# dtypes: object(7)
# memory usage: 1.1+ KB
# None
#                                                judul  \
# 0  Gubes UI: Pendidikan Karakter Harus Sejak Dini...
# 1  Simak! Begini Cara Bikin Perencanaan Keuangan ...
# 2  Mengenal Iklan Baris: Jenis, Untung Rugi, dan ...
# 3  Tari Serampang XII: Pencipta, Sejarah dan Gera...
# 4  Apa yang Termasuk Kebutuhan Primer? Ini Penger...
#
#                                                  url      kategori  \
# 0  https://www.detik.com/edu/sekolah/d-6781739/gu...      detikEdu
# 1  https://finance.detik.com/perencanaan-keuangan...  detikFinance
# 2  https://finance.detik.com/berita-ekonomi-bisni...  detikFinance
# 3  https://www.detik.com/sumut/budaya/d-6781443/t...    detikSumut
# 4  https://finance.detik.com/berita-ekonomi-bisni...  detikFinance
#
#                          tanggal  \
# 0  Selasa, 20 Jun 2023 06:30 WIB
# 1  Selasa, 20 Jun 2023 06:30 WIB
# 2  Selasa, 20 Jun 2023 06:12 WIB
# 3  Selasa, 20 Jun 2023 06:01 WIB
# 4  Selasa, 20 Jun 2023 06:01 WIB
#
#                                              summary  \
# 0  Guru besar Fakultas Psikologi UI menyebut pend...
# 1  Memasuki usia 20an bisa dibilang memasuki deca...
# 2  Iklan baris adalah strategi marketing memanfaa...
# 3  Provinsi Sumut dikenal memiliki beragam budaya...
# 4  Kebutuhan primer adalah kebutuhan yang berkait...
#
#                                           isi_berita  \
# 0  Satu aspek yang perlu mendapatkan perhatian da...
# 1  Selamat sudah kepala dua sekarang. Biasanya or...
# 2  Iklan baris adalah iklan singkat yang terdiri ...
# 3  Tari Serampang XII/Dua Belas merupakan salah s...
# 4  Setiap mahkluk hidup pasti mempunyai kebutuhan...
#
#                                             penulis
# 0                             Pasti Liberti Mappapa
# 1  Steven Ransingin - Aidil Akbar Madjid & Partners
# 2                           Salsabila Azzahra Makka
# 3                                     Michael Ogest
# 4                             Nindy Tiara Hanandita
