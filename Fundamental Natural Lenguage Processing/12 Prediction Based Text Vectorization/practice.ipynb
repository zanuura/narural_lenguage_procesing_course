# %%
import pandas as pd
from gensim.models import Word2Vec
import gensim

# %%
data_path = './dataset.json'

# %%
data = pd.read_json(data_path, lines=True)

# %%
data.head()
# Out:
#                                                0      \
# 0  PPP resmi mendukung Ganjar Pranowo sebagai cap...
#
#                                                1      \
# 0  Manajemen keuangan  yang baik bisa dimulai sej...
#
#                                                2      \
# 0  Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
#
#                                                3      \
# 0  Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
#
#                                                4      \
# 0  Seorang pengendara motor di Kota Cimahi, Jawa ...
#
#                                                5      \
# 0  .\n\nLayanan belanja sekarang bayar nanti (pay...
#
#                                                6      \
# 0  Laptop  saat ini jadi perangkat penting yang d...
#
#                                                7      \
# 0  Laptop  saat ini jadi perangkat penting yang d...
#
#                                                8      \
# 0  .\n\nAC Milan  sukses menendang Napoli  dari L...
#
#                                                9      ...  \
# 0  Badan Pusat Statistik (BPS ) menyebut anjlokny...  ...
#
#                                                14375  \
# 0  Kepolisian Resor Mamuju Tengah menangkap dua o...
#
#                                                14376  \
# 0  Barcelona  harus puas berbagi angka saat berha...
#
#                                                14377  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14378  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14379  \
# 0  .\n\nLampung Geh, Lampung Selatan -  Menteri B...
#
#                                                14380  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14381  \
# 0  Santri  mengamati uang pecahan Rp10 ribu saat ...
#
#                                                14382  \
# 0  Singapore Food Agency (SFA) menyetop impor  ba...
#
#                                                14383  \
# 0  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
#                                                14384
# 0  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
# [1 rows x 14385 columns]

# %%
data = data.T

# %%
data.head()
# Out:
#                                                    0
# 0  PPP resmi mendukung Ganjar Pranowo sebagai cap...
# 1  Manajemen keuangan  yang baik bisa dimulai sej...
# 2  Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
# 3  Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
# 4  Seorang pengendara motor di Kota Cimahi, Jawa ...

# %%
data.rename(columns={0: 'content'}, inplace=True)

# %%
data.tail()
# Out:
#                                                  content
# 14380  Polres Jeneponto diserang pada Kamis dini hari...
# 14381  Santri  mengamati uang pecahan Rp10 ribu saat ...
# 14382  Singapore Food Agency (SFA) menyetop impor  ba...
# 14383  Pemerintahan Presiden Amerika Serikat (AS) Joe...
# 14384  Pemerintahan Presiden Amerika Serikat (AS) Joe...

# %%
data = data.drop_duplicates(keep='first', inplace=False)
data = data.dropna(subset=['content'])

# %%
data
# Out:
#                                                  content
# 0      PPP resmi mendukung Ganjar Pranowo sebagai cap...
# 1      Manajemen keuangan  yang baik bisa dimulai sej...
# 2      Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
# 3      Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
# 4      Seorang pengendara motor di Kota Cimahi, Jawa ...
# ...                                                  ...
# 14377  Polres Jeneponto diserang pada Kamis dini hari...
# 14379  .\n\nLampung Geh, Lampung Selatan -  Menteri B...
# 14381  Santri  mengamati uang pecahan Rp10 ribu saat ...
# 14382  Singapore Food Agency (SFA) menyetop impor  ba...
# 14383  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
# [8637 rows x 1 columns]

# %%
clean_data = data['content'].apply(gensim.utils.simple_preprocess)

# %%
clean_data
# Out:
# 0        [ppp, resmi, mendukung, ganjar, pranowo, sebag...
# 1        [manajemen, keuangan, yang, baik, bisa, dimula...
# 2        [wakil, ketua, dewan, pembina, gerindra, sandi...
# 3        [ketua, umum, pkb, muhaimin, iskandar, alias, ...
# 4        [seorang, pengendara, motor, di, kota, cimahi,...
#                                ...
# 14377    [polres, jeneponto, diserang, pada, kamis, din...
# 14379    [lampung, geh, lampung, selatan, menteri, bumn...
# 14381    [santri, mengamati, uang, pecahan, rp, ribu, s...
# 14382    [singapore, food, agency, sfa, menyetop, impor...
# 14383    [pemerintahan, presiden, amerika, serikat, as,...
# Name: content, Length: 8637, dtype: object

# %%
model_cbow = Word2Vec(clean_data, min_count=3, workers=3, window=3, sg=0)

# %%
model_cbow_2 = Word2Vec(clean_data, min_count=5, workers=3, window=2, sg=0)

# %%
model_cbow.build_vocab(clean_data, progress_per=1000)
model_cbow.train(clean_data, total_examples=model_cbow.corpus_count, epochs=model_cbow.epochs)
# Out:
# (12401524, 14119455)

# %%
model_cbow_2.build_vocab(clean_data, progress_per=1000)
model_cbow_2.train(clean_data, total_examples=model_cbow_2.corpus_count, epochs=model_cbow_2.epochs)
# Out:
# (12252089, 14119455)

# %%
model_cbow.save('./model_cbow.model')

# %%
model_cbow.wv.most_similar('korea')
# Out:
# [('rhodesia', 0.6647233963012695),
#  ('sumatra', 0.645170271396637),
#  ('tapanuli', 0.6158599853515625),
#  ('afrika', 0.60919189453125),
#  ('pagai', 0.604844868183136),
#  ('luwu', 0.5842742919921875),
#  ('tanabala', 0.5832043290138245),
#  ('sumatera', 0.5688298344612122),
#  ('kayong', 0.5673729777336121),
#  ('kutub', 0.5423129796981812)]

# %%
model_cbow_2.wv.most_similar('korea')
# Out:
# [('india', 0.6325303912162781),
#  ('nias', 0.6205827593803406),
#  ('kayong', 0.5995004177093506),
#  ('afrika', 0.5920800566673279),
#  ('tapanuli', 0.5726916790008545),
#  ('luwu', 0.5541835427284241),
#  ('kenya', 0.5238177180290222),
#  ('kutub', 0.49888738989830017),
#  ('australia', 0.49833232164382935),
#  ('konawe', 0.4976864457130432)]

# %%
model_cbow.wv.most_similar('jakarta')
# Out:
# [('monas', 0.5610737800598145),
#  ('tangerang', 0.49778810143470764),
#  ('perbelanjaan', 0.47872012853622437),
#  ('kantornya', 0.44421282410621643),
#  ('semarang', 0.4399082064628601),
#  ('tebet', 0.43749871850013733),
#  ('dishub', 0.4292352795600891),
#  ('tokyo', 0.4288857579231262),
#  ('bisalah', 0.42217451333999634),
#  ('kadishub', 0.4221441149711609)]

# %%
model_cbow_2.wv.most_similar('jakarta')
# Out:
# [('diego', 0.5324656367301941),
#  ('disewakan', 0.5311275124549866),
#  ('perbelanjaan', 0.5248711705207825),
#  ('tangerang', 0.5186662077903748),
#  ('jaksel', 0.5029244422912598),
#  ('senayan', 0.4967592656612396),
#  ('membahayakan', 0.49452662467956543),
#  ('monas', 0.4885423481464386),
#  ('depok', 0.475311279296875),
#  ('primata', 0.47105860710144043)]

# %%
model_cbow.wv['jakarta']
# Out:
# array([ 1.5934176 , -0.7230972 ,  0.59790075, -0.27489176,  3.772393  ,
#        -0.98600763, -2.0885274 , -0.27441737,  1.9526474 ,  1.6406533 ,
#        -0.02509456,  0.967946  , -2.3010883 ,  0.8428624 , -0.21181034,
#         0.74502885,  0.02386158,  0.03255545, -0.17580421, -3.6357505 ,
#         1.2905474 ,  1.683196  ,  3.4767208 ,  0.72282344, -1.0500044 ,
#         1.3346002 , -0.5613989 ,  0.6373451 ,  0.1837414 , -0.98064107,
#         0.5980358 , -0.7092839 , -0.14727956,  0.63987243, -1.0732149 ,
#        -4.747161  , -0.87428045,  1.0742902 , -0.03243617, -2.5935047 ,
#         3.0684938 ,  2.7313182 ,  5.433178  , -0.09412731,  1.3055745 ,
#         3.328055  , -2.3206306 ,  0.44749933,  2.7026422 , -1.0838423 ,
#         0.8964334 , -2.1225984 , -1.1600981 , -1.8326385 ,  0.5210317 ,
#        -0.5050481 , -0.51917326,  2.8227768 ,  2.0046442 ,  0.7310879 ,
#        -0.64566857, -1.029276  , -0.23900633,  1.0871392 , -4.5353737 ,
#         1.1647495 , -0.3540819 , -0.9730835 , -0.1338459 ,  0.24169245,
#        -5.0484276 , -0.0283338 ,  1.1482525 ,  1.7981611 ,  0.9742994 ,
#         0.42343372,  0.23369923, -0.29058862, -0.8077719 , -2.3995469 ,
#        -0.45609197,  2.8782766 ,  1.6723843 , -2.1817882 ,  0.12241977,
#         0.01001867,  0.19238365, -1.186194  ,  0.41532275,  0.7338339 ,
#         0.76090187,  0.35851613,  1.0017965 ,  3.3835568 ,  1.5011332 ,
#        -0.32024398,  1.048379  , -0.5844408 ,  4.1433787 ,  0.7726892 ],
#       dtype=float32)

# %%
model_cbow_2.wv['jakarta']
# Out:
# array([-0.67177683, -0.83690387, -0.48377052,  0.343874  ,  0.35652864,
#        -0.97613174, -1.8237355 ,  2.5508673 , -1.546552  , -0.56777817,
#        -0.46882144,  0.8686725 , -0.62536234,  1.0173366 , -0.96839917,
#        -2.0270047 , -1.6795086 ,  2.1375513 ,  1.0872711 ,  0.06741752,
#        -0.41091034, -1.1298836 , -0.6218319 , -2.7337842 ,  0.27333027,
#         0.13916658, -2.6434498 , -0.21479349, -1.1648408 , -0.5085913 ,
#         0.8470891 ,  0.67258126,  0.8092297 , -0.02169686,  0.8211457 ,
#        -0.4675204 ,  2.2698665 ,  1.8821572 ,  0.3379783 ,  2.7062643 ,
#        -1.1895056 , -1.8199658 , -2.0613585 ,  0.34745312, -0.3438666 ,
#        -2.6805398 ,  0.18286611,  0.03649468,  2.3016279 , -0.77282983,
#        -1.9185052 , -3.3205428 ,  0.9075942 , -0.02512659,  3.785935  ,
#        -0.40867165, -0.9200634 , -0.3715818 , -2.1778405 ,  0.6854214 ,
#         2.136453  , -1.330319  ,  0.07838198,  3.399289  , -0.7899842 ,
#         1.6052027 ,  0.6816487 , -1.1478765 , -1.0659765 ,  1.3542318 ,
#        -0.8694613 ,  1.0256957 , -0.2953257 ,  0.16538702, -0.9404234 ,
#         0.9269346 , -1.7012328 , -1.3058125 ,  0.08923284, -1.2921187 ,
#        -1.429803  ,  1.7934012 , -0.8562827 ,  0.22803336, -1.4652764 ,
#        -0.07914008, -0.66124433, -0.5487321 , -0.77852255,  0.65544534,
#        -0.26232922,  0.45981416,  0.4571153 ,  1.3996196 ,  4.16852   ,
#        -0.00550405,  0.34711298, -0.47588986,  0.87573624, -1.8099866 ],
#       dtype=float32)

# %%
model_cbow.wv.most_similar_cosmul(positive=['jakarta', 'model'], negative=['tangerang'])
# Out:
# [('konsep', 0.9085973501205444),
#  ('sertamu', 0.8985694646835327),
#  ('listrik', 0.8874645829200745),
#  ('komputer', 0.8816417455673218),
#  ('versi', 0.8794366121292114),
#  ('konten', 0.8760053515434265),
#  ('chatbot', 0.8749232888221741),
#  ('produk', 0.8726251721382141),
#  ('dihasilkan', 0.8711275458335876),
#  ('pilihan', 0.8655697107315063)]

# %%
model_cbow_2.wv.most_similar_cosmul(positive=['jakarta', 'model'], negative=['tangerang'])
# Out:
# [('hybrid', 0.8673510551452637),
#  ('kredit', 0.8570948839187622),
#  ('versi', 0.8514430522918701),
#  ('musik', 0.850161612033844),
#  ('didapatkan', 0.8333764672279358),
#  ('album', 0.8317115306854248),
#  ('penyebabnya', 0.8295164704322815),
#  ('pembeli', 0.8284817934036255),
#  ('chatgpt', 0.8280935883522034),
#  ('yaris', 0.8267568349838257)]

# %%
model_cbow.wv.key_to_index
# Out:
# {'yang': 0,
#  'di': 1,
#  'dan': 2,
#  'ini': 3,
#  'dengan': 4,
#  'untuk': 5,
#  'dari': 6,
#  'itu': 7,
#  'dalam': 8,
#  'pada': 9,
#  'tidak': 10,
#  'juga': 11,
#  'akan': 12,
#  'ke': 13,
#  'ada': 14,
#  'bisa': 15,
#  'tersebut': 16,
#  'atau': 17,
#  'sudah': 18,
#  'oleh': 19,
#  'saat': 20,
#  'kita': 21,
#  'adalah': 22,
#  'menjadi': 23,
#  'karena': 24,
#  'tahun': 25,
#  'indonesia': 26,
#  'orang': 27,
#  'lebih': 28,
#  'sebagai': 29,
#  'kata': 30,
#  'saya': 31,
#  'mereka': 32,
#  'dapat': 33,
#  'satu': 34,
#  'hari': 35,
#  'dia': 36,
#  'rp': 37,
#  'hal': 38,
#  'kepada': 39,
#  'kamu': 40,
#  'seperti': 41,
#  'telah': 42,
#  'bahwa': 43,
#  'kami': 44,
#  'masih': 45,
#  'hingga': 46,
#  'banyak': 47,
#  'jadi': 48,
#  'ia': 49,
#  'melakukan': 50,
#  'tak': 51,
#  'anak': 52,
#  'masyarakat': 53,
#  'secara': 54,
#  'hanya': 55,
#  'namun': 56,
#  'salah': 57,
#  'harus': 58,
#  'merupakan': 59,
#  'jakarta': 60,
#  'lalu': 61,
#  'bagi': 62,
#  'memiliki': 63,
#  'para': 64,
#  'lain': 65,
#  'dilakukan': 66,
#  'beberapa': 67,
#  'kota': 68,
#  'baik': 69,
#  'baru': 70,
#  'korban': 71,
#  'atas': 72,
#  'negara': 73,
#  'mengatakan': 74,
#  'sama': 75,
#  'belum': 76,
#  'setelah': 77,
#  'rumah': 78,
#  'jika': 79,
#  'terjadi': 80,
#  'jalan': 81,
#  'sangat': 82,
#  'kemudian': 83,
#  'agar': 84,
#  'tempat': 85,
#  'kalau': 86,
#  'apa': 87,
#  'selain': 88,
#  'besar': 89,
#  'saja': 90,
#  'serta': 91,
#  'pun': 92,
#  'terkait': 93,
#  'sampai': 94,
#  'dua': 95,
#  'cara': 96,
#  'sehingga': 97,
#  'bersama': 98,
#  'waktu': 99,
#  'membuat': 100,
#  'melalui': 101,
#  'ya': 102,
#  'memberikan': 103,
#  'lagi': 104,
#  'sementara': 105,
#  'tapi': 106,
#  'selama': 107,
#  'pemerintah': 108,
#  'april': 109,
#  'persen': 110,
#  'dunia': 111,
#  'kasus': 112,
#  'bulan': 113,
#  'terhadap': 114,
#  'semua': 115,
#  'pelaku': 116,
#  'sekitar': 117,
#  'pihak': 118,
#  'lainnya': 119,
#  'mulai': 120,
#  'kembali': 121,
#  'tentang': 122,
#  'ketika': 123,
#  'langsung': 124,
#  'berbagai': 125,
#  'sebelumnya': 126,
#  'sosial': 127,
#  'bukan': 128,
#  'kedua': 129,
#  'terus': 130,
#  'menggunakan': 131,
#  'pertama': 132,
#  'tengah': 133,
#  'informasi': 134,
#  'wib': 135,
#  'menurut': 136,
#  'kali': 137,
#  'tetap': 138,
#  'warga': 139,
#  'kerja': 140,
#  'lebaran': 141,
#  'sendiri': 142,
#  'memang': 143,
#  'keluarga': 144,
#  'ingin': 145,
#  'berikut': 146,
#  'perlu': 147,
#  'seorang': 148,
#  'masuk': 149,
#  'pukul': 150,
#  'kpk': 151,
#  'sedang': 152,
#  'media': 153,
#  'hukum': 154,
#  'uang': 155,
#  'presiden': 156,
#  'juta': 157,
#  'antara': 158,
#  'kabupaten': 159,
#  'maka': 160,
#  'kesehatan': 161,
#  'berada': 162,
#  'tinggi': 163,
#  'hasil': 164,
#  'pt': 165,
#  'diri': 166,
#  'bahkan': 167,
#  'perusahaan': 168,
#  'harga': 169,
#  'jawa': 170,
#  'ketua': 171,
#  'proses': 172,
#  'setiap': 173,
#  'daerah': 174,
#  'sejak': 175,
#  'soal': 176,
#  'yaitu': 177,
#  'termasuk': 178,
#  'program': 179,
#  'sesuai': 180,
#  'tim': 181,
#  'barat': 182,
#  'nomor': 183,
#  'mobil': 184,
#  'cukup': 185,
#  'ujar': 186,
#  'air': 187,
#  'kegiatan': 188,
#  'selatan': 189,
#  'mungkin': 190,
#  'anda': 191,
#  'pendidikan': 192,
#  'sebuah': 193,
#  'jam': 194,
#  'bagian': 195,
#  'kendaraan': 196,
#  'jumat': 197,
#  'kepala': 198,
#  'sebelum': 199,
#  'ganjar': 200,
#  'jokowi': 201,
#  'sejumlah': 202,
#  'seluruh': 203,
#  'ibu': 204,
#  'polisi': 205,
#  'masa': 206,
#  'mendapatkan': 207,
#  'umum': 208,
#  'perempuan': 209,
#  'kamis': 210,
#  'kumparan': 211,
#  'tol': 212,
#  'pernah': 213,
#  'kondisi': 214,
#  'surat': 215,
#  'wilayah': 216,
#  'partai': 217,
#  'yakni': 218,
#  'mana': 219,
#  'tetapi': 220,
#  'fitri': 221,
#  'nama': 222,
#  'adanya': 223,
#  'sempat': 224,
#  'minggu': 225,
#  'luar': 226,
#  'bawah': 227,
#  'jangan': 228,
#  'mudik': 229,
#  'idul': 230,
#  'barang': 231,
#  'paling': 232,
#  'depan': 233,
#  'melihat': 234,
#  'maupun': 235,
#  'malam': 236,
#  'ramadhan': 237,
#  'penting': 238,
#  'punya': 239,
#  'sebesar': 240,
#  'keuangan': 241,
#  'anggota': 242,
#  'nanti': 243,
#  'lampung': 244,
#  'kan': 245,
#  'berdasarkan': 246,
#  'tiga': 247,
#  'dikutip': 248,
#  'tahu': 249,
#  'menjelaskan': 250,
#  'mengalami': 251,
#  'masing': 252,
#  'usai': 253,
#  'selasa': 254,
#  'raya': 255,
#  'senin': 256,
#  'video': 257,
#  'enggak': 258,
#  'terakhir': 259,
#  'meminta': 260,
#  'lokasi': 261,
#  'rabu': 262,
#  'jelas': 263,
#  'pak': 264,
#  'laporan': 265,
#  'aku': 266,
#  'masalah': 267,
#  'begitu': 268,
#  'data': 269,
#  'mencapai': 270,
#  'negeri': 271,
#  'produk': 272,
#  'makanan': 273,
#  'hidup': 274,
#  'tanpa': 275,
#  'menteri': 276,
#  'mudah': 277,
#  'sekarang': 278,
#  'mau': 279,
#  'lama': 280,
#  'motor': 281,
#  'pasal': 282,
#  'area': 283,
#  'selalu': 284,
#  'lanjut': 285,
#  'timur': 286,
#  'benar': 287,
#  'menyebut': 288,
#  'sebab': 289,
#  'sabtu': 290,
#  'per': 291,
#  'akun': 292,
#  'jumlah': 293,
#  'diduga': 294,
#  'desa': 295,
#  'kini': 296,
#  'tiba': 297,
#  'utama': 298,
#  'politik': 299,
#  'mengaku': 300,
#  'masjid': 301,
#  'mengenai': 302,
#  'bagaimana': 303,
#  'resmi': 304,
#  'digunakan': 305,
#  'teman': 306,
#  'kementerian': 307,
#  'pusat': 308,
#  'km': 309,
#  'datang': 310,
#  'semakin': 311,
#  'wisata': 312,
#  'bekerja': 313,
#  'dirinya': 314,
#  'awal': 315,
#  'meski': 316,
#  'membantu': 317,
#  'nilai': 318,
#  'triliun': 319,
#  'kantor': 320,
#  'liga': 321,
#  'nasional': 322,
#  'ekonomi': 323,
#  'sebanyak': 324,
#  'sistem': 325,
#  'buku': 326,
#  'merasa': 327,
#  'berhasil': 328,
#  'jenis': 329,
#  'utara': 330,
#  'miliar': 331,
#  'bank': 332,
#  'demikian': 333,
#  'katanya': 334,
#  'aplikasi': 335,
#  'al': 336,
#  'akhirnya': 337,
#  'manusia': 338,
#  'tanggal': 339,
#  'allah': 340,
#  'lengkap': 341,
#  'direktur': 342,
#  'layanan': 343,
#  'polda': 344,
#  'naik': 345,
#  'keterangan': 346,
#  'petugas': 347,
#  'polri': 348,
#  'undang': 349,
#  'tentu': 350,
#  'apakah': 351,
#  'terlihat': 352,
#  'terdapat': 353,
#  'meningkatkan': 354,
#  'kecamatan': 355,
#  'kejadian': 356,
#  'makan': 357,
#  'berbeda': 358,
#  'laga': 359,
#  'pasar': 360,
#  'maret': 361,
#  'bisnis': 362,
#  'prabowo': 363,
#  'provinsi': 364,
#  'sakit': 365,
#  'ribu': 366,
#  'mampu': 367,
#  'posisi': 368,
#  'akibat': 369,
#  'bidang': 370,
#  'perjalanan': 371,
#  'tiket': 372,
#  'acara': 373,
#  'mei': 374,
#  'semoga': 375,
#  'mencari': 376,
#  'sekolah': 377,
#  'sekali': 378,
#  'sini': 379,
#  'kereta': 380,
#  'as': 381,
#  'api': 382,
#  'menyampaikan': 383,
#  'rasa': 384,
#  'kawasan': 385,
#  'menarik': 386,
#  'khusus': 387,
#  'kurang': 388,
#  'selamat': 389,
#  'dokter': 390,
#  'the': 391,
#  'menerima': 392,
#  'bentuk': 393,
#  'karya': 394,
#  'hubungan': 395,
#  'diberikan': 396,
#  'buka': 397,
#  'bandara': 398,
#  'guru': 399,
#  'jauh': 400,
#  'tersangka': 401,
#  'angka': 402,
#  'sedangkan': 403,
#  'membawa': 404,
#  'hati': 405,
#  'memastikan': 406,
#  'tujuan': 407,
#  'biasanya': 408,
#  'ditemukan': 409,
#  'diketahui': 410,
#  'perubahan': 411,
#  'sering': 412,
#  'digital': 413,
#  'keputusan': 414,
#  'teknologi': 415,
#  'jalur': 416,
#  'arus': 417,
#  'lingkungan': 418,
#  'tanah': 419,
#  'baca': 420,
#  'menit': 421,
#  'segera': 422,
#  'islam': 423,
#  'upaya': 424,
#  'disebut': 425,
#  'kecil': 426,
#  'mendapat': 427,
#  'sisi': 428,
#  'bahan': 429,
#  'akhir': 430,
#  'total': 431,
#  'wakil': 432,
#  'peristiwa': 433,
#  'arah': 434,
#  'langkah': 435,
#  'berharap': 436,
#  'satunya': 437,
#  'ri': 438,
#  'pidana': 439,
#  'cepat': 440,
#  'dulu': 441,
#  'puasa': 442,
#  'pihaknya': 443,
#  'mengungkapkan': 444,
#  'nah': 445,
#  'unit': 446,
#  'daya': 447,
#  'nya': 448,
#  'no': 449,
#  'badan': 450,
#  'mata': 451,
#  'asal': 452,
#  'biasa': 453,
#  'publik': 454,
#  'keluar': 455,
#  'suatu': 456,
#  'tadi': 457,
#  'bali': 458,
#  'kebutuhan': 459,
#  'pasti': 460,
#  'pertemuan': 461,
#  'tua': 462,
#  'belajar': 463,
#  'budaya': 464,
#  'bahasa': 465,
#  'pekerjaan': 466,
#  'mahasiswa': 467,
#  'kelompok': 468,
#  'disampaikan': 469,
#  'adapun': 470,
#  'dpr': 471,
#  'muda': 472,
#  'fasilitas': 473,
#  'inggris': 474,
#  'tni': 475,
#  'memilih': 476,
#  'muhammadiyah': 477,
#  'pemain': 478,
#  'zodiak': 479,
#  'kasih': 480,
#  'hadir': 481,
#  'transaksi': 482,
#  'pria': 483,
#  'ucap': 484,
#  'selanjutnya': 485,
#  'poin': 486,
#  'berjalan': 487,
#  'laki': 488,
#  'lewat': 489,
#  'hak': 490,
#  'momen': 491,
#  'vs': 492,
#  'sumber': 493,
#  'israel': 494,
#  'biaya': 495,
#  'pembangunan': 496,
#  'tindakan': 497,
#  'bandung': 498,
#  'lakukan': 499,
#  'menuju': 500,
#  'film': 501,
#  'agama': 502,
#  'ujarnya': 503,
#  'pantai': 504,
#  'industri': 505,
#  'ternyata': 506,
#  'tugas': 507,
#  'menunjukkan': 508,
#  'meninggal': 509,
#  'listrik': 510,
#  'pemeriksaan': 511,
#  'suku': 512,
#  'internasional': 513,
#  'mendukung': 514,
#  'siapa': 515,
#  'kesempatan': 516,
#  'terutama': 517,
#  'skor': 518,
#  'putih': 519,
#  'of': 520,
#  'alasan': 521,
#  'penumpang': 522,
#  'tingkat': 523,
#  'kapal': 524,
#  'id': 525,
#  'polres': 526,
#  'kebijakan': 527,
#  'ketiga': 528,
#  'kehidupan': 529,
#  'foto': 530,
#  'misalnya': 531,
#  'bukti': 532,
#  'tepat': 533,
#  'digelar': 534,
#  'berat': 535,
#  'panjang': 536,
#  'turut': 537,
#  'menjaga': 538,
#  'dekat': 539,
#  'seseorang': 540,
#  'mengambil': 541,
#  'tulis': 542,
#  'aksi': 543,
#  'sana': 544,
#  'maaf': 545,
#  'boleh': 546,
#  'muncul': 547,
#  'dosen': 548,
#  'lintas': 549,
#  'dugaan': 550,
#  'senilai': 551,
#  'gubernur': 552,
#  'sang': 553,
#  'proyek': 554,
#  'turun': 555,
#  'ungkap': 556,
#  'terlalu': 557,
#  'pimpinan': 558,
#  'mengetahui': 559,
#  'surabaya': 560,
#  'mengikuti': 561,
#  'jabatan': 562,
#  'sebenarnya': 563,
#  'penuh': 564,
#  'lembaga': 565,
#  'pertandingan': 566,
#  'pengguna': 567,
#  'bertemu': 568,
#  'sekaligus': 569,
#  'ruang': 570,
#  'suara': 571,
#  'empat': 572,
#  'bernama': 573,
#  'bantuan': 574,
#  'terima': 575,
#  'bila': 576,
#  'menyatakan': 577,
#  'ikut': 578,
#  'usaha': 579,
#  'bangsa': 580,
#  'pejabat': 581,
#  'tangan': 582,
#  'laut': 583,
#  'apalagi': 584,
#  'apabila': 585,
#  'pajak': 586,
#  'bakal': 587,
#  'keamanan': 588,
#  'tinggal': 589,
#  'kemarin': 590,
#  'dr': 591,
#  'instagram': 592,
#  'sumatera': 593,
#  'selesai': 594,
#  'bapak': 595,
#  'alam': 596,
#  'penyelidikan': 597,
#  'online': 598,
#  'sebagian': 599,
#  'tenaga': 600,
#  'jawaban': 601,
#  'salat': 602,
#  'kelas': 603,
#  'menurutnya': 604,
#  'pilihan': 605,
#  'keduanya': 606,
#  'luka': 607,
#  'stasiun': 608,
#  'pekan': 609,
#  'calon': 610,
#  'menu': 611,
#  'artinya': 612,
#  'memenuhi': 613,
#  'dana': 614,
#  'jasa': 615,
#  'kepolisian': 616,
#  'istri': 617,
#  'balik': 618,
#  'hotel': 619,
#  'umat': 620,
#  'kemenangan': 621,
#  'merah': 622,
#  'saling': 623,
#  'pemilu': 624,
#  'dikenal': 625,
#  'lima': 626,
#  'saksi': 627,
#  'tubuh': 628,
#  'simak': 629,
#  'menemukan': 630,
#  'siap': 631,
#  'anies': 632,
#  'luas': 633,
#  'terbaik': 634,
#  'uu': 635,
#  'buat': 636,
#  'berlangsung': 637,
#  'berupa': 638,
#  'memberi': 639,
#  'selaku': 640,
#  'metro': 641,
#  'peningkatan': 642,
#  'stadion': 643,
#  'pagi': 644,
#  'periode': 645,
#  'contoh': 646,
#  'kuat': 647,
#  'aman': 648,
#  'menjalani': 649,
#  'endar': 650,
#  'sepanjang': 651,
#  'dasar': 652,
#  'koalisi': 653,
#  'milik': 654,
#  'positif': 655,
#  'amerika': 656,
#  'ayat': 657,
#  'berlaku': 658,
#  'ii': 659,
#  'siswa': 660,
#  'tindak': 661,
#  'karier': 662,
#  'doa': 663,
#  'jaya': 664,
#  'perbedaan': 665,
#  'berasal': 666,
#  'viral': 667,
#  'aktivitas': 668,
#  'wartawan': 669,
#  'jepang': 670,
#  'membangun': 671,
#  'warna': 672,
#  'pengunjung': 673,
#  'khususnya': 674,
#  'pasangan': 675,
#  'tertentu': 676,
#  'beliau': 677,
#  'jawab': 678,
#  'pertanyaan': 679,
#  'lapangan': 680,
#  'dinas': 681,
#  'segala': 682,
#  'operasi': 683,
#  'khas': 684,
#  'paket': 685,
#  'bermain': 686,
#  'nyaman': 687,
#  'gedung': 688,
#  'rapat': 689,
#  'gol': 690,
#  'pernyataan': 691,
#  'investasi': 692,
#  'organisasi': 693,
#  'jadwal': 694,
#  'china': 695,
#  'peserta': 696,
#  'pungkasnya': 697,
#  'aturan': 698,
#  'terlebih': 699,
#  'pilih': 700,
#  'menilai': 701,
#  'mempunyai': 702,
#  'melaporkan': 703,
#  'kemungkinan': 704,
#  'padahal': 705,
#  'korupsi': 706,
#  'sejarah': 707,
#  'pdip': 708,
#  'itulah': 709,
#  'membuka': 710,
#  'rencana': 711,
#  'timnas': 712,
#  'alat': 713,
#  'hakim': 714,
#  'meskipun': 715,
#  'lagu': 716,
#  'anaknya': 717,
#  'antaranya': 718,
#  'dukungan': 719,
#  'rata': 720,
#  'wajib': 721,
#  'kampung': 722,
#  'diterima': 723,
#  'wanita': 724,
#  'taman': 725,
#  'pers': 726,
#  'bumi': 727,
#  'rakyat': 728,
#  'pulau': 729,
#  'sedikit': 730,
#  'udara': 731,
#  'kemampuan': 732,
#  'dampak': 733,
#  'menikmati': 734,
#  'pribadi': 735,
#  'meningkat': 736,
#  'david': 737,
#  'pulang': 738,
#  'terletak': 739,
#  'artikel': 740,
#  'bicara': 741,
#  'pembayaran': 742,
#  'iii': 743,
#  'lihat': 744,
#  'muslim': 745,
#  'sulit': 746,
#  'dki': 747,
#  'sepeda': 748,
#  'ahmad': 749,
#  'sidang': 750,
#  'justru': 751,
#  'menyebabkan': 752,
#  'mantan': 753,
#  'terlibat': 754,
#  'agung': 755,
#  'minyak': 756,
#  'peraturan': 757,
#  'titik': 758,
#  'penjara': 759,
#  'kinerja': 760,
#  'pekerja': 761,
#  'rest': 762,
#  'pengalaman': 763,
#  'rusia': 764,
#  'gempa': 765,
#  'city': 766,
#  'asn': 767,
#  'musim': 768,
#  'isu': 769,
#  'menegaskan': 770,
#  'berita': 771,
#  'tentunya': 772,
#  'melawan': 773,
#  'piala': 774,
#  'bola': 775,
#  'kartu': 776,
#  'senjata': 777,
#  'tutur': 778,
#  'pengadilan': 779,
#  'perkara': 780,
#  'ppp': 781,
#  'matahari': 782,
#  'kabar': 783,
#  'puncak': 784,
#  'peran': 785,
#  'rekomendasi': 786,
#  'tampak': 787,
#  'jelasnya': 788,
#  'jl': 789,
#  'beragam': 790,
#  'bangunan': 791,
#  'jenderal': 792,
#  'melaksanakan': 793,
#  'demi': 794,
#  'pula': 795,
#  'usd': 796,
#  'hampir': 797,
#  'pintu': 798,
#  'pelayanan': 799,
#  'pegawai': 800,
#  'covid': 801,
#  'mengutip': 802,
#  'belakang': 803,
#  'mendatang': 804,
#  'menang': 805,
#  'kamar': 806,
#  'terbuka': 807,
#  'lantas': 808,
#  'bumn': 809,
#  'menghadapi': 810,
#  'capres': 811,
#  'penggunaan': 812,
#  'coba': 813,
#  'berusia': 814,
#  'merdeka': 815,
#  'membeli': 816,
#  'muhammad': 817,
#  'pemilik': 818,
#  'sungai': 819,
#  'setempat': 820,
#  'dokumen': 821,
#  'gunung': 822,
#  'kalian': 823,
#  'dibandingkan': 824,
#  'cuma': 825,
#  'daftar': 826,
#  'fokus': 827,
#  'pesawat': 828,
#  'sehat': 829,
#  'komisi': 830,
#  'ikan': 831,
#  'usia': 832,
#  'kenaikan': 833,
#  'minta': 834,
#  'hukuman': 835,
#  'terbaru': 836,
#  'pemudik': 837,
#  'gerindra': 838,
#  'syarat': 839,
#  'terdiri': 840,
#  'menambahkan': 841,
#  'saham': 842,
#  'akbp': 843,
#  'ibadah': 844,
#  'indah': 845,
#  'pelabuhan': 846,
#  'budi': 847,
#  'tokoh': 848,
#  'serangan': 849,
#  'ditangkap': 850,
#  'minuman': 851,
#  'potensi': 852,
#  'bus': 853,
#  'menyediakan': 854,
#  'produksi': 855,
#  'arab': 856,
#  'perkembangan': 857,
#  'model': 858,
#  'faktor': 859,
#  'universitas': 860,
#  'buruh': 861,
#  'dianggap': 862,
#  'keras': 863,
#  'berangkat': 864,
#  'akses': 865,
#  'nantinya': 866,
#  'menggelar': 867,
#  'kualitas': 868,
#  'ayam': 869,
#  'dini': 870,
#  'ali': 871,
#  'serikat': 872,
#  'asia': 873,
#  'kaki': 874,
#  'united': 875,
#  'kecelakaan': 876,
#  'bagus': 877,
#  'dibawa': 878,
#  'lapas': 879,
#  'situasi': 880,
#  'halaman': 881,
#  'pemuda': 882,
#  'yogyakarta': 883,
#  'komunikasi': 884,
#  'berusaha': 885,
#  'ma': 886,
#  'izin': 887,
#  'kombes': 888,
#  'mencoba': 889,
#  'perdagangan': 890,
#  'lahir': 891,
#  'pontianak': 892,
#  'libur': 893,
#  'raja': 894,
#  'alias': 895,
#  'penyakit': 896,
#  'konflik': 897,
#  'tarif': 898,
#  'tewas': 899,
#  'berarti': 900,
#  'tantangan': 901,
#  'supaya': 902,
#  'sebagaimana': 903,
#  'ilmu': 904,
#  'penjelasan': 905,
#  'pemimpin': 906,
#  'cocok': 907,
#  'kredit': 908,
#  'tersedia': 909,
#  'ahli': 910,
#  'and': 911,
#  'terbesar': 912,
#  'aktif': 913,
#  'februari': 914,
#  'penganiayaan': 915,
#  'pelanggaran': 916,
#  'sudan': 917,
#  'kuartal': 918,
#  'dibuat': 919,
#  'up': 920,
#  'putra': 921,
#  'dahulu': 922,
#  'situs': 923,
#  'pendapatan': 924,
#  'mati': 925,
#  'restoran': 926,
#  'sektor': 927,
#  'mahfud': 928,
#  'nggak': 929,
#  'bebas': 930,
#  'asmara': 931,
#  'konsumen': 932,
#  'permintaan': 933,
#  'batu': 934,
#  'pranowo': 935,
#  'ancaman': 936,
#  'kenapa': 937,
#  'sulawesi': 938,
#  'papua': 939,
#  'mendorong': 940,
#  'mengurangi': 941,
#  'sambil': 942,
#  'perhatian': 943,
#  'dewan': 944,
#  'pemerintahan': 945,
#  'sosok': 946,
#  'sehari': 947,
#  'status': 948,
#  'saudi': 949,
#  'jemaah': 950,
#  'ucapan': 951,
#  'diharapkan': 952,
#  'zakat': 953,
#  'melanjutkan': 954,
#  'tanda': 955,
#  'one': 956,
#  'lokal': 957,
#  'membutuhkan': 958,
#  'penyebab': 959,
#  'penjualan': 960,
#  'wni': 961,
#  'manajemen': 962,
#  'grup': 963,
#  'hitam': 964,
#  'ketum': 965,
#  'laman': 966,
#  'maksimal': 967,
#  'sambungnya': 968,
#  'ramai': 969,
#  'bupati': 970,
#  'olahraga': 971,
#  'bersih': 972,
#  'si': 973,
#  'ramalan': 974,
#  'generasi': 975,
#  'pesan': 976,
#  'maju': 977,
#  'korea': 978,
#  'beredar': 979,
#  'com': 980,
#  'meraih': 981,
#  'sikap': 982,
#  'pakaian': 983,
#  'klik': 984,
#  'fifa': 985,
#  'target': 986,
#  'ungkapnya': 987,
#  'pengembangan': 988,
#  'bogor': 989,
#  'sri': 990,
#  'melibatkan': 991,
#  'tambahan': 992,
#  'semangat': 993,
#  'memahami': 994,
#  'menambah': 995,
#  'saudara': 996,
#  'membahas': 997,
#  'cerita': 998,
#  'to': 999,
#  ...}

# %% [markdown]
# # Skip Gram

# %%
model_skipgram = Word2Vec(clean_data, min_count=3, workers=3, window=3, sg=1)

# %%
model_skipgram_2 = Word2Vec(clean_data, min_count=5, workers = 3, window = 2, sg=1)

# %%
model_skipgram.build_vocab(clean_data, progress_per=1000)
model_skipgram.train(clean_data, total_examples=model_skipgram.corpus_count, epochs=model_skipgram.epochs)
# Out:
# (12403379, 14119455)

# %%
# model_skipgram_2.build_vocab(clean_data, progress_per=1000)
# model_skipgram_2.train(clean_data, tatal_examples=model_skipgram_2.corpus_count, epochs=model_skipgram_2.epochs)
model_skipgram_2.build_vocab(clean_data, progress_per=1000)
model_skipgram_2.train(clean_data, total_examples=model_skipgram_2.corpus_count, epochs=model_skipgram_2.epochs)
# Out:
# (12252141, 14119455)

# %%
model_skipgram.save('./model_skipgram.model')

# %%
model_skipgram.wv.most_similar('sandiaga')
# Out:
# [('uno', 0.7874215841293335),
#  ('menparekraf', 0.7710379958152771),
#  ('salahuddin', 0.7339052557945251),
#  ('gerindra', 0.7237692475318909),
#  ('dibicarakan', 0.7105414867401123),
#  ('ibtidaiyah', 0.6697611808776855),
#  ('sandi', 0.6459879279136658),
#  ('desmond', 0.6446249485015869),
#  ('subianto', 0.6423851251602173),
#  ('ppp', 0.6405712962150574)]

# %%
model_skipgram_2.wv.most_similar('sandiaga')
# Out:
# [('iskandar', 0.7087830901145935),
#  ('salahuddin', 0.6880061030387878),
#  ('uno', 0.6753785014152527),
#  ('ahy', 0.6655243039131165),
#  ('puan', 0.6649277806282043),
#  ('menparekraf', 0.6544554233551025),
#  ('prananda', 0.6483010649681091),
#  ('gerindra', 0.6465962529182434),
#  ('sandi', 0.6400135159492493),
#  ('subianto', 0.6296094655990601)]

# %%
model_skipgram.wv['sandiaga']
# Out:
# array([-4.8979551e-01,  6.7618233e-01,  2.2028494e-01,  3.0194232e-01,
#         1.2998667e-01, -3.3620456e-01,  1.1797622e+00,  3.3302075e-01,
#        -1.8316342e-02, -5.0227886e-01, -5.7660741e-01, -2.0804405e-01,
#        -8.4623814e-02,  1.7451383e-01,  3.0244118e-01,  7.5617582e-01,
#         9.3051650e-02, -4.7047415e-01, -1.5430336e-01, -8.5505497e-01,
#         4.6519244e-01,  8.7815237e-01, -4.3071106e-01, -3.2884529e-01,
#        -2.4623835e-01, -7.8666881e-02, -2.5697213e-01, -3.7878183e-01,
#        -6.0644668e-01,  4.7885403e-02, -5.1972512e-03, -1.6530284e-01,
#        -2.4834475e-01, -1.2877466e-01,  2.3261954e-01,  8.8368970e-01,
#         3.9260966e-01,  6.6398078e-04, -4.9849680e-01, -2.2145209e-01,
#         2.5742117e-01, -2.1254370e-01, -1.3740443e+00,  2.8513346e-02,
#         2.5076711e-01,  4.8569641e-01, -6.9388545e-01, -6.6901141e-01,
#         7.3269045e-01,  7.0261371e-01,  3.4098986e-01, -1.2132590e-01,
#        -1.4211996e-01,  1.6186447e-01, -5.2699322e-01, -7.0421183e-01,
#        -3.0563557e-01, -5.2874535e-01, -4.6769172e-01, -4.7758698e-02,
#        -1.0568827e+00,  7.0622140e-01,  4.5206580e-02, -7.4585015e-01,
#         1.1406156e-01, -3.2180506e-01,  4.7981256e-01,  1.0263374e+00,
#        -6.3284820e-01,  1.6402262e-01,  6.2372553e-01, -8.5922480e-03,
#        -3.4026557e-01,  1.9567943e-01, -3.2977885e-01, -1.0919579e+00,
#        -1.6135041e-01,  8.0837142e-01, -2.5846422e-01,  4.7575632e-01,
#         7.4998957e-01, -2.0691843e-01, -9.4443011e-01,  4.8642194e-01,
#        -7.0687866e-01, -1.8477965e-02,  5.3147185e-01,  4.0263554e-01,
#         1.0022118e+00, -5.1052034e-01,  4.6847567e-01,  5.9560436e-01,
#         2.9993114e-01, -5.9165433e-02,  4.2618170e-01,  3.7631458e-01,
#        -3.2399285e-01, -1.0239778e-01,  1.4979571e-01, -4.9405706e-01],
#       dtype=float32)

# %%
model_skipgram.wv.most_similar_cosmul(positive=['jakarta', 'mobil'], negative=['korea'])
# Out:
# [('kendaraan', 0.985729455947876),
#  ('melintas', 0.9445900917053223),
#  ('transjakarta', 0.933272123336792),
#  ('roda', 0.9261981844902039),
#  ('kusworo', 0.9175586104393005),
#  ('bus', 0.9114211797714233),
#  ('rush', 0.909092366695404),
#  ('fortuner', 0.9089208841323853),
#  ('lrt', 0.9055078029632568),
#  ('sedan', 0.9029648303985596)]

# %%
model_skipgram_2.wv.most_similar_cosmul(positive=['jakarta', 'mobil'], negative=['korea'])
# Out:
# [('kendaraan', 1.015320897102356),
#  ('motor', 0.9444963335990906),
#  ('mobilnya', 0.9181241393089294),
#  ('roda', 0.9160534739494324),
#  ('transjakarta', 0.9132155776023865),
#  ('bus', 0.910306453704834),
#  ('urip', 0.9081659317016602),
#  ('bermotor', 0.8999786972999573),
#  ('monginsidi', 0.895146369934082),
#  ('pajero', 0.888299286365509)]

# %%
model_skipgram.wv.key_to_index
# Out:
# {'yang': 0,
#  'di': 1,
#  'dan': 2,
#  'ini': 3,
#  'dengan': 4,
#  'untuk': 5,
#  'dari': 6,
#  'itu': 7,
#  'dalam': 8,
#  'pada': 9,
#  'tidak': 10,
#  'juga': 11,
#  'akan': 12,
#  'ke': 13,
#  'ada': 14,
#  'bisa': 15,
#  'tersebut': 16,
#  'atau': 17,
#  'sudah': 18,
#  'oleh': 19,
#  'saat': 20,
#  'kita': 21,
#  'adalah': 22,
#  'menjadi': 23,
#  'karena': 24,
#  'tahun': 25,
#  'indonesia': 26,
#  'orang': 27,
#  'lebih': 28,
#  'sebagai': 29,
#  'kata': 30,
#  'saya': 31,
#  'mereka': 32,
#  'dapat': 33,
#  'satu': 34,
#  'hari': 35,
#  'dia': 36,
#  'rp': 37,
#  'hal': 38,
#  'kepada': 39,
#  'kamu': 40,
#  'seperti': 41,
#  'telah': 42,
#  'bahwa': 43,
#  'kami': 44,
#  'masih': 45,
#  'hingga': 46,
#  'banyak': 47,
#  'jadi': 48,
#  'ia': 49,
#  'melakukan': 50,
#  'tak': 51,
#  'anak': 52,
#  'masyarakat': 53,
#  'secara': 54,
#  'hanya': 55,
#  'namun': 56,
#  'salah': 57,
#  'harus': 58,
#  'merupakan': 59,
#  'jakarta': 60,
#  'lalu': 61,
#  'bagi': 62,
#  'memiliki': 63,
#  'para': 64,
#  'lain': 65,
#  'dilakukan': 66,
#  'beberapa': 67,
#  'kota': 68,
#  'baik': 69,
#  'baru': 70,
#  'korban': 71,
#  'atas': 72,
#  'negara': 73,
#  'mengatakan': 74,
#  'sama': 75,
#  'belum': 76,
#  'setelah': 77,
#  'rumah': 78,
#  'jika': 79,
#  'terjadi': 80,
#  'jalan': 81,
#  'sangat': 82,
#  'kemudian': 83,
#  'agar': 84,
#  'tempat': 85,
#  'kalau': 86,
#  'apa': 87,
#  'selain': 88,
#  'besar': 89,
#  'saja': 90,
#  'serta': 91,
#  'pun': 92,
#  'terkait': 93,
#  'sampai': 94,
#  'dua': 95,
#  'cara': 96,
#  'sehingga': 97,
#  'bersama': 98,
#  'waktu': 99,
#  'membuat': 100,
#  'melalui': 101,
#  'ya': 102,
#  'memberikan': 103,
#  'lagi': 104,
#  'sementara': 105,
#  'tapi': 106,
#  'selama': 107,
#  'pemerintah': 108,
#  'april': 109,
#  'persen': 110,
#  'dunia': 111,
#  'kasus': 112,
#  'bulan': 113,
#  'terhadap': 114,
#  'semua': 115,
#  'pelaku': 116,
#  'sekitar': 117,
#  'pihak': 118,
#  'lainnya': 119,
#  'mulai': 120,
#  'kembali': 121,
#  'tentang': 122,
#  'ketika': 123,
#  'langsung': 124,
#  'berbagai': 125,
#  'sebelumnya': 126,
#  'sosial': 127,
#  'bukan': 128,
#  'kedua': 129,
#  'terus': 130,
#  'menggunakan': 131,
#  'pertama': 132,
#  'tengah': 133,
#  'informasi': 134,
#  'wib': 135,
#  'menurut': 136,
#  'kali': 137,
#  'tetap': 138,
#  'warga': 139,
#  'kerja': 140,
#  'lebaran': 141,
#  'sendiri': 142,
#  'memang': 143,
#  'keluarga': 144,
#  'ingin': 145,
#  'berikut': 146,
#  'perlu': 147,
#  'seorang': 148,
#  'masuk': 149,
#  'pukul': 150,
#  'kpk': 151,
#  'sedang': 152,
#  'media': 153,
#  'hukum': 154,
#  'uang': 155,
#  'presiden': 156,
#  'juta': 157,
#  'antara': 158,
#  'kabupaten': 159,
#  'maka': 160,
#  'kesehatan': 161,
#  'berada': 162,
#  'tinggi': 163,
#  'hasil': 164,
#  'pt': 165,
#  'diri': 166,
#  'bahkan': 167,
#  'perusahaan': 168,
#  'harga': 169,
#  'jawa': 170,
#  'ketua': 171,
#  'proses': 172,
#  'setiap': 173,
#  'daerah': 174,
#  'sejak': 175,
#  'soal': 176,
#  'yaitu': 177,
#  'termasuk': 178,
#  'program': 179,
#  'sesuai': 180,
#  'tim': 181,
#  'barat': 182,
#  'nomor': 183,
#  'mobil': 184,
#  'cukup': 185,
#  'ujar': 186,
#  'air': 187,
#  'kegiatan': 188,
#  'selatan': 189,
#  'mungkin': 190,
#  'anda': 191,
#  'pendidikan': 192,
#  'sebuah': 193,
#  'jam': 194,
#  'bagian': 195,
#  'kendaraan': 196,
#  'jumat': 197,
#  'kepala': 198,
#  'sebelum': 199,
#  'ganjar': 200,
#  'jokowi': 201,
#  'sejumlah': 202,
#  'seluruh': 203,
#  'ibu': 204,
#  'polisi': 205,
#  'masa': 206,
#  'mendapatkan': 207,
#  'umum': 208,
#  'perempuan': 209,
#  'kamis': 210,
#  'kumparan': 211,
#  'tol': 212,
#  'pernah': 213,
#  'kondisi': 214,
#  'surat': 215,
#  'wilayah': 216,
#  'partai': 217,
#  'yakni': 218,
#  'mana': 219,
#  'tetapi': 220,
#  'fitri': 221,
#  'nama': 222,
#  'adanya': 223,
#  'sempat': 224,
#  'minggu': 225,
#  'luar': 226,
#  'bawah': 227,
#  'jangan': 228,
#  'mudik': 229,
#  'idul': 230,
#  'barang': 231,
#  'paling': 232,
#  'depan': 233,
#  'melihat': 234,
#  'maupun': 235,
#  'malam': 236,
#  'ramadhan': 237,
#  'penting': 238,
#  'punya': 239,
#  'sebesar': 240,
#  'keuangan': 241,
#  'anggota': 242,
#  'nanti': 243,
#  'lampung': 244,
#  'kan': 245,
#  'berdasarkan': 246,
#  'tiga': 247,
#  'dikutip': 248,
#  'tahu': 249,
#  'menjelaskan': 250,
#  'mengalami': 251,
#  'masing': 252,
#  'usai': 253,
#  'selasa': 254,
#  'raya': 255,
#  'senin': 256,
#  'video': 257,
#  'enggak': 258,
#  'terakhir': 259,
#  'meminta': 260,
#  'lokasi': 261,
#  'rabu': 262,
#  'jelas': 263,
#  'pak': 264,
#  'laporan': 265,
#  'aku': 266,
#  'masalah': 267,
#  'begitu': 268,
#  'data': 269,
#  'mencapai': 270,
#  'negeri': 271,
#  'produk': 272,
#  'makanan': 273,
#  'hidup': 274,
#  'tanpa': 275,
#  'menteri': 276,
#  'mudah': 277,
#  'sekarang': 278,
#  'mau': 279,
#  'lama': 280,
#  'motor': 281,
#  'pasal': 282,
#  'area': 283,
#  'selalu': 284,
#  'lanjut': 285,
#  'timur': 286,
#  'benar': 287,
#  'menyebut': 288,
#  'sebab': 289,
#  'sabtu': 290,
#  'per': 291,
#  'akun': 292,
#  'jumlah': 293,
#  'diduga': 294,
#  'desa': 295,
#  'kini': 296,
#  'tiba': 297,
#  'utama': 298,
#  'politik': 299,
#  'mengaku': 300,
#  'masjid': 301,
#  'mengenai': 302,
#  'bagaimana': 303,
#  'resmi': 304,
#  'digunakan': 305,
#  'teman': 306,
#  'kementerian': 307,
#  'pusat': 308,
#  'km': 309,
#  'datang': 310,
#  'semakin': 311,
#  'wisata': 312,
#  'bekerja': 313,
#  'dirinya': 314,
#  'awal': 315,
#  'meski': 316,
#  'membantu': 317,
#  'nilai': 318,
#  'triliun': 319,
#  'kantor': 320,
#  'liga': 321,
#  'nasional': 322,
#  'ekonomi': 323,
#  'sebanyak': 324,
#  'sistem': 325,
#  'buku': 326,
#  'merasa': 327,
#  'berhasil': 328,
#  'jenis': 329,
#  'utara': 330,
#  'miliar': 331,
#  'bank': 332,
#  'demikian': 333,
#  'katanya': 334,
#  'aplikasi': 335,
#  'al': 336,
#  'akhirnya': 337,
#  'manusia': 338,
#  'tanggal': 339,
#  'allah': 340,
#  'lengkap': 341,
#  'direktur': 342,
#  'layanan': 343,
#  'polda': 344,
#  'naik': 345,
#  'keterangan': 346,
#  'petugas': 347,
#  'polri': 348,
#  'undang': 349,
#  'tentu': 350,
#  'apakah': 351,
#  'terlihat': 352,
#  'terdapat': 353,
#  'meningkatkan': 354,
#  'kecamatan': 355,
#  'kejadian': 356,
#  'makan': 357,
#  'berbeda': 358,
#  'laga': 359,
#  'pasar': 360,
#  'maret': 361,
#  'bisnis': 362,
#  'prabowo': 363,
#  'provinsi': 364,
#  'sakit': 365,
#  'ribu': 366,
#  'mampu': 367,
#  'posisi': 368,
#  'akibat': 369,
#  'bidang': 370,
#  'perjalanan': 371,
#  'tiket': 372,
#  'acara': 373,
#  'mei': 374,
#  'semoga': 375,
#  'mencari': 376,
#  'sekolah': 377,
#  'sekali': 378,
#  'sini': 379,
#  'kereta': 380,
#  'as': 381,
#  'api': 382,
#  'menyampaikan': 383,
#  'rasa': 384,
#  'kawasan': 385,
#  'menarik': 386,
#  'khusus': 387,
#  'kurang': 388,
#  'selamat': 389,
#  'dokter': 390,
#  'the': 391,
#  'menerima': 392,
#  'bentuk': 393,
#  'karya': 394,
#  'hubungan': 395,
#  'diberikan': 396,
#  'buka': 397,
#  'bandara': 398,
#  'guru': 399,
#  'jauh': 400,
#  'tersangka': 401,
#  'angka': 402,
#  'sedangkan': 403,
#  'membawa': 404,
#  'hati': 405,
#  'memastikan': 406,
#  'tujuan': 407,
#  'biasanya': 408,
#  'ditemukan': 409,
#  'diketahui': 410,
#  'perubahan': 411,
#  'sering': 412,
#  'digital': 413,
#  'keputusan': 414,
#  'teknologi': 415,
#  'jalur': 416,
#  'arus': 417,
#  'lingkungan': 418,
#  'tanah': 419,
#  'baca': 420,
#  'menit': 421,
#  'segera': 422,
#  'islam': 423,
#  'upaya': 424,
#  'disebut': 425,
#  'kecil': 426,
#  'mendapat': 427,
#  'sisi': 428,
#  'bahan': 429,
#  'akhir': 430,
#  'total': 431,
#  'wakil': 432,
#  'peristiwa': 433,
#  'arah': 434,
#  'langkah': 435,
#  'berharap': 436,
#  'satunya': 437,
#  'ri': 438,
#  'pidana': 439,
#  'cepat': 440,
#  'dulu': 441,
#  'puasa': 442,
#  'pihaknya': 443,
#  'mengungkapkan': 444,
#  'nah': 445,
#  'unit': 446,
#  'daya': 447,
#  'nya': 448,
#  'no': 449,
#  'badan': 450,
#  'mata': 451,
#  'asal': 452,
#  'biasa': 453,
#  'publik': 454,
#  'keluar': 455,
#  'suatu': 456,
#  'tadi': 457,
#  'bali': 458,
#  'kebutuhan': 459,
#  'pasti': 460,
#  'pertemuan': 461,
#  'tua': 462,
#  'belajar': 463,
#  'budaya': 464,
#  'bahasa': 465,
#  'pekerjaan': 466,
#  'mahasiswa': 467,
#  'kelompok': 468,
#  'disampaikan': 469,
#  'adapun': 470,
#  'dpr': 471,
#  'muda': 472,
#  'fasilitas': 473,
#  'inggris': 474,
#  'tni': 475,
#  'memilih': 476,
#  'muhammadiyah': 477,
#  'pemain': 478,
#  'zodiak': 479,
#  'kasih': 480,
#  'hadir': 481,
#  'transaksi': 482,
#  'pria': 483,
#  'ucap': 484,
#  'selanjutnya': 485,
#  'poin': 486,
#  'berjalan': 487,
#  'laki': 488,
#  'lewat': 489,
#  'hak': 490,
#  'momen': 491,
#  'vs': 492,
#  'sumber': 493,
#  'israel': 494,
#  'biaya': 495,
#  'pembangunan': 496,
#  'tindakan': 497,
#  'bandung': 498,
#  'lakukan': 499,
#  'menuju': 500,
#  'film': 501,
#  'agama': 502,
#  'ujarnya': 503,
#  'pantai': 504,
#  'industri': 505,
#  'ternyata': 506,
#  'tugas': 507,
#  'menunjukkan': 508,
#  'meninggal': 509,
#  'listrik': 510,
#  'pemeriksaan': 511,
#  'suku': 512,
#  'internasional': 513,
#  'mendukung': 514,
#  'siapa': 515,
#  'kesempatan': 516,
#  'terutama': 517,
#  'skor': 518,
#  'putih': 519,
#  'of': 520,
#  'alasan': 521,
#  'penumpang': 522,
#  'tingkat': 523,
#  'kapal': 524,
#  'id': 525,
#  'polres': 526,
#  'kebijakan': 527,
#  'ketiga': 528,
#  'kehidupan': 529,
#  'foto': 530,
#  'misalnya': 531,
#  'bukti': 532,
#  'tepat': 533,
#  'digelar': 534,
#  'berat': 535,
#  'panjang': 536,
#  'turut': 537,
#  'menjaga': 538,
#  'dekat': 539,
#  'seseorang': 540,
#  'mengambil': 541,
#  'tulis': 542,
#  'aksi': 543,
#  'sana': 544,
#  'maaf': 545,
#  'boleh': 546,
#  'muncul': 547,
#  'dosen': 548,
#  'lintas': 549,
#  'dugaan': 550,
#  'senilai': 551,
#  'gubernur': 552,
#  'sang': 553,
#  'proyek': 554,
#  'turun': 555,
#  'ungkap': 556,
#  'terlalu': 557,
#  'pimpinan': 558,
#  'mengetahui': 559,
#  'surabaya': 560,
#  'mengikuti': 561,
#  'jabatan': 562,
#  'sebenarnya': 563,
#  'penuh': 564,
#  'lembaga': 565,
#  'pertandingan': 566,
#  'pengguna': 567,
#  'bertemu': 568,
#  'sekaligus': 569,
#  'ruang': 570,
#  'suara': 571,
#  'empat': 572,
#  'bernama': 573,
#  'bantuan': 574,
#  'terima': 575,
#  'bila': 576,
#  'menyatakan': 577,
#  'ikut': 578,
#  'usaha': 579,
#  'bangsa': 580,
#  'pejabat': 581,
#  'tangan': 582,
#  'laut': 583,
#  'apalagi': 584,
#  'apabila': 585,
#  'pajak': 586,
#  'bakal': 587,
#  'keamanan': 588,
#  'tinggal': 589,
#  'kemarin': 590,
#  'dr': 591,
#  'instagram': 592,
#  'sumatera': 593,
#  'selesai': 594,
#  'bapak': 595,
#  'alam': 596,
#  'penyelidikan': 597,
#  'online': 598,
#  'sebagian': 599,
#  'tenaga': 600,
#  'jawaban': 601,
#  'salat': 602,
#  'kelas': 603,
#  'menurutnya': 604,
#  'pilihan': 605,
#  'keduanya': 606,
#  'luka': 607,
#  'stasiun': 608,
#  'pekan': 609,
#  'calon': 610,
#  'menu': 611,
#  'artinya': 612,
#  'memenuhi': 613,
#  'dana': 614,
#  'jasa': 615,
#  'kepolisian': 616,
#  'istri': 617,
#  'balik': 618,
#  'hotel': 619,
#  'umat': 620,
#  'kemenangan': 621,
#  'merah': 622,
#  'saling': 623,
#  'pemilu': 624,
#  'dikenal': 625,
#  'lima': 626,
#  'saksi': 627,
#  'tubuh': 628,
#  'simak': 629,
#  'menemukan': 630,
#  'siap': 631,
#  'anies': 632,
#  'luas': 633,
#  'terbaik': 634,
#  'uu': 635,
#  'buat': 636,
#  'berlangsung': 637,
#  'berupa': 638,
#  'memberi': 639,
#  'selaku': 640,
#  'metro': 641,
#  'peningkatan': 642,
#  'stadion': 643,
#  'pagi': 644,
#  'periode': 645,
#  'contoh': 646,
#  'kuat': 647,
#  'aman': 648,
#  'menjalani': 649,
#  'endar': 650,
#  'sepanjang': 651,
#  'dasar': 652,
#  'koalisi': 653,
#  'milik': 654,
#  'positif': 655,
#  'amerika': 656,
#  'ayat': 657,
#  'berlaku': 658,
#  'ii': 659,
#  'siswa': 660,
#  'tindak': 661,
#  'karier': 662,
#  'doa': 663,
#  'jaya': 664,
#  'perbedaan': 665,
#  'berasal': 666,
#  'viral': 667,
#  'aktivitas': 668,
#  'wartawan': 669,
#  'jepang': 670,
#  'membangun': 671,
#  'warna': 672,
#  'pengunjung': 673,
#  'khususnya': 674,
#  'pasangan': 675,
#  'tertentu': 676,
#  'beliau': 677,
#  'jawab': 678,
#  'pertanyaan': 679,
#  'lapangan': 680,
#  'dinas': 681,
#  'segala': 682,
#  'operasi': 683,
#  'khas': 684,
#  'paket': 685,
#  'bermain': 686,
#  'nyaman': 687,
#  'gedung': 688,
#  'rapat': 689,
#  'gol': 690,
#  'pernyataan': 691,
#  'investasi': 692,
#  'organisasi': 693,
#  'jadwal': 694,
#  'china': 695,
#  'peserta': 696,
#  'pungkasnya': 697,
#  'aturan': 698,
#  'terlebih': 699,
#  'pilih': 700,
#  'menilai': 701,
#  'mempunyai': 702,
#  'melaporkan': 703,
#  'kemungkinan': 704,
#  'padahal': 705,
#  'korupsi': 706,
#  'sejarah': 707,
#  'pdip': 708,
#  'itulah': 709,
#  'membuka': 710,
#  'rencana': 711,
#  'timnas': 712,
#  'alat': 713,
#  'hakim': 714,
#  'meskipun': 715,
#  'lagu': 716,
#  'anaknya': 717,
#  'antaranya': 718,
#  'dukungan': 719,
#  'rata': 720,
#  'wajib': 721,
#  'kampung': 722,
#  'diterima': 723,
#  'wanita': 724,
#  'taman': 725,
#  'pers': 726,
#  'bumi': 727,
#  'rakyat': 728,
#  'pulau': 729,
#  'sedikit': 730,
#  'udara': 731,
#  'kemampuan': 732,
#  'dampak': 733,
#  'menikmati': 734,
#  'pribadi': 735,
#  'meningkat': 736,
#  'david': 737,
#  'pulang': 738,
#  'terletak': 739,
#  'artikel': 740,
#  'bicara': 741,
#  'pembayaran': 742,
#  'iii': 743,
#  'lihat': 744,
#  'muslim': 745,
#  'sulit': 746,
#  'dki': 747,
#  'sepeda': 748,
#  'ahmad': 749,
#  'sidang': 750,
#  'justru': 751,
#  'menyebabkan': 752,
#  'mantan': 753,
#  'terlibat': 754,
#  'agung': 755,
#  'minyak': 756,
#  'peraturan': 757,
#  'titik': 758,
#  'penjara': 759,
#  'kinerja': 760,
#  'pekerja': 761,
#  'rest': 762,
#  'pengalaman': 763,
#  'rusia': 764,
#  'gempa': 765,
#  'city': 766,
#  'asn': 767,
#  'musim': 768,
#  'isu': 769,
#  'menegaskan': 770,
#  'berita': 771,
#  'tentunya': 772,
#  'melawan': 773,
#  'piala': 774,
#  'bola': 775,
#  'kartu': 776,
#  'senjata': 777,
#  'tutur': 778,
#  'pengadilan': 779,
#  'perkara': 780,
#  'ppp': 781,
#  'matahari': 782,
#  'kabar': 783,
#  'puncak': 784,
#  'peran': 785,
#  'rekomendasi': 786,
#  'tampak': 787,
#  'jelasnya': 788,
#  'jl': 789,
#  'beragam': 790,
#  'bangunan': 791,
#  'jenderal': 792,
#  'melaksanakan': 793,
#  'demi': 794,
#  'pula': 795,
#  'usd': 796,
#  'hampir': 797,
#  'pintu': 798,
#  'pelayanan': 799,
#  'pegawai': 800,
#  'covid': 801,
#  'mengutip': 802,
#  'belakang': 803,
#  'mendatang': 804,
#  'menang': 805,
#  'kamar': 806,
#  'terbuka': 807,
#  'lantas': 808,
#  'bumn': 809,
#  'menghadapi': 810,
#  'capres': 811,
#  'penggunaan': 812,
#  'coba': 813,
#  'berusia': 814,
#  'merdeka': 815,
#  'membeli': 816,
#  'muhammad': 817,
#  'pemilik': 818,
#  'sungai': 819,
#  'setempat': 820,
#  'dokumen': 821,
#  'gunung': 822,
#  'kalian': 823,
#  'dibandingkan': 824,
#  'cuma': 825,
#  'daftar': 826,
#  'fokus': 827,
#  'pesawat': 828,
#  'sehat': 829,
#  'komisi': 830,
#  'ikan': 831,
#  'usia': 832,
#  'kenaikan': 833,
#  'minta': 834,
#  'hukuman': 835,
#  'terbaru': 836,
#  'pemudik': 837,
#  'gerindra': 838,
#  'syarat': 839,
#  'terdiri': 840,
#  'menambahkan': 841,
#  'saham': 842,
#  'akbp': 843,
#  'ibadah': 844,
#  'indah': 845,
#  'pelabuhan': 846,
#  'budi': 847,
#  'tokoh': 848,
#  'serangan': 849,
#  'ditangkap': 850,
#  'minuman': 851,
#  'potensi': 852,
#  'bus': 853,
#  'menyediakan': 854,
#  'produksi': 855,
#  'arab': 856,
#  'perkembangan': 857,
#  'model': 858,
#  'faktor': 859,
#  'universitas': 860,
#  'buruh': 861,
#  'dianggap': 862,
#  'keras': 863,
#  'berangkat': 864,
#  'akses': 865,
#  'nantinya': 866,
#  'menggelar': 867,
#  'kualitas': 868,
#  'ayam': 869,
#  'dini': 870,
#  'ali': 871,
#  'serikat': 872,
#  'asia': 873,
#  'kaki': 874,
#  'united': 875,
#  'kecelakaan': 876,
#  'bagus': 877,
#  'dibawa': 878,
#  'lapas': 879,
#  'situasi': 880,
#  'halaman': 881,
#  'pemuda': 882,
#  'yogyakarta': 883,
#  'komunikasi': 884,
#  'berusaha': 885,
#  'ma': 886,
#  'izin': 887,
#  'kombes': 888,
#  'mencoba': 889,
#  'perdagangan': 890,
#  'lahir': 891,
#  'pontianak': 892,
#  'libur': 893,
#  'raja': 894,
#  'alias': 895,
#  'penyakit': 896,
#  'konflik': 897,
#  'tarif': 898,
#  'tewas': 899,
#  'berarti': 900,
#  'tantangan': 901,
#  'supaya': 902,
#  'sebagaimana': 903,
#  'ilmu': 904,
#  'penjelasan': 905,
#  'pemimpin': 906,
#  'cocok': 907,
#  'kredit': 908,
#  'tersedia': 909,
#  'ahli': 910,
#  'and': 911,
#  'terbesar': 912,
#  'aktif': 913,
#  'februari': 914,
#  'penganiayaan': 915,
#  'pelanggaran': 916,
#  'sudan': 917,
#  'kuartal': 918,
#  'dibuat': 919,
#  'up': 920,
#  'putra': 921,
#  'dahulu': 922,
#  'situs': 923,
#  'pendapatan': 924,
#  'mati': 925,
#  'restoran': 926,
#  'sektor': 927,
#  'mahfud': 928,
#  'nggak': 929,
#  'bebas': 930,
#  'asmara': 931,
#  'konsumen': 932,
#  'permintaan': 933,
#  'batu': 934,
#  'pranowo': 935,
#  'ancaman': 936,
#  'kenapa': 937,
#  'sulawesi': 938,
#  'papua': 939,
#  'mendorong': 940,
#  'mengurangi': 941,
#  'sambil': 942,
#  'perhatian': 943,
#  'dewan': 944,
#  'pemerintahan': 945,
#  'sosok': 946,
#  'sehari': 947,
#  'status': 948,
#  'saudi': 949,
#  'jemaah': 950,
#  'ucapan': 951,
#  'diharapkan': 952,
#  'zakat': 953,
#  'melanjutkan': 954,
#  'tanda': 955,
#  'one': 956,
#  'lokal': 957,
#  'membutuhkan': 958,
#  'penyebab': 959,
#  'penjualan': 960,
#  'wni': 961,
#  'manajemen': 962,
#  'grup': 963,
#  'hitam': 964,
#  'ketum': 965,
#  'laman': 966,
#  'maksimal': 967,
#  'sambungnya': 968,
#  'ramai': 969,
#  'bupati': 970,
#  'olahraga': 971,
#  'bersih': 972,
#  'si': 973,
#  'ramalan': 974,
#  'generasi': 975,
#  'pesan': 976,
#  'maju': 977,
#  'korea': 978,
#  'beredar': 979,
#  'com': 980,
#  'meraih': 981,
#  'sikap': 982,
#  'pakaian': 983,
#  'klik': 984,
#  'fifa': 985,
#  'target': 986,
#  'ungkapnya': 987,
#  'pengembangan': 988,
#  'bogor': 989,
#  'sri': 990,
#  'melibatkan': 991,
#  'tambahan': 992,
#  'semangat': 993,
#  'memahami': 994,
#  'menambah': 995,
#  'saudara': 996,
#  'membahas': 997,
#  'cerita': 998,
#  'to': 999,
#  ...}
