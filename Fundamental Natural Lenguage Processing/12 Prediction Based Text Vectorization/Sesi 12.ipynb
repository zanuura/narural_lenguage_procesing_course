# %% [markdown]
# ## Prediction-Based Text Vectorization

# %% [markdown]
# Metode dalam text vectorization yang menggunakan model prediksi bahasa untuk menghasilkan representasi numerik dari teks.

# %% [markdown]
# Pada latihan kali ini, library yang digunakan adalah library dari gensim yang bisa diinstall dengan `pip install gensim`

# %% [markdown]
# # 1. CBOW

# %%
import pandas as pd
from gensim.models import Word2Vec
import gensim

# %%
data_path = '/content/dataset.json'

# %%
data = pd.read_json(data_path, lines=True)

# %%
data.head()
# Out:
#                                                0      \
# 0  PPP resmi mendukung Ganjar Pranowo sebagai cap...
#
#                                                1      \
# 0  Manajemen keuangan  yang baik bisa dimulai sej...
#
#                                                2      \
# 0  Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
#
#                                                3      \
# 0  Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
#
#                                                4      \
# 0  Seorang pengendara motor di Kota Cimahi, Jawa ...
#
#                                                5      \
# 0  .\n\nLayanan belanja sekarang bayar nanti (pay...
#
#                                                6      \
# 0  Laptop  saat ini jadi perangkat penting yang d...
#
#                                                7      \
# 0  Laptop  saat ini jadi perangkat penting yang d...
#
#                                                8      \
# 0  .\n\nAC Milan  sukses menendang Napoli  dari L...
#
#                                                9      ...  \
# 0  Badan Pusat Statistik (BPS ) menyebut anjlokny...  ...
#
#                                                14375  \
# 0  Kepolisian Resor Mamuju Tengah menangkap dua o...
#
#                                                14376  \
# 0  Barcelona  harus puas berbagi angka saat berha...
#
#                                                14377  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14378  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14379  \
# 0  .\n\nLampung Geh, Lampung Selatan -  Menteri B...
#
#                                                14380  \
# 0  Polres Jeneponto diserang pada Kamis dini hari...
#
#                                                14381  \
# 0  Santri  mengamati uang pecahan Rp10 ribu saat ...
#
#                                                14382  \
# 0  Singapore Food Agency (SFA) menyetop impor  ba...
#
#                                                14383  \
# 0  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
#                                                14384
# 0  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
# [1 rows x 14385 columns]

# %%
# Transpose data
data = data.T

# %%
data.head()
# Out:
#                                                    0
# 0  PPP resmi mendukung Ganjar Pranowo sebagai cap...
# 1  Manajemen keuangan  yang baik bisa dimulai sej...
# 2  Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
# 3  Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
# 4  Seorang pengendara motor di Kota Cimahi, Jawa ...

# %%
data.rename(columns={0: 'content'}, inplace=True)

# %%
data.tail()
# Out:
#                                                  content
# 14380  Polres Jeneponto diserang pada Kamis dini hari...
# 14381  Santri  mengamati uang pecahan Rp10 ribu saat ...
# 14382  Singapore Food Agency (SFA) menyetop impor  ba...
# 14383  Pemerintahan Presiden Amerika Serikat (AS) Joe...
# 14384  Pemerintahan Presiden Amerika Serikat (AS) Joe...

# %%
data = data.drop_duplicates(keep="first", inplace=False)
data = data.dropna(subset=['content'])

# %%
data
# Out:
#                                                  content
# 0      PPP resmi mendukung Ganjar Pranowo sebagai cap...
# 1      Manajemen keuangan  yang baik bisa dimulai sej...
# 2      Wakil Ketua Dewan Pembina Gerindra Sandiaga Un...
# 3      Ketua Umum PKB Muhaimin Iskandar alias Cak Imi...
# 4      Seorang pengendara motor di Kota Cimahi, Jawa ...
# ...                                                  ...
# 14377  Polres Jeneponto diserang pada Kamis dini hari...
# 14379  .\n\nLampung Geh, Lampung Selatan -  Menteri B...
# 14381  Santri  mengamati uang pecahan Rp10 ribu saat ...
# 14382  Singapore Food Agency (SFA) menyetop impor  ba...
# 14383  Pemerintahan Presiden Amerika Serikat (AS) Joe...
#
# [8637 rows x 1 columns]

# %% [markdown]
# Konversi ke dalam bentuk yang dipahami gensim word2vec

# %%
clean_data = data['content'].apply(gensim.utils.simple_preprocess)

# %%
clean_data
# Out:
# 0        [ppp, resmi, mendukung, ganjar, pranowo, sebag...
# 1        [manajemen, keuangan, yang, baik, bisa, dimula...
# 2        [wakil, ketua, dewan, pembina, gerindra, sandi...
# 3        [ketua, umum, pkb, muhaimin, iskandar, alias, ...
# 4        [seorang, pengendara, motor, di, kota, cimahi,...
#                                ...
# 14377    [polres, jeneponto, diserang, pada, kamis, din...
# 14379    [lampung, geh, lampung, selatan, menteri, bumn...
# 14381    [santri, mengamati, uang, pecahan, rp, ribu, s...
# 14382    [singapore, food, agency, sfa, menyetop, impor...
# 14383    [pemerintahan, presiden, amerika, serikat, as,...
# Name: content, Length: 8637, dtype: object

# %% [markdown]
# sg: Algoritma pelatihan, CBOW(0) dan skip gram(1). Default adalah CBOW(0)

# %%
model_cbow = Word2Vec(clean_data, min_count=3, workers=3, window = 3, sg = 0)

# %%
model_cbow_2 = Word2Vec(clean_data, min_count=5, workers=3, window = 2, sg = 0)

# %%
model_cbow.build_vocab(clean_data, progress_per=1000)
model_cbow.train(clean_data, total_examples=model_cbow.corpus_count, epochs=model_cbow.epochs)
# Out:
# WARNING:gensim.models.keyedvectors:sorting after vectors have been allocated is expensive & error-prone
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (12403460, 14119455)

# %%
model_cbow_2.build_vocab(clean_data, progress_per=1000)
model_cbow_2.train(clean_data, total_examples=model_cbow_2.corpus_count, epochs=model_cbow_2.epochs)
# Out:
# WARNING:gensim.models.keyedvectors:sorting after vectors have been allocated is expensive & error-prone
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (12254032, 14119455)

# %%
model_cbow.save("./model_cbow.model")

# %%
model_cbow.wv.most_similar("korea")
# Out:
# [('rhodesia', 0.675208568572998),
#  ('sumatra', 0.6643838882446289),
#  ('afrika', 0.6131760478019714),
#  ('tapanuli', 0.6056145429611206),
#  ('pagai', 0.5894243121147156),
#  ('tanabala', 0.5765926837921143),
#  ('sumatera', 0.5752552151679993),
#  ('luwu', 0.5743155479431152),
#  ('sulawesi', 0.5727336406707764),
#  ('kayong', 0.5506176352500916)]

# %%
model_cbow_2.wv.most_similar("jakarta")
# Out:
# [('tangerang', 0.5371121764183044),
#  ('monas', 0.5288844704627991),
#  ('perbelanjaan', 0.5111390948295593),
#  ('korea', 0.48645028471946716),
#  ('nagreg', 0.48588040471076965),
#  ('kutub', 0.47718319296836853),
#  ('bogor', 0.47226011753082275),
#  ('jaksel', 0.470218300819397),
#  ('tebet', 0.4584469795227051),
#  ('pontianak', 0.4562956392765045)]

# %%
model_cbow.wv['jakarta']
# Out:
# array([ 0.81410027, -1.537624  , -1.0829258 , -1.3937246 ,  2.080511  ,
#        -1.7189581 , -2.9876356 , -0.8506641 ,  2.1221383 ,  0.309153  ,
#         0.37311465,  1.0695043 , -2.4522593 , -0.06711048, -0.8234186 ,
#         1.161898  , -0.08868101,  0.39217356,  2.3431296 , -3.0425837 ,
#         3.3517861 ,  0.19228312,  2.0484798 ,  2.2557359 ,  0.4989    ,
#         1.6929488 ,  0.24341449,  1.6142893 , -0.66548294, -0.7940363 ,
#         2.448433  , -0.3906241 ,  0.6352482 , -0.4336496 , -1.7101483 ,
#        -3.1923943 ,  0.4550399 ,  1.0709392 ,  0.54153645, -4.580053  ,
#         2.241644  ,  0.91329813,  2.2185552 ,  0.9941851 ,  2.0615034 ,
#         1.2530289 , -2.0640092 ,  1.4458201 ,  4.4924636 ,  0.07544965,
#        -1.3628931 , -0.9391696 , -0.77249736, -0.01307233,  0.01506492,
#        -0.38745734,  2.8226533 ,  2.6454558 ,  1.5090199 ,  0.6874521 ,
#         1.2477663 ,  0.7477161 ,  1.6425675 ,  1.777242  , -2.5793765 ,
#         0.7380453 , -1.59909   , -1.4852897 , -0.12736082, -1.499125  ,
#        -4.1280646 ,  0.28159693,  2.0923407 , -2.854759  , -0.5821766 ,
#        -0.8750819 ,  0.7763985 , -0.4896262 , -0.5735909 , -2.3219492 ,
#        -0.5831323 ,  2.5187876 ,  1.9180781 , -0.7709885 ,  0.35030994,
#        -0.04800171,  1.0162371 , -0.2505152 , -2.8187563 ,  0.19578043,
#         0.23996007, -2.5592725 , -0.7756516 ,  2.8964033 ,  2.7984357 ,
#        -0.6568024 , -1.4331944 , -1.5117426 ,  1.5583172 ,  1.7662772 ],
#       dtype=float32)

# %%
model_cbow_2.wv['jakarta']
# Out:
# array([-2.6938076 , -0.5043423 ,  0.7696607 , -0.41427448, -0.49736008,
#         1.9122648 ,  1.3616443 ,  1.6256201 ,  0.5459256 , -2.2120724 ,
#        -0.77945167,  0.18299933, -1.3405207 ,  0.527081  , -0.56532764,
#        -3.0832357 , -0.5363368 , -2.3178823 ,  0.20370966, -1.9522612 ,
#        -1.9016595 , -1.0260912 ,  1.0630432 , -0.41219974,  1.9972317 ,
#         0.6905018 ,  1.3612916 ,  1.8432562 ,  2.1302462 ,  0.94845515,
#        -0.54347837,  0.10815062,  0.18798833, -0.18852116, -0.45961067,
#         0.00599091,  1.4333259 , -0.9356349 ,  0.9400231 , -0.47939596,
#         1.0534741 , -0.38795853,  0.15476716,  0.2348133 ,  2.0283124 ,
#         1.4888669 ,  2.2342966 , -0.85814595,  0.8965871 , -0.0491261 ,
#        -0.13725248, -0.39763418, -0.92175853,  0.05025787,  1.4011439 ,
#        -0.1593177 , -1.635417  , -0.09061751, -2.721582  ,  1.740517  ,
#         2.1743336 ,  0.19315435,  0.9301077 ,  3.447936  , -3.7608342 ,
#         1.4827169 , -0.6927207 ,  0.33044666, -1.1281486 , -0.9424347 ,
#         0.62744445, -0.79971194, -0.53337294, -1.276021  ,  0.8969656 ,
#        -1.3531938 ,  1.6434433 ,  0.32654375,  2.1084898 ,  1.1393393 ,
#        -1.0319451 , -0.9504331 ,  1.5283498 ,  0.02432684, -2.6547945 ,
#         0.22548898, -1.4603853 ,  0.79355353, -0.7175369 ,  2.0083528 ,
#        -2.7410576 ,  1.6743805 ,  1.1103327 ,  2.6405048 ,  1.0234858 ,
#        -1.7248781 ,  0.7353643 ,  0.4984481 ,  1.062593  , -0.6193356 ],
#       dtype=float32)

# %%
model_cbow.wv.most_similar_cosmul(positive=['jakarta', 'model'], negative=['tangerang'])
# Out:
# [('produk', 0.940834105014801),
#  ('sertamu', 0.9323060512542725),
#  ('listrik', 0.8901747465133667),
#  ('pastinya', 0.8785401582717896),
#  ('berkembang', 0.8744855523109436),
#  ('jual', 0.8736470937728882),
#  ('mengayomi', 0.8690223097801208),
#  ('honda', 0.8647385835647583),
#  ('bekal', 0.8618462085723877),
#  ('pdb', 0.8606938719749451)]

# %%
model_cbow_2.wv.most_similar_cosmul(positive=['jakarta', 'model'], negative=['tangerang'])
# Out:
# [('beda', 0.8588116765022278),
#  ('perantara', 0.8548314571380615),
#  ('timbul', 0.8396003246307373),
#  ('produk', 0.8242548704147339),
#  ('maju', 0.8144422769546509),
#  ('varian', 0.8102501630783081),
#  ('kredit', 0.8095846772193909),
#  ('kinerja', 0.8088123798370361),
#  ('contoh', 0.8086586594581604),
#  ('kunci', 0.8083571791648865)]

# %%
model_cbow.wv.key_to_index
# Out:
# {'yang': 0,
#  'di': 1,
#  'dan': 2,
#  'ini': 3,
#  'dengan': 4,
#  'untuk': 5,
#  'dari': 6,
#  'itu': 7,
#  'dalam': 8,
#  'pada': 9,
#  'tidak': 10,
#  'juga': 11,
#  'akan': 12,
#  'ke': 13,
#  'ada': 14,
#  'bisa': 15,
#  'tersebut': 16,
#  'atau': 17,
#  'sudah': 18,
#  'oleh': 19,
#  'saat': 20,
#  'kita': 21,
#  'adalah': 22,
#  'menjadi': 23,
#  'karena': 24,
#  'tahun': 25,
#  'indonesia': 26,
#  'orang': 27,
#  'lebih': 28,
#  'sebagai': 29,
#  'kata': 30,
#  'saya': 31,
#  'mereka': 32,
#  'dapat': 33,
#  'satu': 34,
#  'hari': 35,
#  'dia': 36,
#  'rp': 37,
#  'hal': 38,
#  'kepada': 39,
#  'kamu': 40,
#  'seperti': 41,
#  'telah': 42,
#  'bahwa': 43,
#  'kami': 44,
#  'masih': 45,
#  'hingga': 46,
#  'banyak': 47,
#  'jadi': 48,
#  'ia': 49,
#  'melakukan': 50,
#  'tak': 51,
#  'anak': 52,
#  'masyarakat': 53,
#  'secara': 54,
#  'hanya': 55,
#  'namun': 56,
#  'salah': 57,
#  'harus': 58,
#  'merupakan': 59,
#  'jakarta': 60,
#  'lalu': 61,
#  'bagi': 62,
#  'memiliki': 63,
#  'para': 64,
#  'lain': 65,
#  'dilakukan': 66,
#  'beberapa': 67,
#  'kota': 68,
#  'baik': 69,
#  'baru': 70,
#  'korban': 71,
#  'atas': 72,
#  'negara': 73,
#  'mengatakan': 74,
#  'sama': 75,
#  'belum': 76,
#  'setelah': 77,
#  'rumah': 78,
#  'jika': 79,
#  'terjadi': 80,
#  'jalan': 81,
#  'sangat': 82,
#  'kemudian': 83,
#  'agar': 84,
#  'tempat': 85,
#  'kalau': 86,
#  'apa': 87,
#  'selain': 88,
#  'besar': 89,
#  'saja': 90,
#  'serta': 91,
#  'pun': 92,
#  'terkait': 93,
#  'sampai': 94,
#  'dua': 95,
#  'cara': 96,
#  'sehingga': 97,
#  'bersama': 98,
#  'waktu': 99,
#  'membuat': 100,
#  'melalui': 101,
#  'ya': 102,
#  'memberikan': 103,
#  'lagi': 104,
#  'sementara': 105,
#  'tapi': 106,
#  'selama': 107,
#  'pemerintah': 108,
#  'april': 109,
#  'persen': 110,
#  'dunia': 111,
#  'kasus': 112,
#  'bulan': 113,
#  'terhadap': 114,
#  'semua': 115,
#  'pelaku': 116,
#  'sekitar': 117,
#  'pihak': 118,
#  'lainnya': 119,
#  'mulai': 120,
#  'kembali': 121,
#  'tentang': 122,
#  'ketika': 123,
#  'langsung': 124,
#  'berbagai': 125,
#  'sebelumnya': 126,
#  'sosial': 127,
#  'bukan': 128,
#  'kedua': 129,
#  'terus': 130,
#  'menggunakan': 131,
#  'pertama': 132,
#  'tengah': 133,
#  'informasi': 134,
#  'wib': 135,
#  'menurut': 136,
#  'kali': 137,
#  'tetap': 138,
#  'warga': 139,
#  'kerja': 140,
#  'lebaran': 141,
#  'sendiri': 142,
#  'memang': 143,
#  'keluarga': 144,
#  'ingin': 145,
#  'berikut': 146,
#  'perlu': 147,
#  'seorang': 148,
#  'masuk': 149,
#  'pukul': 150,
#  'kpk': 151,
#  'sedang': 152,
#  'media': 153,
#  'hukum': 154,
#  'uang': 155,
#  'presiden': 156,
#  'juta': 157,
#  'antara': 158,
#  'kabupaten': 159,
#  'maka': 160,
#  'kesehatan': 161,
#  'berada': 162,
#  'tinggi': 163,
#  'hasil': 164,
#  'pt': 165,
#  'diri': 166,
#  'bahkan': 167,
#  'perusahaan': 168,
#  'harga': 169,
#  'jawa': 170,
#  'ketua': 171,
#  'proses': 172,
#  'setiap': 173,
#  'daerah': 174,
#  'sejak': 175,
#  'soal': 176,
#  'yaitu': 177,
#  'termasuk': 178,
#  'program': 179,
#  'sesuai': 180,
#  'tim': 181,
#  'barat': 182,
#  'nomor': 183,
#  'mobil': 184,
#  'cukup': 185,
#  'ujar': 186,
#  'air': 187,
#  'kegiatan': 188,
#  'selatan': 189,
#  'mungkin': 190,
#  'anda': 191,
#  'pendidikan': 192,
#  'sebuah': 193,
#  'jam': 194,
#  'bagian': 195,
#  'kendaraan': 196,
#  'jumat': 197,
#  'kepala': 198,
#  'sebelum': 199,
#  'ganjar': 200,
#  'jokowi': 201,
#  'sejumlah': 202,
#  'seluruh': 203,
#  'ibu': 204,
#  'polisi': 205,
#  'masa': 206,
#  'mendapatkan': 207,
#  'umum': 208,
#  'perempuan': 209,
#  'kamis': 210,
#  'kumparan': 211,
#  'tol': 212,
#  'pernah': 213,
#  'kondisi': 214,
#  'surat': 215,
#  'wilayah': 216,
#  'partai': 217,
#  'yakni': 218,
#  'mana': 219,
#  'tetapi': 220,
#  'fitri': 221,
#  'nama': 222,
#  'adanya': 223,
#  'sempat': 224,
#  'minggu': 225,
#  'luar': 226,
#  'bawah': 227,
#  'jangan': 228,
#  'mudik': 229,
#  'idul': 230,
#  'barang': 231,
#  'paling': 232,
#  'depan': 233,
#  'melihat': 234,
#  'maupun': 235,
#  'malam': 236,
#  'ramadhan': 237,
#  'penting': 238,
#  'punya': 239,
#  'sebesar': 240,
#  'keuangan': 241,
#  'anggota': 242,
#  'nanti': 243,
#  'lampung': 244,
#  'kan': 245,
#  'berdasarkan': 246,
#  'tiga': 247,
#  'dikutip': 248,
#  'tahu': 249,
#  'menjelaskan': 250,
#  'mengalami': 251,
#  'masing': 252,
#  'usai': 253,
#  'selasa': 254,
#  'raya': 255,
#  'senin': 256,
#  'video': 257,
#  'enggak': 258,
#  'terakhir': 259,
#  'meminta': 260,
#  'lokasi': 261,
#  'rabu': 262,
#  'jelas': 263,
#  'pak': 264,
#  'laporan': 265,
#  'aku': 266,
#  'masalah': 267,
#  'begitu': 268,
#  'data': 269,
#  'mencapai': 270,
#  'negeri': 271,
#  'produk': 272,
#  'makanan': 273,
#  'hidup': 274,
#  'tanpa': 275,
#  'menteri': 276,
#  'mudah': 277,
#  'sekarang': 278,
#  'mau': 279,
#  'lama': 280,
#  'motor': 281,
#  'pasal': 282,
#  'area': 283,
#  'selalu': 284,
#  'lanjut': 285,
#  'timur': 286,
#  'benar': 287,
#  'menyebut': 288,
#  'sebab': 289,
#  'sabtu': 290,
#  'per': 291,
#  'akun': 292,
#  'jumlah': 293,
#  'diduga': 294,
#  'desa': 295,
#  'kini': 296,
#  'tiba': 297,
#  'utama': 298,
#  'politik': 299,
#  'mengaku': 300,
#  'masjid': 301,
#  'mengenai': 302,
#  'bagaimana': 303,
#  'resmi': 304,
#  'digunakan': 305,
#  'teman': 306,
#  'kementerian': 307,
#  'pusat': 308,
#  'km': 309,
#  'datang': 310,
#  'semakin': 311,
#  'wisata': 312,
#  'bekerja': 313,
#  'dirinya': 314,
#  'awal': 315,
#  'meski': 316,
#  'membantu': 317,
#  'nilai': 318,
#  'triliun': 319,
#  'kantor': 320,
#  'liga': 321,
#  'nasional': 322,
#  'ekonomi': 323,
#  'sebanyak': 324,
#  'sistem': 325,
#  'buku': 326,
#  'merasa': 327,
#  'berhasil': 328,
#  'jenis': 329,
#  'utara': 330,
#  'miliar': 331,
#  'bank': 332,
#  'demikian': 333,
#  'katanya': 334,
#  'aplikasi': 335,
#  'al': 336,
#  'akhirnya': 337,
#  'manusia': 338,
#  'tanggal': 339,
#  'allah': 340,
#  'lengkap': 341,
#  'direktur': 342,
#  'layanan': 343,
#  'polda': 344,
#  'naik': 345,
#  'keterangan': 346,
#  'petugas': 347,
#  'polri': 348,
#  'undang': 349,
#  'tentu': 350,
#  'apakah': 351,
#  'terlihat': 352,
#  'terdapat': 353,
#  'meningkatkan': 354,
#  'kecamatan': 355,
#  'kejadian': 356,
#  'makan': 357,
#  'berbeda': 358,
#  'laga': 359,
#  'pasar': 360,
#  'maret': 361,
#  'bisnis': 362,
#  'prabowo': 363,
#  'provinsi': 364,
#  'sakit': 365,
#  'ribu': 366,
#  'mampu': 367,
#  'posisi': 368,
#  'akibat': 369,
#  'bidang': 370,
#  'perjalanan': 371,
#  'tiket': 372,
#  'acara': 373,
#  'mei': 374,
#  'semoga': 375,
#  'mencari': 376,
#  'sekolah': 377,
#  'sekali': 378,
#  'sini': 379,
#  'kereta': 380,
#  'as': 381,
#  'api': 382,
#  'menyampaikan': 383,
#  'rasa': 384,
#  'kawasan': 385,
#  'menarik': 386,
#  'khusus': 387,
#  'kurang': 388,
#  'selamat': 389,
#  'dokter': 390,
#  'the': 391,
#  'menerima': 392,
#  'bentuk': 393,
#  'karya': 394,
#  'hubungan': 395,
#  'diberikan': 396,
#  'buka': 397,
#  'bandara': 398,
#  'guru': 399,
#  'jauh': 400,
#  'tersangka': 401,
#  'angka': 402,
#  'sedangkan': 403,
#  'membawa': 404,
#  'hati': 405,
#  'memastikan': 406,
#  'tujuan': 407,
#  'biasanya': 408,
#  'ditemukan': 409,
#  'diketahui': 410,
#  'perubahan': 411,
#  'sering': 412,
#  'digital': 413,
#  'keputusan': 414,
#  'teknologi': 415,
#  'jalur': 416,
#  'arus': 417,
#  'lingkungan': 418,
#  'tanah': 419,
#  'baca': 420,
#  'menit': 421,
#  'segera': 422,
#  'islam': 423,
#  'upaya': 424,
#  'disebut': 425,
#  'kecil': 426,
#  'mendapat': 427,
#  'sisi': 428,
#  'bahan': 429,
#  'akhir': 430,
#  'total': 431,
#  'wakil': 432,
#  'peristiwa': 433,
#  'arah': 434,
#  'langkah': 435,
#  'berharap': 436,
#  'satunya': 437,
#  'ri': 438,
#  'pidana': 439,
#  'cepat': 440,
#  'dulu': 441,
#  'puasa': 442,
#  'pihaknya': 443,
#  'mengungkapkan': 444,
#  'nah': 445,
#  'unit': 446,
#  'daya': 447,
#  'nya': 448,
#  'no': 449,
#  'badan': 450,
#  'mata': 451,
#  'asal': 452,
#  'biasa': 453,
#  'publik': 454,
#  'keluar': 455,
#  'suatu': 456,
#  'tadi': 457,
#  'bali': 458,
#  'kebutuhan': 459,
#  'pasti': 460,
#  'pertemuan': 461,
#  'tua': 462,
#  'belajar': 463,
#  'budaya': 464,
#  'bahasa': 465,
#  'pekerjaan': 466,
#  'mahasiswa': 467,
#  'kelompok': 468,
#  'disampaikan': 469,
#  'adapun': 470,
#  'dpr': 471,
#  'muda': 472,
#  'fasilitas': 473,
#  'inggris': 474,
#  'tni': 475,
#  'memilih': 476,
#  'muhammadiyah': 477,
#  'pemain': 478,
#  'zodiak': 479,
#  'kasih': 480,
#  'hadir': 481,
#  'transaksi': 482,
#  'pria': 483,
#  'ucap': 484,
#  'selanjutnya': 485,
#  'poin': 486,
#  'berjalan': 487,
#  'laki': 488,
#  'lewat': 489,
#  'hak': 490,
#  'momen': 491,
#  'vs': 492,
#  'sumber': 493,
#  'israel': 494,
#  'biaya': 495,
#  'pembangunan': 496,
#  'tindakan': 497,
#  'bandung': 498,
#  'lakukan': 499,
#  'menuju': 500,
#  'film': 501,
#  'agama': 502,
#  'ujarnya': 503,
#  'pantai': 504,
#  'industri': 505,
#  'ternyata': 506,
#  'tugas': 507,
#  'menunjukkan': 508,
#  'meninggal': 509,
#  'listrik': 510,
#  'pemeriksaan': 511,
#  'suku': 512,
#  'internasional': 513,
#  'mendukung': 514,
#  'siapa': 515,
#  'kesempatan': 516,
#  'terutama': 517,
#  'skor': 518,
#  'putih': 519,
#  'of': 520,
#  'alasan': 521,
#  'penumpang': 522,
#  'tingkat': 523,
#  'kapal': 524,
#  'id': 525,
#  'polres': 526,
#  'kebijakan': 527,
#  'ketiga': 528,
#  'kehidupan': 529,
#  'foto': 530,
#  'misalnya': 531,
#  'bukti': 532,
#  'tepat': 533,
#  'digelar': 534,
#  'berat': 535,
#  'panjang': 536,
#  'turut': 537,
#  'menjaga': 538,
#  'dekat': 539,
#  'seseorang': 540,
#  'mengambil': 541,
#  'tulis': 542,
#  'aksi': 543,
#  'sana': 544,
#  'maaf': 545,
#  'boleh': 546,
#  'muncul': 547,
#  'dosen': 548,
#  'lintas': 549,
#  'dugaan': 550,
#  'senilai': 551,
#  'gubernur': 552,
#  'sang': 553,
#  'proyek': 554,
#  'turun': 555,
#  'ungkap': 556,
#  'terlalu': 557,
#  'pimpinan': 558,
#  'mengetahui': 559,
#  'surabaya': 560,
#  'mengikuti': 561,
#  'jabatan': 562,
#  'sebenarnya': 563,
#  'penuh': 564,
#  'lembaga': 565,
#  'pertandingan': 566,
#  'pengguna': 567,
#  'bertemu': 568,
#  'sekaligus': 569,
#  'ruang': 570,
#  'suara': 571,
#  'empat': 572,
#  'bernama': 573,
#  'bantuan': 574,
#  'terima': 575,
#  'bila': 576,
#  'menyatakan': 577,
#  'ikut': 578,
#  'usaha': 579,
#  'bangsa': 580,
#  'pejabat': 581,
#  'tangan': 582,
#  'laut': 583,
#  'apalagi': 584,
#  'apabila': 585,
#  'pajak': 586,
#  'bakal': 587,
#  'keamanan': 588,
#  'tinggal': 589,
#  'kemarin': 590,
#  'dr': 591,
#  'instagram': 592,
#  'sumatera': 593,
#  'selesai': 594,
#  'bapak': 595,
#  'alam': 596,
#  'penyelidikan': 597,
#  'online': 598,
#  'sebagian': 599,
#  'tenaga': 600,
#  'jawaban': 601,
#  'salat': 602,
#  'kelas': 603,
#  'menurutnya': 604,
#  'pilihan': 605,
#  'keduanya': 606,
#  'luka': 607,
#  'stasiun': 608,
#  'pekan': 609,
#  'calon': 610,
#  'menu': 611,
#  'artinya': 612,
#  'memenuhi': 613,
#  'dana': 614,
#  'jasa': 615,
#  'kepolisian': 616,
#  'istri': 617,
#  'balik': 618,
#  'hotel': 619,
#  'umat': 620,
#  'kemenangan': 621,
#  'merah': 622,
#  'saling': 623,
#  'pemilu': 624,
#  'dikenal': 625,
#  'lima': 626,
#  'saksi': 627,
#  'tubuh': 628,
#  'simak': 629,
#  'menemukan': 630,
#  'siap': 631,
#  'anies': 632,
#  'luas': 633,
#  'terbaik': 634,
#  'uu': 635,
#  'buat': 636,
#  'berlangsung': 637,
#  'berupa': 638,
#  'memberi': 639,
#  'selaku': 640,
#  'metro': 641,
#  'peningkatan': 642,
#  'stadion': 643,
#  'pagi': 644,
#  'periode': 645,
#  'contoh': 646,
#  'kuat': 647,
#  'aman': 648,
#  'menjalani': 649,
#  'endar': 650,
#  'sepanjang': 651,
#  'dasar': 652,
#  'koalisi': 653,
#  'milik': 654,
#  'positif': 655,
#  'amerika': 656,
#  'ayat': 657,
#  'berlaku': 658,
#  'ii': 659,
#  'siswa': 660,
#  'tindak': 661,
#  'karier': 662,
#  'doa': 663,
#  'jaya': 664,
#  'perbedaan': 665,
#  'berasal': 666,
#  'viral': 667,
#  'aktivitas': 668,
#  'wartawan': 669,
#  'jepang': 670,
#  'membangun': 671,
#  'warna': 672,
#  'pengunjung': 673,
#  'khususnya': 674,
#  'pasangan': 675,
#  'tertentu': 676,
#  'beliau': 677,
#  'jawab': 678,
#  'pertanyaan': 679,
#  'lapangan': 680,
#  'dinas': 681,
#  'segala': 682,
#  'operasi': 683,
#  'khas': 684,
#  'paket': 685,
#  'bermain': 686,
#  'nyaman': 687,
#  'gedung': 688,
#  'rapat': 689,
#  'gol': 690,
#  'pernyataan': 691,
#  'investasi': 692,
#  'organisasi': 693,
#  'jadwal': 694,
#  'china': 695,
#  'peserta': 696,
#  'pungkasnya': 697,
#  'aturan': 698,
#  'terlebih': 699,
#  'pilih': 700,
#  'menilai': 701,
#  'mempunyai': 702,
#  'melaporkan': 703,
#  'kemungkinan': 704,
#  'padahal': 705,
#  'korupsi': 706,
#  'sejarah': 707,
#  'pdip': 708,
#  'itulah': 709,
#  'membuka': 710,
#  'rencana': 711,
#  'timnas': 712,
#  'alat': 713,
#  'hakim': 714,
#  'meskipun': 715,
#  'lagu': 716,
#  'anaknya': 717,
#  'antaranya': 718,
#  'dukungan': 719,
#  'rata': 720,
#  'wajib': 721,
#  'kampung': 722,
#  'diterima': 723,
#  'wanita': 724,
#  'taman': 725,
#  'pers': 726,
#  'bumi': 727,
#  'rakyat': 728,
#  'pulau': 729,
#  'sedikit': 730,
#  'udara': 731,
#  'kemampuan': 732,
#  'dampak': 733,
#  'menikmati': 734,
#  'pribadi': 735,
#  'meningkat': 736,
#  'david': 737,
#  'pulang': 738,
#  'terletak': 739,
#  'artikel': 740,
#  'bicara': 741,
#  'pembayaran': 742,
#  'iii': 743,
#  'lihat': 744,
#  'muslim': 745,
#  'sulit': 746,
#  'dki': 747,
#  'sepeda': 748,
#  'ahmad': 749,
#  'sidang': 750,
#  'justru': 751,
#  'menyebabkan': 752,
#  'mantan': 753,
#  'terlibat': 754,
#  'agung': 755,
#  'minyak': 756,
#  'peraturan': 757,
#  'titik': 758,
#  'penjara': 759,
#  'kinerja': 760,
#  'pekerja': 761,
#  'rest': 762,
#  'pengalaman': 763,
#  'rusia': 764,
#  'gempa': 765,
#  'city': 766,
#  'asn': 767,
#  'musim': 768,
#  'isu': 769,
#  'menegaskan': 770,
#  'berita': 771,
#  'tentunya': 772,
#  'melawan': 773,
#  'piala': 774,
#  'bola': 775,
#  'kartu': 776,
#  'senjata': 777,
#  'tutur': 778,
#  'pengadilan': 779,
#  'perkara': 780,
#  'ppp': 781,
#  'matahari': 782,
#  'kabar': 783,
#  'puncak': 784,
#  'peran': 785,
#  'rekomendasi': 786,
#  'tampak': 787,
#  'jelasnya': 788,
#  'jl': 789,
#  'beragam': 790,
#  'bangunan': 791,
#  'jenderal': 792,
#  'melaksanakan': 793,
#  'demi': 794,
#  'pula': 795,
#  'usd': 796,
#  'hampir': 797,
#  'pintu': 798,
#  'pelayanan': 799,
#  'pegawai': 800,
#  'covid': 801,
#  'mengutip': 802,
#  'belakang': 803,
#  'mendatang': 804,
#  'menang': 805,
#  'kamar': 806,
#  'terbuka': 807,
#  'lantas': 808,
#  'bumn': 809,
#  'menghadapi': 810,
#  'capres': 811,
#  'penggunaan': 812,
#  'coba': 813,
#  'berusia': 814,
#  'merdeka': 815,
#  'membeli': 816,
#  'muhammad': 817,
#  'pemilik': 818,
#  'sungai': 819,
#  'setempat': 820,
#  'dokumen': 821,
#  'gunung': 822,
#  'kalian': 823,
#  'dibandingkan': 824,
#  'cuma': 825,
#  'daftar': 826,
#  'fokus': 827,
#  'pesawat': 828,
#  'sehat': 829,
#  'komisi': 830,
#  'ikan': 831,
#  'usia': 832,
#  'kenaikan': 833,
#  'minta': 834,
#  'hukuman': 835,
#  'terbaru': 836,
#  'pemudik': 837,
#  'gerindra': 838,
#  'syarat': 839,
#  'terdiri': 840,
#  'menambahkan': 841,
#  'saham': 842,
#  'akbp': 843,
#  'ibadah': 844,
#  'indah': 845,
#  'pelabuhan': 846,
#  'budi': 847,
#  'tokoh': 848,
#  'serangan': 849,
#  'ditangkap': 850,
#  'minuman': 851,
#  'potensi': 852,
#  'bus': 853,
#  'menyediakan': 854,
#  'produksi': 855,
#  'arab': 856,
#  'perkembangan': 857,
#  'model': 858,
#  'faktor': 859,
#  'universitas': 860,
#  'buruh': 861,
#  'dianggap': 862,
#  'keras': 863,
#  'berangkat': 864,
#  'akses': 865,
#  'nantinya': 866,
#  'menggelar': 867,
#  'kualitas': 868,
#  'ayam': 869,
#  'dini': 870,
#  'ali': 871,
#  'serikat': 872,
#  'asia': 873,
#  'kaki': 874,
#  'united': 875,
#  'kecelakaan': 876,
#  'bagus': 877,
#  'dibawa': 878,
#  'lapas': 879,
#  'situasi': 880,
#  'halaman': 881,
#  'pemuda': 882,
#  'yogyakarta': 883,
#  'komunikasi': 884,
#  'berusaha': 885,
#  'ma': 886,
#  'izin': 887,
#  'kombes': 888,
#  'mencoba': 889,
#  'perdagangan': 890,
#  'lahir': 891,
#  'pontianak': 892,
#  'libur': 893,
#  'raja': 894,
#  'alias': 895,
#  'penyakit': 896,
#  'konflik': 897,
#  'tarif': 898,
#  'tewas': 899,
#  'berarti': 900,
#  'tantangan': 901,
#  'supaya': 902,
#  'sebagaimana': 903,
#  'ilmu': 904,
#  'penjelasan': 905,
#  'pemimpin': 906,
#  'cocok': 907,
#  'kredit': 908,
#  'tersedia': 909,
#  'ahli': 910,
#  'and': 911,
#  'terbesar': 912,
#  'aktif': 913,
#  'februari': 914,
#  'penganiayaan': 915,
#  'pelanggaran': 916,
#  'sudan': 917,
#  'kuartal': 918,
#  'dibuat': 919,
#  'up': 920,
#  'putra': 921,
#  'dahulu': 922,
#  'situs': 923,
#  'pendapatan': 924,
#  'mati': 925,
#  'restoran': 926,
#  'sektor': 927,
#  'mahfud': 928,
#  'nggak': 929,
#  'bebas': 930,
#  'asmara': 931,
#  'konsumen': 932,
#  'permintaan': 933,
#  'batu': 934,
#  'pranowo': 935,
#  'ancaman': 936,
#  'kenapa': 937,
#  'sulawesi': 938,
#  'papua': 939,
#  'mendorong': 940,
#  'mengurangi': 941,
#  'sambil': 942,
#  'perhatian': 943,
#  'dewan': 944,
#  'pemerintahan': 945,
#  'sosok': 946,
#  'sehari': 947,
#  'status': 948,
#  'saudi': 949,
#  'jemaah': 950,
#  'ucapan': 951,
#  'diharapkan': 952,
#  'zakat': 953,
#  'melanjutkan': 954,
#  'tanda': 955,
#  'one': 956,
#  'lokal': 957,
#  'membutuhkan': 958,
#  'penyebab': 959,
#  'penjualan': 960,
#  'wni': 961,
#  'manajemen': 962,
#  'grup': 963,
#  'hitam': 964,
#  'ketum': 965,
#  'laman': 966,
#  'maksimal': 967,
#  'sambungnya': 968,
#  'ramai': 969,
#  'bupati': 970,
#  'olahraga': 971,
#  'bersih': 972,
#  'si': 973,
#  'ramalan': 974,
#  'generasi': 975,
#  'pesan': 976,
#  'maju': 977,
#  'korea': 978,
#  'beredar': 979,
#  'com': 980,
#  'meraih': 981,
#  'sikap': 982,
#  'pakaian': 983,
#  'klik': 984,
#  'fifa': 985,
#  'target': 986,
#  'ungkapnya': 987,
#  'pengembangan': 988,
#  'bogor': 989,
#  'sri': 990,
#  'melibatkan': 991,
#  'tambahan': 992,
#  'semangat': 993,
#  'memahami': 994,
#  'menambah': 995,
#  'saudara': 996,
#  'membahas': 997,
#  'cerita': 998,
#  'to': 999,
#  ...}

# %% [markdown]
# # 2. SKIP-GRAM

# %%
model_skipgram = Word2Vec(clean_data, min_count=3, workers=3, window =3, sg = 1)

# %%
model_skipgram_2 = Word2Vec(clean_data, min_count = 5, workers = 3, window = 2, sg = 1)

# %%
model_skipgram.build_vocab(clean_data, progress_per=1000)
model_skipgram.train(clean_data, total_examples=model_skipgram.corpus_count, epochs=model_skipgram.epochs)
# Out:
# WARNING:gensim.models.keyedvectors:sorting after vectors have been allocated is expensive & error-prone
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (12403273, 14119455)

# %%
model_skipgram_2.build_vocab(clean_data, progress_per=1000)
model_skipgram_2.train(clean_data, total_examples=model_skipgram_2.corpus_count, epochs=model_skipgram_2.epochs)
# Out:
# WARNING:gensim.models.keyedvectors:sorting after vectors have been allocated is expensive & error-prone
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (12252365, 14119455)

# %%
model_skipgram.save("./model_skipgram.model")

# %%
model_skipgram.wv.most_similar("sandiaga")
# Out:
# [('uno', 0.8341730237007141),
#  ('salahuddin', 0.7296923398971558),
#  ('menparekraf', 0.7230873703956604),
#  ('oso', 0.6339700222015381),
#  ('gerindra', 0.6202329993247986),
#  ('rafli', 0.6170905828475952),
#  ('ganjarian', 0.61518794298172),
#  ('thohir', 0.6041550636291504),
#  ('mundur', 0.6013341546058655),
#  ('dipasangkan', 0.5976154208183289)]

# %%
model_skipgram_2.wv.most_similar("sandiaga")
# Out:
# [('uno', 0.7084506154060364),
#  ('salahuddin', 0.6855056881904602),
#  ('prabowo', 0.6673839688301086),
#  ('menparekraf', 0.6644760370254517),
#  ('hanura', 0.6409403085708618),
#  ('duet', 0.638599157333374),
#  ('mendeklarasikan', 0.6380643248558044),
#  ('desmond', 0.6301162838935852),
#  ('pengusung', 0.6264421939849854),
#  ('ahy', 0.6241039633750916)]

# %%
model_skipgram.wv['sandiaga']
# Out:
# array([ 0.02649695,  0.02234598,  0.37347078,  0.11977343, -0.42182627,
#         0.14438352,  1.4098506 ,  0.55257225, -0.43544993,  0.18819383,
#         0.22773963, -0.49750057,  0.44329455,  0.1695091 , -0.5214634 ,
#        -0.654717  ,  0.16290224, -0.02400804, -0.41588834,  0.18038285,
#         0.38259786,  0.07778295, -0.094966  ,  0.9724474 ,  0.67444825,
#         0.32952493, -0.55875725,  0.2972414 ,  0.2430169 ,  0.2887938 ,
#         0.89275086, -0.89428836, -0.03470521, -0.0099121 , -0.826569  ,
#         0.59627795,  0.67817974, -0.5944021 ,  0.6358281 , -0.28472146,
#         0.5409063 , -0.3461897 , -0.49388683,  0.302856  ,  0.97842586,
#        -0.47423643, -0.021933  , -0.02741507,  0.4888356 ,  0.6512335 ,
#        -0.6251683 , -0.5025365 , -0.57432836,  0.15510829,  0.03307483,
#         0.2068265 , -0.31838349, -0.27147502, -0.26349396,  0.41491348,
#         0.2713875 ,  0.16051272,  0.39803588,  0.4063181 , -1.0327652 ,
#         0.34001076, -0.06056989, -0.03469887, -0.03256943,  0.429541  ,
#        -0.33629617,  0.3043909 ,  0.18145047, -0.70078397,  0.5499632 ,
#        -0.25795192, -0.559239  ,  0.00862421, -0.27393338, -0.13010114,
#        -0.47945815, -0.9811653 ,  0.07352844,  0.10260036, -0.57791185,
#        -0.50488067,  0.4797464 , -0.75258327,  0.33356616, -1.5570798 ,
#         0.53393304, -0.37898102,  0.97387254, -0.54999864,  0.54929924,
#         0.09595388,  0.8871982 , -0.3052296 , -0.35886422, -0.5448625 ],
#       dtype=float32)

# %%
model_skipgram.wv.most_similar_cosmul(positive=['jakarta', 'mobil'], negative=['korea'])
# Out:
# [('bersenggolan', 0.9824720621109009),
#  ('kendaraan', 0.9813573360443115),
#  ('truk', 0.9468469619750977),
#  ('jabodebek', 0.9440714716911316),
#  ('bermotor', 0.9413668513298035),
#  ('lajur', 0.9375934600830078),
#  ('rush', 0.9285282492637634),
#  ('lrt', 0.9272882342338562),
#  ('transjakarta', 0.9256765842437744),
#  ('roda', 0.9252162575721741)]

# %%
model_skipgram_2.wv.most_similar_cosmul(positive=['jakarta', 'mobil'], negative=['korea'])
# Out:
# [('spbu', 0.9834356307983398),
#  ('sepeda', 0.9437838196754456),
#  ('kendaraan', 0.942536473274231),
#  ('motor', 0.9336618781089783),
#  ('unit', 0.9266325235366821),
#  ('sedan', 0.9249581098556519),
#  ('pikap', 0.9145265817642212),
#  ('pajero', 0.9132686257362366),
#  ('terminal', 0.9052368998527527),
#  ('jatinegara', 0.9000824689865112)]

# %%
model_skipgram.wv.key_to_index
# Out:
# {'yang': 0,
#  'di': 1,
#  'dan': 2,
#  'ini': 3,
#  'dengan': 4,
#  'untuk': 5,
#  'dari': 6,
#  'itu': 7,
#  'dalam': 8,
#  'pada': 9,
#  'tidak': 10,
#  'juga': 11,
#  'akan': 12,
#  'ke': 13,
#  'ada': 14,
#  'bisa': 15,
#  'tersebut': 16,
#  'atau': 17,
#  'sudah': 18,
#  'oleh': 19,
#  'saat': 20,
#  'kita': 21,
#  'adalah': 22,
#  'menjadi': 23,
#  'karena': 24,
#  'tahun': 25,
#  'indonesia': 26,
#  'orang': 27,
#  'lebih': 28,
#  'sebagai': 29,
#  'kata': 30,
#  'saya': 31,
#  'mereka': 32,
#  'dapat': 33,
#  'satu': 34,
#  'hari': 35,
#  'dia': 36,
#  'rp': 37,
#  'hal': 38,
#  'kepada': 39,
#  'kamu': 40,
#  'seperti': 41,
#  'telah': 42,
#  'bahwa': 43,
#  'kami': 44,
#  'masih': 45,
#  'hingga': 46,
#  'banyak': 47,
#  'jadi': 48,
#  'ia': 49,
#  'melakukan': 50,
#  'tak': 51,
#  'anak': 52,
#  'masyarakat': 53,
#  'secara': 54,
#  'hanya': 55,
#  'namun': 56,
#  'salah': 57,
#  'harus': 58,
#  'merupakan': 59,
#  'jakarta': 60,
#  'lalu': 61,
#  'bagi': 62,
#  'memiliki': 63,
#  'para': 64,
#  'lain': 65,
#  'dilakukan': 66,
#  'beberapa': 67,
#  'kota': 68,
#  'baik': 69,
#  'baru': 70,
#  'korban': 71,
#  'atas': 72,
#  'negara': 73,
#  'mengatakan': 74,
#  'sama': 75,
#  'belum': 76,
#  'setelah': 77,
#  'rumah': 78,
#  'jika': 79,
#  'terjadi': 80,
#  'jalan': 81,
#  'sangat': 82,
#  'kemudian': 83,
#  'agar': 84,
#  'tempat': 85,
#  'kalau': 86,
#  'apa': 87,
#  'selain': 88,
#  'besar': 89,
#  'saja': 90,
#  'serta': 91,
#  'pun': 92,
#  'terkait': 93,
#  'sampai': 94,
#  'dua': 95,
#  'cara': 96,
#  'sehingga': 97,
#  'bersama': 98,
#  'waktu': 99,
#  'membuat': 100,
#  'melalui': 101,
#  'ya': 102,
#  'memberikan': 103,
#  'lagi': 104,
#  'sementara': 105,
#  'tapi': 106,
#  'selama': 107,
#  'pemerintah': 108,
#  'april': 109,
#  'persen': 110,
#  'dunia': 111,
#  'kasus': 112,
#  'bulan': 113,
#  'terhadap': 114,
#  'semua': 115,
#  'pelaku': 116,
#  'sekitar': 117,
#  'pihak': 118,
#  'lainnya': 119,
#  'mulai': 120,
#  'kembali': 121,
#  'tentang': 122,
#  'ketika': 123,
#  'langsung': 124,
#  'berbagai': 125,
#  'sebelumnya': 126,
#  'sosial': 127,
#  'bukan': 128,
#  'kedua': 129,
#  'terus': 130,
#  'menggunakan': 131,
#  'pertama': 132,
#  'tengah': 133,
#  'informasi': 134,
#  'wib': 135,
#  'menurut': 136,
#  'kali': 137,
#  'tetap': 138,
#  'warga': 139,
#  'kerja': 140,
#  'lebaran': 141,
#  'sendiri': 142,
#  'memang': 143,
#  'keluarga': 144,
#  'ingin': 145,
#  'berikut': 146,
#  'perlu': 147,
#  'seorang': 148,
#  'masuk': 149,
#  'pukul': 150,
#  'kpk': 151,
#  'sedang': 152,
#  'media': 153,
#  'hukum': 154,
#  'uang': 155,
#  'presiden': 156,
#  'juta': 157,
#  'antara': 158,
#  'kabupaten': 159,
#  'maka': 160,
#  'kesehatan': 161,
#  'berada': 162,
#  'tinggi': 163,
#  'hasil': 164,
#  'pt': 165,
#  'diri': 166,
#  'bahkan': 167,
#  'perusahaan': 168,
#  'harga': 169,
#  'jawa': 170,
#  'ketua': 171,
#  'proses': 172,
#  'setiap': 173,
#  'daerah': 174,
#  'sejak': 175,
#  'soal': 176,
#  'yaitu': 177,
#  'termasuk': 178,
#  'program': 179,
#  'sesuai': 180,
#  'tim': 181,
#  'barat': 182,
#  'nomor': 183,
#  'mobil': 184,
#  'cukup': 185,
#  'ujar': 186,
#  'air': 187,
#  'kegiatan': 188,
#  'selatan': 189,
#  'mungkin': 190,
#  'anda': 191,
#  'pendidikan': 192,
#  'sebuah': 193,
#  'jam': 194,
#  'bagian': 195,
#  'kendaraan': 196,
#  'jumat': 197,
#  'kepala': 198,
#  'sebelum': 199,
#  'ganjar': 200,
#  'jokowi': 201,
#  'sejumlah': 202,
#  'seluruh': 203,
#  'ibu': 204,
#  'polisi': 205,
#  'masa': 206,
#  'mendapatkan': 207,
#  'umum': 208,
#  'perempuan': 209,
#  'kamis': 210,
#  'kumparan': 211,
#  'tol': 212,
#  'pernah': 213,
#  'kondisi': 214,
#  'surat': 215,
#  'wilayah': 216,
#  'partai': 217,
#  'yakni': 218,
#  'mana': 219,
#  'tetapi': 220,
#  'fitri': 221,
#  'nama': 222,
#  'adanya': 223,
#  'sempat': 224,
#  'minggu': 225,
#  'luar': 226,
#  'bawah': 227,
#  'jangan': 228,
#  'mudik': 229,
#  'idul': 230,
#  'barang': 231,
#  'paling': 232,
#  'depan': 233,
#  'melihat': 234,
#  'maupun': 235,
#  'malam': 236,
#  'ramadhan': 237,
#  'penting': 238,
#  'punya': 239,
#  'sebesar': 240,
#  'keuangan': 241,
#  'anggota': 242,
#  'nanti': 243,
#  'lampung': 244,
#  'kan': 245,
#  'berdasarkan': 246,
#  'tiga': 247,
#  'dikutip': 248,
#  'tahu': 249,
#  'menjelaskan': 250,
#  'mengalami': 251,
#  'masing': 252,
#  'usai': 253,
#  'selasa': 254,
#  'raya': 255,
#  'senin': 256,
#  'video': 257,
#  'enggak': 258,
#  'terakhir': 259,
#  'meminta': 260,
#  'lokasi': 261,
#  'rabu': 262,
#  'jelas': 263,
#  'pak': 264,
#  'laporan': 265,
#  'aku': 266,
#  'masalah': 267,
#  'begitu': 268,
#  'data': 269,
#  'mencapai': 270,
#  'negeri': 271,
#  'produk': 272,
#  'makanan': 273,
#  'hidup': 274,
#  'tanpa': 275,
#  'menteri': 276,
#  'mudah': 277,
#  'sekarang': 278,
#  'mau': 279,
#  'lama': 280,
#  'motor': 281,
#  'pasal': 282,
#  'area': 283,
#  'selalu': 284,
#  'lanjut': 285,
#  'timur': 286,
#  'benar': 287,
#  'menyebut': 288,
#  'sebab': 289,
#  'sabtu': 290,
#  'per': 291,
#  'akun': 292,
#  'jumlah': 293,
#  'diduga': 294,
#  'desa': 295,
#  'kini': 296,
#  'tiba': 297,
#  'utama': 298,
#  'politik': 299,
#  'mengaku': 300,
#  'masjid': 301,
#  'mengenai': 302,
#  'bagaimana': 303,
#  'resmi': 304,
#  'digunakan': 305,
#  'teman': 306,
#  'kementerian': 307,
#  'pusat': 308,
#  'km': 309,
#  'datang': 310,
#  'semakin': 311,
#  'wisata': 312,
#  'bekerja': 313,
#  'dirinya': 314,
#  'awal': 315,
#  'meski': 316,
#  'membantu': 317,
#  'nilai': 318,
#  'triliun': 319,
#  'kantor': 320,
#  'liga': 321,
#  'nasional': 322,
#  'ekonomi': 323,
#  'sebanyak': 324,
#  'sistem': 325,
#  'buku': 326,
#  'merasa': 327,
#  'berhasil': 328,
#  'jenis': 329,
#  'utara': 330,
#  'miliar': 331,
#  'bank': 332,
#  'demikian': 333,
#  'katanya': 334,
#  'aplikasi': 335,
#  'al': 336,
#  'akhirnya': 337,
#  'manusia': 338,
#  'tanggal': 339,
#  'allah': 340,
#  'lengkap': 341,
#  'direktur': 342,
#  'layanan': 343,
#  'polda': 344,
#  'naik': 345,
#  'keterangan': 346,
#  'petugas': 347,
#  'polri': 348,
#  'undang': 349,
#  'tentu': 350,
#  'apakah': 351,
#  'terlihat': 352,
#  'terdapat': 353,
#  'meningkatkan': 354,
#  'kecamatan': 355,
#  'kejadian': 356,
#  'makan': 357,
#  'berbeda': 358,
#  'laga': 359,
#  'pasar': 360,
#  'maret': 361,
#  'bisnis': 362,
#  'prabowo': 363,
#  'provinsi': 364,
#  'sakit': 365,
#  'ribu': 366,
#  'mampu': 367,
#  'posisi': 368,
#  'akibat': 369,
#  'bidang': 370,
#  'perjalanan': 371,
#  'tiket': 372,
#  'acara': 373,
#  'mei': 374,
#  'semoga': 375,
#  'mencari': 376,
#  'sekolah': 377,
#  'sekali': 378,
#  'sini': 379,
#  'kereta': 380,
#  'as': 381,
#  'api': 382,
#  'menyampaikan': 383,
#  'rasa': 384,
#  'kawasan': 385,
#  'menarik': 386,
#  'khusus': 387,
#  'kurang': 388,
#  'selamat': 389,
#  'dokter': 390,
#  'the': 391,
#  'menerima': 392,
#  'bentuk': 393,
#  'karya': 394,
#  'hubungan': 395,
#  'diberikan': 396,
#  'buka': 397,
#  'bandara': 398,
#  'guru': 399,
#  'jauh': 400,
#  'tersangka': 401,
#  'angka': 402,
#  'sedangkan': 403,
#  'membawa': 404,
#  'hati': 405,
#  'memastikan': 406,
#  'tujuan': 407,
#  'biasanya': 408,
#  'ditemukan': 409,
#  'diketahui': 410,
#  'perubahan': 411,
#  'sering': 412,
#  'digital': 413,
#  'keputusan': 414,
#  'teknologi': 415,
#  'jalur': 416,
#  'arus': 417,
#  'lingkungan': 418,
#  'tanah': 419,
#  'baca': 420,
#  'menit': 421,
#  'segera': 422,
#  'islam': 423,
#  'upaya': 424,
#  'disebut': 425,
#  'kecil': 426,
#  'mendapat': 427,
#  'sisi': 428,
#  'bahan': 429,
#  'akhir': 430,
#  'total': 431,
#  'wakil': 432,
#  'peristiwa': 433,
#  'arah': 434,
#  'langkah': 435,
#  'berharap': 436,
#  'satunya': 437,
#  'ri': 438,
#  'pidana': 439,
#  'cepat': 440,
#  'dulu': 441,
#  'puasa': 442,
#  'pihaknya': 443,
#  'mengungkapkan': 444,
#  'nah': 445,
#  'unit': 446,
#  'daya': 447,
#  'nya': 448,
#  'no': 449,
#  'badan': 450,
#  'mata': 451,
#  'asal': 452,
#  'biasa': 453,
#  'publik': 454,
#  'keluar': 455,
#  'suatu': 456,
#  'tadi': 457,
#  'bali': 458,
#  'kebutuhan': 459,
#  'pasti': 460,
#  'pertemuan': 461,
#  'tua': 462,
#  'belajar': 463,
#  'budaya': 464,
#  'bahasa': 465,
#  'pekerjaan': 466,
#  'mahasiswa': 467,
#  'kelompok': 468,
#  'disampaikan': 469,
#  'adapun': 470,
#  'dpr': 471,
#  'muda': 472,
#  'fasilitas': 473,
#  'inggris': 474,
#  'tni': 475,
#  'memilih': 476,
#  'muhammadiyah': 477,
#  'pemain': 478,
#  'zodiak': 479,
#  'kasih': 480,
#  'hadir': 481,
#  'transaksi': 482,
#  'pria': 483,
#  'ucap': 484,
#  'selanjutnya': 485,
#  'poin': 486,
#  'berjalan': 487,
#  'laki': 488,
#  'lewat': 489,
#  'hak': 490,
#  'momen': 491,
#  'vs': 492,
#  'sumber': 493,
#  'israel': 494,
#  'biaya': 495,
#  'pembangunan': 496,
#  'tindakan': 497,
#  'bandung': 498,
#  'lakukan': 499,
#  'menuju': 500,
#  'film': 501,
#  'agama': 502,
#  'ujarnya': 503,
#  'pantai': 504,
#  'industri': 505,
#  'ternyata': 506,
#  'tugas': 507,
#  'menunjukkan': 508,
#  'meninggal': 509,
#  'listrik': 510,
#  'pemeriksaan': 511,
#  'suku': 512,
#  'internasional': 513,
#  'mendukung': 514,
#  'siapa': 515,
#  'kesempatan': 516,
#  'terutama': 517,
#  'skor': 518,
#  'putih': 519,
#  'of': 520,
#  'alasan': 521,
#  'penumpang': 522,
#  'tingkat': 523,
#  'kapal': 524,
#  'id': 525,
#  'polres': 526,
#  'kebijakan': 527,
#  'ketiga': 528,
#  'kehidupan': 529,
#  'foto': 530,
#  'misalnya': 531,
#  'bukti': 532,
#  'tepat': 533,
#  'digelar': 534,
#  'berat': 535,
#  'panjang': 536,
#  'turut': 537,
#  'menjaga': 538,
#  'dekat': 539,
#  'seseorang': 540,
#  'mengambil': 541,
#  'tulis': 542,
#  'aksi': 543,
#  'sana': 544,
#  'maaf': 545,
#  'boleh': 546,
#  'muncul': 547,
#  'dosen': 548,
#  'lintas': 549,
#  'dugaan': 550,
#  'senilai': 551,
#  'gubernur': 552,
#  'sang': 553,
#  'proyek': 554,
#  'turun': 555,
#  'ungkap': 556,
#  'terlalu': 557,
#  'pimpinan': 558,
#  'mengetahui': 559,
#  'surabaya': 560,
#  'mengikuti': 561,
#  'jabatan': 562,
#  'sebenarnya': 563,
#  'penuh': 564,
#  'lembaga': 565,
#  'pertandingan': 566,
#  'pengguna': 567,
#  'bertemu': 568,
#  'sekaligus': 569,
#  'ruang': 570,
#  'suara': 571,
#  'empat': 572,
#  'bernama': 573,
#  'bantuan': 574,
#  'terima': 575,
#  'bila': 576,
#  'menyatakan': 577,
#  'ikut': 578,
#  'usaha': 579,
#  'bangsa': 580,
#  'pejabat': 581,
#  'tangan': 582,
#  'laut': 583,
#  'apalagi': 584,
#  'apabila': 585,
#  'pajak': 586,
#  'bakal': 587,
#  'keamanan': 588,
#  'tinggal': 589,
#  'kemarin': 590,
#  'dr': 591,
#  'instagram': 592,
#  'sumatera': 593,
#  'selesai': 594,
#  'bapak': 595,
#  'alam': 596,
#  'penyelidikan': 597,
#  'online': 598,
#  'sebagian': 599,
#  'tenaga': 600,
#  'jawaban': 601,
#  'salat': 602,
#  'kelas': 603,
#  'menurutnya': 604,
#  'pilihan': 605,
#  'keduanya': 606,
#  'luka': 607,
#  'stasiun': 608,
#  'pekan': 609,
#  'calon': 610,
#  'menu': 611,
#  'artinya': 612,
#  'memenuhi': 613,
#  'dana': 614,
#  'jasa': 615,
#  'kepolisian': 616,
#  'istri': 617,
#  'balik': 618,
#  'hotel': 619,
#  'umat': 620,
#  'kemenangan': 621,
#  'merah': 622,
#  'saling': 623,
#  'pemilu': 624,
#  'dikenal': 625,
#  'lima': 626,
#  'saksi': 627,
#  'tubuh': 628,
#  'simak': 629,
#  'menemukan': 630,
#  'siap': 631,
#  'anies': 632,
#  'luas': 633,
#  'terbaik': 634,
#  'uu': 635,
#  'buat': 636,
#  'berlangsung': 637,
#  'berupa': 638,
#  'memberi': 639,
#  'selaku': 640,
#  'metro': 641,
#  'peningkatan': 642,
#  'stadion': 643,
#  'pagi': 644,
#  'periode': 645,
#  'contoh': 646,
#  'kuat': 647,
#  'aman': 648,
#  'menjalani': 649,
#  'endar': 650,
#  'sepanjang': 651,
#  'dasar': 652,
#  'koalisi': 653,
#  'milik': 654,
#  'positif': 655,
#  'amerika': 656,
#  'ayat': 657,
#  'berlaku': 658,
#  'ii': 659,
#  'siswa': 660,
#  'tindak': 661,
#  'karier': 662,
#  'doa': 663,
#  'jaya': 664,
#  'perbedaan': 665,
#  'berasal': 666,
#  'viral': 667,
#  'aktivitas': 668,
#  'wartawan': 669,
#  'jepang': 670,
#  'membangun': 671,
#  'warna': 672,
#  'pengunjung': 673,
#  'khususnya': 674,
#  'pasangan': 675,
#  'tertentu': 676,
#  'beliau': 677,
#  'jawab': 678,
#  'pertanyaan': 679,
#  'lapangan': 680,
#  'dinas': 681,
#  'segala': 682,
#  'operasi': 683,
#  'khas': 684,
#  'paket': 685,
#  'bermain': 686,
#  'nyaman': 687,
#  'gedung': 688,
#  'rapat': 689,
#  'gol': 690,
#  'pernyataan': 691,
#  'investasi': 692,
#  'organisasi': 693,
#  'jadwal': 694,
#  'china': 695,
#  'peserta': 696,
#  'pungkasnya': 697,
#  'aturan': 698,
#  'terlebih': 699,
#  'pilih': 700,
#  'menilai': 701,
#  'mempunyai': 702,
#  'melaporkan': 703,
#  'kemungkinan': 704,
#  'padahal': 705,
#  'korupsi': 706,
#  'sejarah': 707,
#  'pdip': 708,
#  'itulah': 709,
#  'membuka': 710,
#  'rencana': 711,
#  'timnas': 712,
#  'alat': 713,
#  'hakim': 714,
#  'meskipun': 715,
#  'lagu': 716,
#  'anaknya': 717,
#  'antaranya': 718,
#  'dukungan': 719,
#  'rata': 720,
#  'wajib': 721,
#  'kampung': 722,
#  'diterima': 723,
#  'wanita': 724,
#  'taman': 725,
#  'pers': 726,
#  'bumi': 727,
#  'rakyat': 728,
#  'pulau': 729,
#  'sedikit': 730,
#  'udara': 731,
#  'kemampuan': 732,
#  'dampak': 733,
#  'menikmati': 734,
#  'pribadi': 735,
#  'meningkat': 736,
#  'david': 737,
#  'pulang': 738,
#  'terletak': 739,
#  'artikel': 740,
#  'bicara': 741,
#  'pembayaran': 742,
#  'iii': 743,
#  'lihat': 744,
#  'muslim': 745,
#  'sulit': 746,
#  'dki': 747,
#  'sepeda': 748,
#  'ahmad': 749,
#  'sidang': 750,
#  'justru': 751,
#  'menyebabkan': 752,
#  'mantan': 753,
#  'terlibat': 754,
#  'agung': 755,
#  'minyak': 756,
#  'peraturan': 757,
#  'titik': 758,
#  'penjara': 759,
#  'kinerja': 760,
#  'pekerja': 761,
#  'rest': 762,
#  'pengalaman': 763,
#  'rusia': 764,
#  'gempa': 765,
#  'city': 766,
#  'asn': 767,
#  'musim': 768,
#  'isu': 769,
#  'menegaskan': 770,
#  'berita': 771,
#  'tentunya': 772,
#  'melawan': 773,
#  'piala': 774,
#  'bola': 775,
#  'kartu': 776,
#  'senjata': 777,
#  'tutur': 778,
#  'pengadilan': 779,
#  'perkara': 780,
#  'ppp': 781,
#  'matahari': 782,
#  'kabar': 783,
#  'puncak': 784,
#  'peran': 785,
#  'rekomendasi': 786,
#  'tampak': 787,
#  'jelasnya': 788,
#  'jl': 789,
#  'beragam': 790,
#  'bangunan': 791,
#  'jenderal': 792,
#  'melaksanakan': 793,
#  'demi': 794,
#  'pula': 795,
#  'usd': 796,
#  'hampir': 797,
#  'pintu': 798,
#  'pelayanan': 799,
#  'pegawai': 800,
#  'covid': 801,
#  'mengutip': 802,
#  'belakang': 803,
#  'mendatang': 804,
#  'menang': 805,
#  'kamar': 806,
#  'terbuka': 807,
#  'lantas': 808,
#  'bumn': 809,
#  'menghadapi': 810,
#  'capres': 811,
#  'penggunaan': 812,
#  'coba': 813,
#  'berusia': 814,
#  'merdeka': 815,
#  'membeli': 816,
#  'muhammad': 817,
#  'pemilik': 818,
#  'sungai': 819,
#  'setempat': 820,
#  'dokumen': 821,
#  'gunung': 822,
#  'kalian': 823,
#  'dibandingkan': 824,
#  'cuma': 825,
#  'daftar': 826,
#  'fokus': 827,
#  'pesawat': 828,
#  'sehat': 829,
#  'komisi': 830,
#  'ikan': 831,
#  'usia': 832,
#  'kenaikan': 833,
#  'minta': 834,
#  'hukuman': 835,
#  'terbaru': 836,
#  'pemudik': 837,
#  'gerindra': 838,
#  'syarat': 839,
#  'terdiri': 840,
#  'menambahkan': 841,
#  'saham': 842,
#  'akbp': 843,
#  'ibadah': 844,
#  'indah': 845,
#  'pelabuhan': 846,
#  'budi': 847,
#  'tokoh': 848,
#  'serangan': 849,
#  'ditangkap': 850,
#  'minuman': 851,
#  'potensi': 852,
#  'bus': 853,
#  'menyediakan': 854,
#  'produksi': 855,
#  'arab': 856,
#  'perkembangan': 857,
#  'model': 858,
#  'faktor': 859,
#  'universitas': 860,
#  'buruh': 861,
#  'dianggap': 862,
#  'keras': 863,
#  'berangkat': 864,
#  'akses': 865,
#  'nantinya': 866,
#  'menggelar': 867,
#  'kualitas': 868,
#  'ayam': 869,
#  'dini': 870,
#  'ali': 871,
#  'serikat': 872,
#  'asia': 873,
#  'kaki': 874,
#  'united': 875,
#  'kecelakaan': 876,
#  'bagus': 877,
#  'dibawa': 878,
#  'lapas': 879,
#  'situasi': 880,
#  'halaman': 881,
#  'pemuda': 882,
#  'yogyakarta': 883,
#  'komunikasi': 884,
#  'berusaha': 885,
#  'ma': 886,
#  'izin': 887,
#  'kombes': 888,
#  'mencoba': 889,
#  'perdagangan': 890,
#  'lahir': 891,
#  'pontianak': 892,
#  'libur': 893,
#  'raja': 894,
#  'alias': 895,
#  'penyakit': 896,
#  'konflik': 897,
#  'tarif': 898,
#  'tewas': 899,
#  'berarti': 900,
#  'tantangan': 901,
#  'supaya': 902,
#  'sebagaimana': 903,
#  'ilmu': 904,
#  'penjelasan': 905,
#  'pemimpin': 906,
#  'cocok': 907,
#  'kredit': 908,
#  'tersedia': 909,
#  'ahli': 910,
#  'and': 911,
#  'terbesar': 912,
#  'aktif': 913,
#  'februari': 914,
#  'penganiayaan': 915,
#  'pelanggaran': 916,
#  'sudan': 917,
#  'kuartal': 918,
#  'dibuat': 919,
#  'up': 920,
#  'putra': 921,
#  'dahulu': 922,
#  'situs': 923,
#  'pendapatan': 924,
#  'mati': 925,
#  'restoran': 926,
#  'sektor': 927,
#  'mahfud': 928,
#  'nggak': 929,
#  'bebas': 930,
#  'asmara': 931,
#  'konsumen': 932,
#  'permintaan': 933,
#  'batu': 934,
#  'pranowo': 935,
#  'ancaman': 936,
#  'kenapa': 937,
#  'sulawesi': 938,
#  'papua': 939,
#  'mendorong': 940,
#  'mengurangi': 941,
#  'sambil': 942,
#  'perhatian': 943,
#  'dewan': 944,
#  'pemerintahan': 945,
#  'sosok': 946,
#  'sehari': 947,
#  'status': 948,
#  'saudi': 949,
#  'jemaah': 950,
#  'ucapan': 951,
#  'diharapkan': 952,
#  'zakat': 953,
#  'melanjutkan': 954,
#  'tanda': 955,
#  'one': 956,
#  'lokal': 957,
#  'membutuhkan': 958,
#  'penyebab': 959,
#  'penjualan': 960,
#  'wni': 961,
#  'manajemen': 962,
#  'grup': 963,
#  'hitam': 964,
#  'ketum': 965,
#  'laman': 966,
#  'maksimal': 967,
#  'sambungnya': 968,
#  'ramai': 969,
#  'bupati': 970,
#  'olahraga': 971,
#  'bersih': 972,
#  'si': 973,
#  'ramalan': 974,
#  'generasi': 975,
#  'pesan': 976,
#  'maju': 977,
#  'korea': 978,
#  'beredar': 979,
#  'com': 980,
#  'meraih': 981,
#  'sikap': 982,
#  'pakaian': 983,
#  'klik': 984,
#  'fifa': 985,
#  'target': 986,
#  'ungkapnya': 987,
#  'pengembangan': 988,
#  'bogor': 989,
#  'sri': 990,
#  'melibatkan': 991,
#  'tambahan': 992,
#  'semangat': 993,
#  'memahami': 994,
#  'menambah': 995,
#  'saudara': 996,
#  'membahas': 997,
#  'cerita': 998,
#  'to': 999,
#  ...}
