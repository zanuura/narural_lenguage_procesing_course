# %%
import nltk
import os
import pickle
import warnings
import wget
from nlp_id.tokenizer import Tokenizer
from nltk.tree import Tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Hammam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenizer = Tokenizer()

# %%
dataset_path = './dataset_postag.txt'

# %%
def read_dataset(dataset_path=None, encoding='utf-8'):
    with open(dataset_path, 'r', encoding=encoding) as f:
        raw_file = f.read().split("\n")

    files = [i.split("\t") for i in raw_file]

    sentences, tags, temp_sentences, temp_tags = [], [], [], []

    for file in files:
        if file != [""]:
            temp_sentences.append(file[0])  # get the sentences
            temp_tags.append(file[1])  # get the tag
        else:
            # check if the temp sentences and temp tags are not empty
            # and both of them have the same length
            if len(temp_sentences) > 0 and (
                len(temp_sentences) == len(temp_tags)
            ):
                sentences.append(temp_sentences)
                tags.append(temp_tags)
            temp_sentences, temp_tags = [], []
    return sentences, tags

# %%
read_dataset(dataset_path, encoding='iso=8859-1')
# Out:
# ([['Ditjen',
#    'Bea',
#    'dan',
#    'Cukai',
#    'Kementerian',
#    'Keuangan',
#    '(',
#    'Kemenkeu',
#    ')',
#    'memastikan',
#    'ada',
#    'nya',
#    '18',
#    'kotak',
#    'selundupan',
#    'yang',
#    'dibawa',
#    'melalui',
#    'pesawat',
#    'baru',
#    'Airbus',
#    'A330-900',
#    'Neo',
#    'milik',
#    'Garuda',
#    'Indonesia',
#    '.'],
#   ['Pengambilan',
#    'foto',
#    'dilakukan',
#    'dari',
#    'kepala',
#    'perahu',
#    'sehingga',
#    'menghasilkan',
#    'foto',
#    'yang',
#    'sangat',
#    'menarik',
#    '.'],
#   ['Vice',
#    'President',
#    'Corporate',
#    'Secretary',
#    'Garuda',
#    'Indonesia',
#    ',',
#    'M',
#    '.'],
#   ['Di',
#    'sana',
#    ',',
#    'penumpang',
#    'mengungkapkan',
#    'atau',
#    'men-declare',
#    'barang',
#    'bawaan',
#    ',',
#    'termasuk',
#    'yang',
#    'disebut',
#    'sparepart',
#    'Harley',
#    'dan',
#    'sepeda',
#    'Brompton',
#    '.'],
#   ['Kita', '(', 'penumpang', ')', 'self', 'declare', '.'],
#   ['Untuk',
#    'clean',
#    'and',
#    'jerk',
#    ',',
#    'sosok',
#    'berusia',
#    '21',
#    'tahun',
#    'ini',
#    'menorehkan',
#    '107',
#    'kg',
#    '.'],
#   ['Direktur',
#    'Utama',
#    'Perum',
#    'Bulog',
#    'Budi',
#    'Waseso',
#    'sudah',
#    'mulai',
#    'ancang-ancang',
#    'memperbaiki',
#    'kinerja',
#    'perusahaan',
#    '.'],
#   ['Menurut',
#    'polisi',
#    'setempat',
#    ',',
#    'kecelakaan',
#    'ini',
#    'terjadi',
#    'karena',
#    'konstruksi',
#    'bangunan',
#    'yang',
#    'tidak',
#    'dibuat',
#    'dengan',
#    'baik',
#    '.'],
#   ['Tidak',
#    'hanya',
#    'Tokopedia',
#    ',',
#    'sang',
#    'desainer',
#    ',',
#    'Ria',
#    'Miranda',
#    'sebagai',
#    'penyelenggara',
#    'acara',
#    'resmi',
#    'juga',
#    'akhirnya',
#    'menyampaikan',
#    'pernyataan',
#    'permintaan',
#    'maaf',
#    'kepada',
#    'seluruh',
#    'pihak',
#    'yang',
#    'mendukung',
#    'acara',
#    'nya',
#    'ini',
#    '.'],
#   ['The',
#    'Reds',
#    'sendiri',
#    'butuh',
#    'kemenangan',
#    'untuk',
#    'menjaga',
#    'jarak',
#    'dengan',
#    'Leicester',
#    'City',
#    '.'],
#   ['Saat', 'ini', 'Arsenal', 'sedang', 'limbung', '.'],
#   ['Claudia',
#    'mengatakan',
#    ',',
#    'pendidikan',
#    'usia',
#    'dini',
#    'dinilai',
#    'ampuh',
#    'menanamkan',
#    'nilai',
#    'positif',
#    'kepada',
#    'anak',
#    '.'],
#   ['Serangan', 'menewaskan', 'dua', 'orang', '.'],
#   ['Sebab',
#    ',',
#    'pada',
#    'ajang',
#    'Asian',
#    'Games',
#    '2018',
#    'silam',
#    ',',
#    'Puspa',
#    'juga',
#    'berhasil',
#    'membukukan',
#    'medali',
#    'emas',
#    '.'],
#   ['Sebelum',
#    'menabrak',
#    'korban',
#    'yang',
#    'mengendarai',
#    'motor',
#    ',',
#    'sopir',
#    'bus',
#    'bernama',
#    'Arif',
#    'Himawan',
#    'Suryadi',
#    '(',
#    '32',
#    ')',
#    'sebenarnya',
#    'sudah',
#    'melihat',
#    'lampu',
#    'lalu',
#    'lintas',
#    'menyala',
#    'merah',
#    '.'],
#   ['Garis',
#    'polisi',
#    'pun',
#    'sudah',
#    'dicopot',
#    'dari',
#    'Tempat',
#    'Kejadian',
#    'Perkara',
#    '.'],
#   ['Buah',
#    'yang',
#    'daging',
#    'nya',
#    'berwarna',
#    'hijau',
#    'dan',
#    'kuning',
#    'ini',
#    ',',
#    'hampir',
#    '90',
#    'persen',
#    'nya',
#    'mengandung',
#    'air',
#    ',',
#    'sehingga',
#    'mudah',
#    'dicerna',
#    'oleh',
#    'si',
#    'kecil',
#    '.'],
#   ['ungkap', 'dia', '.'],
#   ['Sehingga',
#    'tercipta',
#    'citra',
#    'diri',
#    'sosok',
#    'yang',
#    'bisa',
#    'diandalkan',
#    '.'],
#   ['Bagaimana', 'dengan', 'dua', 'tim', 'lain', 'nya', '?'],
#   ['"',
#    'Karena',
#    'itu',
#    ',',
#    'permen',
#    '(',
#    'peraturan',
#    'menteri',
#    ')',
#    'ini',
#    'harus',
#    'dikeluarkan',
#    '.'],
#   ['Setidaknya',
#    '21',
#    'orang',
#    'tewas',
#    'dalam',
#    'bentrokan',
#    'tersebut',
#    '.'],
#   ['Ada', 'beragam', 'jenis', 'Yakitori', 'yang', 'bisa', 'kamu', 'coba', '.'],
#   ['Hasil', 'nya', 'apik', '.'],
#   ['Lalu', 'kenapa', 'dia', 'bisa', 'naik', '?'],
#   ['Pertanyaan',
#    'nya',
#    'kemudian',
#    'bagaimana',
#    'soal',
#    'konsumsi',
#    'BBM-nya',
#    ',',
#    'apa',
#    'kah',
#    'bakal',
#    'lebih',
#    'boros',
#    'dari',
#    'sebelumnya',
#    '?'],
#   ['kata',
#    'Farah',
#    'Quinn',
#    'saat',
#    'ditemui',
#    'baru-baru',
#    'ini',
#    'di',
#    'kawasan',
#    'Jalan',
#    'MH',
#    'Thamrin',
#    ',',
#    'Jakarta',
#    'Pusat',
#    '.'],
#   ['Di',
#    'sisi',
#    'lain',
#    ',',
#    'perusahaan',
#    'bisa',
#    'kapan',
#    'saja',
#    'memecat',
#    'si',
#    'pilot',
#    'tanpa',
#    'terbebani',
#    'kewajiban',
#    'apa',
#    'pun',
#    'seperti',
#    'membayar',
#    'uang',
#    'pesangon',
#    '.'],
#   ['Para',
#    'pilot',
#    'itu',
#    ',',
#    'ujar',
#    'Guru',
#    'Besar',
#    'Hukum',
#    'Perburuhan',
#    'dan',
#    'mantan',
#    'Ketua',
#    'Umum',
#    'Asosiasi',
#    'Arbiter',
#    'Ketenagakerjaan',
#    'Indonesia',
#    'itu',
#    ',',
#    'seharusnya',
#    'diangkat',
#    'pegawai',
#    'tetap',
#    'dan',
#    'mendapat',
#    'pesangon',
#    'jika',
#    'mengalami',
#    'PHK',
#    'dari',
#    'perusahaan',
#    '.'],
#   ['sejak',
#    'kecil',
#    'Meier',
#    'mengaku',
#    'telah',
#    'dihubungi',
#    'oleh',
#    'makhluk',
#    'luar',
#    'angkasa',
#    ',',
#    'dan',
#    'hubungan',
#    'di',
#    'antara',
#    'kedua',
#    'nya',
#    'berlanjut',
#    'hingga',
#    'Meier',
#    'dewasa',
#    '.'],
#   ['di',
#    'acara',
#    'televisi',
#    'The',
#    'X-Files',
#    ',',
#    'dan',
#    'dipajang',
#    'di',
#    'kantor',
#    'agen',
#    'khusus',
#    'FBI',
#    'Fox',
#    'Mulder',
#    '.'],
#   ['Angke',
#    ',',
#    'Kecamatan',
#    'Tambora',
#    ',',
#    'Kota',
#    'Jakarta',
#    'Barat',
#    ',',
#    'Daerah',
#    'Khusus',
#    'Ibukota',
#    'Jakarta',
#    '11330',
#    'No',
#    '.'],
#   ['RT', '.'],
#   ['9/RW', '.'],
#   ['8/RW', '.'],
#   ['9', ','],
#   ['6-9', ','],
#   ['RT', '.'],
#   ['SDS', 'Kalam', 'Kudus', 'Alamat', ':', 'Jl', '.'],
#   ['page_id=433', '55', '.'],
#   ['6', ','],
#   ['ujar', 'Asrul', '.'],
#   ['Anak',
#    'ketiga',
#    'Ratu',
#    'Elizabeth',
#    'II',
#    'tersebut',
#    'dikaitkan',
#    'dengan',
#    'pelaku',
#    'pidana',
#    'perdagangan',
#    'seks',
#    'anak',
#    ',',
#    'Jeffrey',
#    'Epstein',
#    '.'],
#   ['"',
#    'Perenang',
#    'dari',
#    'Singapura',
#    'dan',
#    'Vietnam',
#    'memang',
#    'sudah',
#    'menjadi',
#    'rival',
#    'abadi',
#    '.'],
#   ['tutur', 'Siman', '.'],
#   ['Kendati',
#    'bentuk',
#    'nya',
#    'tidak',
#    'mirip',
#    'dengan',
#    'benteng',
#    'catur',
#    'modern',
#    'yang',
#    'ada',
#    'saat',
#    'ini',
#    ',',
#    'namun',
#    'benda',
#    'yang',
#    'ditemukan',
#    'Oleson',
#    'diyakini',
#    'mirip',
#    'dengan',
#    'bentuk',
#    'benteng',
#    'catur',
#    'kuno',
#    'di',
#    'awal',
#    'kemunculan',
#    'permainan',
#    'tersebut',
#    '.'],
#   ['Sedangkan',
#    ',',
#    'di',
#    'tahun',
#    'ini',
#    'Gilbert',
#    'mengungkapkan',
#    'akan',
#    'ada',
#    'lebih',
#    'banyak',
#    'hadiah',
#    'dan',
#    'memberikan',
#    'peluang',
#    'yang',
#    'lebih',
#    'besar',
#    'untuk',
#    'menang',
#    '.'],
#   ['Gatot',
#    'menjelaskan',
#    ',',
#    'tidak',
#    'ada',
#    'pengamanan',
#    'khusus',
#    'meski',
#    'kejadian',
#    'berada',
#    'di',
#    'ring',
#    '1',
#    'atau',
#    'dekat',
#    'Istana',
#    'Kepresidenan',
#    '.'],
#   ['Kegunaan',
#    'nya',
#    'dianggap',
#    'sebagai',
#    'persinyalan',
#    'dan',
#    'perlindungan',
#    '.'],
#   ['Dua',
#    'wacana',
#    'ini',
#    'awalnya',
#    'dilontarkan',
#    'oleh',
#    'dua',
#    'parpol',
#    'pendukung',
#    'Jokowi',
#    ',',
#    'NasDem',
#    'dan',
#    'PKB',
#    '.'],
#   ['Persentase',
#    'field',
#    'goal',
#    'sukses',
#    'mereka',
#    'mencapai',
#    'angka',
#    '55',
#    ',',
#    '8%',
#    '.',
#    'Begitu',
#    'juga',
#    'persentase',
#    'tiga',
#    'angka',
#    'sukses',
#    'mereka',
#    'yang',
#    'berada',
#    'di',
#    'angka',
#    '45',
#    ',',
#    '7%',
#    '.',
#    'Di',
#    'satu',
#    'sisi',
#    ',',
#    'Bucks',
#    'berhasil',
#    'membuat',
#    'Knicks',
#    "'",
#    'hanya',
#    "'",
#    'mampu',
#    'mencatatkan',
#    'persentase',
#    'field',
#    'goal',
#    'sukses',
#    'di',
#    'angka',
#    '30',
#    ',',
#    '8%',
#    '.',
#    'Antetokounmpo',
#    'tentu',
#    'menjadi',
#    'metronom',
#    'Bucks',
#    'di',
#    'laga',
#    'ini',
#    '.'],
#   ['"',
#    'Itu',
#    '(',
#    'BPNT',
#    ')',
#    'pada',
#    'akhirnya',
#    'enggak',
#    'menggunakan',
#    'beras',
#    'nya',
#    'Bulog',
#    'karena',
#    'masyarakat',
#    'dibolehkan',
#    'memilih',
#    'beras',
#    'beli',
#    'di',
#    'pasar',
#    ',',
#    'bebas',
#    '.'],
#   ['Sehingga', 'kejadian', 'itu', 'tidak', 'berulang', '.'],
#   ['Dalam',
#    'persidangan',
#    'tersebut',
#    ',',
#    'para',
#    'pengurus',
#    'Golkar',
#    'akan',
#    'menentukan',
#    'tata',
#    'tertib',
#    'munas',
#    ',',
#    'pemilihan',
#    'pimpinan',
#    'sidang',
#    'munas',
#    ',',
#    'hingga',
#    'mekanisme',
#    'pemilihan',
#    'ketum',
#    '.'],
#   ['kata',
#    'Sekjen',
#    'PDIP',
#    'Hasto',
#    'Kristiyanto',
#    ',',
#    'dalam',
#    'keterangan',
#    'nya',
#    ',',
#    'Selasa',
#    '(',
#    '3/12',
#    ')',
#    '.',
#    'Sikap',
#    'PDIP',
#    'tetap',
#    'mendorong',
#    'amandemen',
#    'UUD',
#    '1945',
#    'itu',
#    'berbeda',
#    'dengan',
#    'Jokowi',
#    'yang',
#    'menyatakan',
#    'tidak',
#    'perlu',
#    'amandemen',
#    '.'],
#   ["'", 'menelanjangi'],
#   ['Smartwatch',
#    'terbaru',
#    'ini',
#    'dilansir',
#    'Samsung',
#    'di',
#    'Indonesia',
#    'pada',
#    'September',
#    '2019',
#    'lalu',
#    ',',
#    'berselang',
#    'enam',
#    'bulan',
#    'dari',
#    'generasi',
#    'pertama',
#    'nya',
#    '.'],
#   ['Selain',
#    'itu',
#    ',',
#    'jam',
#    'ini',
#    'juga',
#    'bisa',
#    'Anda',
#    'gunakan',
#    'untuk',
#    'membantu',
#    'memonitor',
#    'kesehatan',
#    ',',
#    'dengan',
#    'fitur',
#    'ECG',
#    '(',
#    'electrocardiogram',
#    ')',
#    'yang',
#    'bisa',
#    'mengecek',
#    'ritme',
#    'dan',
#    'aktivitas',
#    'jantung',
#    'pengguna',
#    'nya',
#    '.'],
#   ['Sangat', 'cepat', 'dan', 'menegangkan', '.'],
#   ['Pemandangan', 'nya', 'keren', 'banget', '!'],
#   ['Ketakutan',
#    'akan',
#    'ketinggian',
#    'berganti',
#    'dengan',
#    'kegembiraan',
#    'yang',
#    'tidak',
#    'terkira',
#    '.'],
#   ['Bila',
#    'itu',
#    'terjadi',
#    ',',
#    'Anda',
#    'bisa',
#    'menawarkan',
#    'sesuatu',
#    'hal',
#    'lain',
#    'agar',
#    'balita',
#    'Anda',
#    'mau',
#    'beranjak',
#    'dari',
#    'sana',
#    'atau',
#    'bisa',
#    'berjanji',
#    'lagi',
#    'untuk',
#    'kembali',
#    'ke',
#    'sana',
#    'bila',
#    'ada',
#    'waktu',
#    '.'],
#   ['Dengan',
#    'Lead',
#    'Acid',
#    'Baterai',
#    'bertenaga',
#    '72V20AH',
#    'dan',
#    'motor',
#    'penggerak',
#    '2000',
#    'Watt',
#    ',',
#    'motor',
#    'ini',
#    'dapat',
#    'menempuh',
#    'jarak',
#    '60',
#    'kilometer',
#    'sekali',
#    'diisi',
#    'penuh',
#    '.'],
#   ['}'],
#   ['Berdasarkan',
#    'keterangan',
#    'resmi',
#    'yang',
#    'terimai',
#    'kumparan',
#    'dari',
#    'Kementerian',
#    'Pariwisata',
#    'edan',
#    'Ekonomi',
#    'Kreatif',
#    'pada',
#    'belum',
#    'lama',
#    'ini',
#    ',',
#    'untuk',
#    'mengelilingi',
#    'lokasi',
#    'wisata',
#    'pulau',
#    'di',
#    'Belitung',
#    ',',
#    'kamu',
#    'harus',
#    'menyewa',
#    'kapal',
#    'wisata',
#    'yang',
#    'khusus',
#    'diperuntukkan',
#    'untuk',
#    'itu',
#    '.'],
#   ['Adapun',
#    'penumpang',
#    'pembawa',
#    'komponen',
#    'motor',
#    'Harley',
#    'Davidson',
#    'bekas',
#    'itu',
#    'inisiali',
#    'SAW',
#    ',',
#    'sementara',
#    'pembawa',
#    'unit',
#    'Brompton',
#    'merupakan',
#    'penumpang',
#    'inisiali',
#    'LS',
#    '.'],
#   ['Adapun',
#    'penumpang',
#    'pembawa',
#    'komponen',
#    'motor',
#    'Harley',
#    'Davidson',
#    'bekas',
#    'itu',
#    'berinisial',
#    'SAW',
#    ',',
#    'sementara',
#    'pembawa',
#    'unit',
#    'Brompton',
#    'rupai',
#    'penumpang',
#    'berinisial',
#    'LS',
#    '.'],
#   ['Ketika',
#    'mengunjungi',
#    'pura',
#    'tersebut',
#    ',',
#    'Lorenzo',
#    'akui',
#    'bisa',
#    'mengenal',
#    'lebih',
#    'jauh',
#    'tentang',
#    'pulau',
#    'Bali',
#    'yang',
#    'indah',
#    'ini',
#    'dengan',
#    'kekayaan',
#    'budaya',
#    'dan',
#    'tradisi',
#    'yang',
#    'dimiliki',
#    'nya',
#    '.'],
#   ['"',
#    'Ya',
#    '(',
#    'ada',
#    'ledakan',
#    ')',
#    '.',
#    'Semua',
#    'sedang',
#    'lakui',
#    'penyelidikan',
#    '.'],
#   ['Desainer',
#    'modest',
#    'fashion',
#    'Ria',
#    'Miranda',
#    'baru',
#    'saja',
#    'menggelar',
#    'fashion',
#    'show',
#    'yang',
#    'hadiri',
#    'serangkaian',
#    'koleksi',
#    'terbaru',
#    'pada',
#    '28-29',
#    'November',
#    'di',
#    'The',
#    'Hall',
#    'Senayan',
#    'City',
#    ',',
#    'Jakarta',
#    'Selatan',
#    '.'],
#   ['Ia',
#    'juga',
#    'nyatai',
#    'bahwa',
#    'kehadiran',
#    'Tokopedia',
#    'beserta',
#    'pihak',
#    'sponsor',
#    'lain',
#    'nya',
#    'dalam',
#    'RiaMiranda',
#    'Annual',
#    'Show',
#    'adalah',
#    'sebagai',
#    'sponsor',
#    'dan',
#    'business',
#    'partner',
#    'yang',
#    'memberikan',
#    'dukungan',
#    ',',
#    'serta',
#    'rekan',
#    'yang',
#    'juga',
#    'melakukan',
#    'kerja',
#    'sama',
#    'dalam',
#    'industri',
#    'fashion',
#    '.'],
#   ['Lewat',
#    'butik',
#    'ini',
#    ',',
#    'pengunjung',
#    'bisa',
#    'mendapatkan',
#    'beragam',
#    'pengalaman',
#    'kecantikan',
#    ',',
#    'mulai',
#    'dari',
#    'belajar',
#    'cara',
#    'pemakaian',
#    'produk',
#    ',',
#    'mencoba',
#    'produk-produk',
#    'terbaru',
#    ',',
#    'hingga',
#    'nikmati',
#    'layanan',
#    'butik',
#    'khas',
#    'Lancome',
#    '.'],
#   ['Seperti',
#    'hasil',
#    'karya',
#    'para',
#    'penyandang',
#    'disabilitas',
#    'di',
#    'arena',
#    'pameran',
#    'ini',
#    'menurut',
#    'nya',
#    'perlu',
#    'hubungi',
#    'dengan',
#    'pasar',
#    'lebih',
#    'luas',
#    '.'],
#   ['Saya', 'kira', 'ini', 'perlu', 'wujudi', ',', '"'],
#   ['Pada',
#    'kesempatan',
#    'itu',
#    ',',
#    'Grace',
#    'hadir',
#    'juga',
#    'dalam',
#    'kapasitas',
#    'nya',
#    'wakili',
#    'Organisasi',
#    'Aksi',
#    'Solidaritas',
#    'Era',
#    '-',
#    'Kabinet',
#    'Indonesia',
#    'Maju',
#    '(',
#    'OASE',
#    '-',
#    'KIM',
#    ')',
#    'Bidang',
#    'Sosial',
#    '.'],
#   ['Grace',
#    'hadir',
#    'tampak',
#    'tinjaui',
#    'sejumlah',
#    'booth',
#    'dan',
#    'berdialog',
#    'dengan',
#    'peserta',
#    'pameran',
#    '.'],
#   ['Laga',
#    'babak',
#    'ketiga',
#    'Piala',
#    'FA',
#    'ini',
#    'akan',
#    'gelari',
#    'pada',
#    '3',
#    's',
#    '/',
#    'd',
#    '6',
#    'Januari',
#    '2020',
#    'mendatang',
#    '.'],
#   ['Sebelum',
#    'tabraki',
#    'korban',
#    'yang',
#    'mengendarai',
#    'motor',
#    ',',
#    'sopir',
#    'bus',
#    'bernama',
#    'Arif',
#    'Himawan',
#    'Suryadi',
#    '(',
#    '32',
#    ')',
#    'sebenarnya',
#    'sudah',
#    'melihat',
#    'lampu',
#    'lalu',
#    'lintas',
#    'menyala',
#    'merah',
#    '.'],
#   ['"',
#    'Hasil',
#    'dari',
#    'pemeriksaan',
#    'kami',
#    'di-BAP',
#    ',',
#    'si',
#    'sopir',
#    'sudah',
#    'akui',
#    'bahwasanya',
#    'sudah',
#    'melihat',
#    'lampu',
#    'merah',
#    '.'],
#   ['Saat',
#    'itu',
#    ',',
#    'Bambang',
#    'yang',
#    'masih',
#    'kerjai',
#    'di',
#    'Kantor',
#    'Pusat',
#    'PT',
#    'Pertamina',
#    'bertemu',
#    'dengan',
#    'perwakilan',
#    'Kernel',
#    'Oil',
#    '.'],
#   ['Pengadaan',
#    'saat',
#    'itu',
#    'adakani',
#    'untuk',
#    'kebutuhan',
#    'PT',
#    'Pertamina',
#    '(',
#    'Persero',
#    ')',
#    'yang',
#    'dapat',
#    'diikuti',
#    'oleh',
#    'National',
#    'Oil',
#    'Company',
#    ',',
#    'Major',
#    'Oil',
#    'Company',
#    ',',
#    'Refinery',
#    ',',
#    'maupun',
#    'trader',
#    '.'],
#   ['Untuk',
#    'meneruskan',
#    'pembahasan',
#    'kaiti',
#    'pengadaan',
#    'tersebut',
#    ',',
#    'perwakilan',
#    'Kernel',
#    'Oil',
#    'beberapa',
#    'kali',
#    'diundang',
#    'dan',
#    'menjadi',
#    'rekanan',
#    'PES',
#    'dalam',
#    'kegiatan',
#    'impor',
#    'dan',
#    'ekspor',
#    'minyak',
#    'mentah',
#    'untuk',
#    'kepentingan',
#    'PES',
#    '.'],
#   ['Bambang',
#    'selaku',
#    'VP',
#    'Marketing',
#    'PES',
#    'dugai',
#    'membantu',
#    'mengamankan',
#    'jatah',
#    'alokasi',
#    'kargo',
#    'Kernel',
#    'Oil',
#    'dalam',
#    'tender',
#    'pengadaan',
#    'atau',
#    'penjualan',
#    'minyak',
#    'mentah',
#    'atau',
#    'produk',
#    'kilang',
#    '.'],
#   ['Bercerita',
#    'tentang',
#    '6',
#    'orang',
#    'yang',
#    'membentuk',
#    'tim',
#    'setelah',
#    'memalsukan',
#    'kematian',
#    'mereka',
#    ',',
#    'untuk',
#    'jatuhi',
#    'penjahat',
#    'terkenal',
#    '.'],
#   ['Melanjutkan',
#    'tradisi',
#    'dari',
#    'tahun',
#    'ke',
#    'tahun',
#    ',',
#    'Google',
#    'ungkapi',
#    'daftar',
#    'aplikasi',
#    'dan',
#    'game',
#    'terbaik',
#    'yang',
#    'berhasil',
#    'pencuri',
#    'perhatian',
#    'pengguna',
#    'smartphone',
#    'Android',
#    'selama',
#    'setahun',
#    'penuh',
#    '.'],
#   ['lengkapi',
#    'pemenang',
#    'aplikasi',
#    'terbaik',
#    ',',
#    'Google',
#    'juga',
#    'membuat',
#    'daftar',
#    'aplikasi-aplikasi',
#    'pilihan',
#    'berdasarkan',
#    'kegunaan',
#    'dan',
#    'keunikan',
#    '.'],
#   ['Buah',
#    'yang',
#    'daging',
#    'nya',
#    'warnai',
#    'hijau',
#    'dan',
#    'kuning',
#    'ini',
#    ',',
#    'hampir',
#    '90',
#    'persen',
#    'nya',
#    'mengandung',
#    'air',
#    ',',
#    'sehingga',
#    'mudah',
#    'dicerna',
#    'oleh',
#    'si',
#    'kecil',
#    '.'],
#   ['Selain',
#    'ubahan',
#    'pada',
#    'kosmetika',
#    ',',
#    'jenama',
#    'Jepang',
#    'itu',
#    'turun',
#    'tambahi',
#    'sejumlah',
#    'fitur',
#    'baru',
#    'agar',
#    'all',
#    'new',
#    'Yamaha',
#    'NMax',
#    'kompetitif',
#    'di',
#    'pasar',
#    '.'],
#   ['"',
#    'Sekarang',
#    'NMax',
#    'masuki',
#    'babak',
#    'baru',
#    'untuk',
#    'konsumen',
#    'di',
#    'Indonesia',
#    '.'],
#   ['ABS',
#    '(',
#    'Anti-lock',
#    'Braking',
#    'System',
#    ')',
#    '2-Channel',
#    'Yamaha',
#    'Nmax',
#    'yang',
#    'akan',
#    'dijual',
#    'pada',
#    '2020',
#    'ini',
#    'dihadirkan',
#    'dalam',
#    'dua',
#    'varian',
#    'bedai',
#    ',',
#    'yakni',
#    'Connected',
#    'ABS',
#    'dan',
#    'non',
#    'ABS',
#    '(',
#    'versi',
#    'standar',
#    ')',
#    '.',
#    'Kita',
#    'bahas',
#    'yang',
#    'versi',
#    'ABS-nya',
#    '.'],
#   ['Tim',
#    'itu',
#    'anggotai',
#    '65',
#    'orang',
#    'di',
#    'mana',
#    '53',
#    'orang',
#    'berasal',
#    'dari',
#    'Polri',
#    '.'],
#   ['Coba',
#    'lah',
#    'pilihi',
#    'knitwear',
#    'berwarna',
#    'cerah',
#    ',',
#    'seperti',
#    'kuning',
#    'mustard',
#    'milik',
#    'H',
#    '&',
#    'M',
#    'ini',
#    '.'],
#   ['Dalam',
#    'foto',
#    'yang',
#    'edari',
#    ',',
#    'terlihat',
#    'ada',
#    'korban',
#    'luka-luka',
#    '.'],
#   ['Semua',
#    'orang',
#    'dalam',
#    'sebuah',
#    'perusahaan',
#    'saling',
#    'butuhi',
#    'dan',
#    'bekerja',
#    'sama',
#    'untuk',
#    'mencapai',
#    'dan',
#    'melampaui',
#    'tujuan',
#    'yang',
#    'telah',
#    'ditetapkan',
#    '.'],
#   ['Edho',
#    'Zell',
#    'dan',
#    'Ammar',
#    'Zoni',
#    'dari',
#    '#DubaiTeamINDO',
#    'sempati',
#    'untuk',
#    'menaiki',
#    'unta',
#    'di',
#    'tengah',
#    'padang',
#    'pasir',
#    '.'],
#   ['Selain',
#    'hapusi',
#    'rencana',
#    'Super',
#    'Holding',
#    'BUMN',
#    ',',
#    'dalam',
#    'rapat',
#    'kerja',
#    'perdana',
#    'dengan',
#    'Komisi',
#    'VI',
#    'DPR',
#    'RI',
#    'kemarin',
#    ',',
#    'Erick',
#    'juga',
#    'bakal',
#    'hapusi',
#    'anak',
#    'usaha',
#    'yang',
#    'tumpang',
#    'tindih',
#    'satu',
#    'sama',
#    'lain',
#    '.'],
#   ['Kantor',
#    'wali',
#    'kota',
#    'dipenuhi',
#    'lubang-lubang',
#    'bekas',
#    'terjangi',
#    'peluru',
#    '.'],
#   ['Namun',
#    'sebelumnya',
#    'dalam',
#    'dakwaan',
#    'pemilik',
#    'PT',
#    'Enra',
#    'Sari',
#    ',',
#    'Robi',
#    'Okta',
#    'Fahlefi',
#    ',',
#    'selaku',
#    'penyuap',
#    'Ahmad',
#    'Yani',
#    ',',
#    'disebut',
#    '22',
#    'anggota',
#    'DPRD',
#    'Muara',
#    'Enim',
#    'terimai',
#    'aliran',
#    'suap',
#    '.'],
#   ['Seorang',
#    'ibu',
#    'di',
#    'Makassar',
#    ',',
#    'Samina',
#    '(',
#    '42',
#    ')',
#    ',',
#    'tega',
#    'paksai',
#    'anak',
#    'nya',
#    'yang',
#    'masih',
#    'berusia',
#    '9',
#    'tahun',
#    'mengemis',
#    'di',
#    'sekitar',
#    'Mall',
#    'Panakkukang',
#    '.'],
#   ['"',
#    'Akhirnya',
#    'korban',
#    'temui',
#    'di',
#    'rumah',
#    'tersebut',
#    'bersama',
#    'ibu',
#    'nya',
#    ',',
#    '"'],
#   ['Satu',
#    'yang',
#    'tidak',
#    'boleh',
#    'lewati',
#    'adalah',
#    'mencoba',
#    'kelezatan',
#    'kuliner',
#    'khas',
#    'nya',
#    '.'],
#   ['Makan',
#    'banyak',
#    'tentu',
#    'boleh',
#    ',',
#    'apalagi',
#    'kamu',
#    'sedang',
#    'liburan',
#    'ke',
#    'tempat',
#    'yang',
#    'jarang',
#    'kamu',
#    'kunjungi',
#    ',',
#    'pasti',
#    'penasaran',
#    'ingin',
#    'cobai',
#    ',',
#    'bukan',
#    '?'],
#   ['Sebelumnya',
#    ',',
#    'kedua',
#    'atlet',
#    'ini',
#    'sudah',
#    'pernah',
#    'temui',
#    'dalam',
#    'babak',
#    'final',
#    'Thailand',
#    'Masters',
#    '2019',
#    'silam',
#    '.'],
#   ['Namun',
#    ',',
#    'Farah',
#    'akui',
#    'tidak',
#    'menyimpan',
#    'sendiri',
#    'koleksi',
#    'perhiasan',
#    'nya',
#    'di',
#    'rumah',
#    ',',
#    'melainkan',
#    'menyimpan',
#    'di',
#    'bank',
#    '.'],
#   ['Hakim',
#    'akan',
#    'menentukan',
#    'kontrak',
#    'pilot',
#    'Lion',
#    'menjadi',
#    'PKWTT',
#    ',',
#    'memaksa',
#    'agar',
#    'itu',
#    'harus',
#    'dilakukan',
#    ',',
#    'harus',
#    'patuhi',
#    '.'],
#   ['Pelanggaran',
#    'terkait',
#    'status',
#    'pekerja',
#    'kontrak',
#    'dan',
#    'pekerja',
#    'tetap',
#    'terus',
#    'ulangi',
#    '.'],
#   ['Sementara',
#    'itu',
#    ',',
#    'di',
#    'sisi',
#    'kanan',
#    'dan',
#    'kiri',
#    ',',
#    'lihati',
#    'proyek',
#    'trotoar',
#    'yang',
#    'masih',
#    'belum',
#    'rampung',
#    '.'],
#   ['Nah',
#    ',',
#    'kita',
#    'sudah',
#    'antisipasi',
#    'untuk',
#    'itu',
#    'ya',
#    'sehingga',
#    'beberapa',
#    'arus',
#    'kita',
#    'alihi',
#    ',',
#    '"'],
#   ['Benda',
#    'tersebut',
#    'miliki',
#    'bentuk',
#    'persegi',
#    'panjang',
#    'dengan',
#    'dua',
#    'tonjolan',
#    'di',
#    'bagian',
#    'atas',
#    'yang',
#    'menyerupai',
#    'tanduk',
#    '.'],
#   ['Karena',
#    'selain',
#    'upgrade',
#    'kelas',
#    'tiket',
#    'pesawat',
#    ',',
#    'wisatawan',
#    'yang',
#    'beruntung',
#    'juga',
#    'bisa',
#    'berkesempatan',
#    'menangi',
#    'tiket',
#    'menginap',
#    'semalam',
#    'di',
#    'suite',
#    'hotel',
#    ',',
#    'tiket',
#    'untuk',
#    'makan',
#    'malam',
#    'di',
#    'restoran',
#    'mewah',
#    ',',
#    'hingga',
#    'hadiah',
#    'menarik',
#    'lain',
#    'nya',
#    '.'],
#   ['maini',
#    'game',
#    'umum',
#    'nya',
#    'menjadi',
#    'kegiatan',
#    'untuk',
#    'mengisi',
#    'waktu',
#    'luang',
#    '.'],
#   ['Meski',
#    'olah',
#    'TKP',
#    'sudah',
#    'selesai',
#    ',',
#    'polisi',
#    'masih',
#    'lakui',
#    'pengecekan',
#    'di',
#    'sejumlah',
#    'titik',
#    'ditemukan',
#    'darah',
#    'yang',
#    'berasal',
#    'dari',
#    'korban',
#    '.'],
#   ['Meski',
#    'olah',
#    'TKP',
#    'sudah',
#    'selesai',
#    ',',
#    'polisi',
#    'masih',
#    'melakukan',
#    'pengecekan',
#    'di',
#    'sejumlah',
#    'titik',
#    'temui',
#    'darah',
#    'yang',
#    'berasal',
#    'dari',
#    'korban',
#    '.'],
#   ['Ledakan',
#    'ini',
#    'sebabi',
#    'dua',
#    'korban',
#    'anggota',
#    'TNI',
#    'terluka',
#    ',',
#    'yakni',
#    'Serda',
#    'Fajar',
#    'dan',
#    'Praka',
#    'Gunawan',
#    '.'],
#   ['Selain',
#    'delapan',
#    'emas',
#    ',',
#    'Indonesia',
#    'juga',
#    'telah',
#    'kumpuli',
#    '12',
#    'perak',
#    'dan',
#    '12',
#    'perunggu',
#    '.'],
#   ['Persentase',
#    'field',
#    'goal',
#    'sukses',
#    'mereka',
#    'mencapai',
#    'angka',
#    '55',
#    ',',
#    '8%',
#    '.',
#    'Begitu',
#    'juga',
#    'persentase',
#    'tiga',
#    'angka',
#    'sukses',
#    'mereka',
#    'yang',
#    'berada',
#    'di',
#    'angka',
#    '45',
#    ',',
#    '7%',
#    '.',
#    'Di',
#    'satu',
#    'sisi',
#    ',',
#    'Bucks',
#    'berhasil',
#    'membuat',
#    'Knicks',
#    "'",
#    'hanya',
#    "'",
#    'mampu',
#    'catati',
#    'persentase',
#    'field',
#    'goal',
#    'sukses',
#    'di',
#    'angka',
#    '30',
#    ',',
#    '8%',
#    '.',
#    'Antetokounmpo',
#    'tentu',
#    'menjadi',
#    'metronom',
#    'Bucks',
#    'di',
#    'laga',
#    'ini',
#    '.'],
#   ['Anggota',
#    'Komisi',
#    'I',
#    'DPR',
#    'itu',
#    'menjelaskan',
#    ',',
#    'pada',
#    'hari',
#    'kedua',
#    'atau',
#    'Rabu',
#    ',',
#    '4',
#    'Desember',
#    ',',
#    'peserta',
#    'Munas',
#    'akan',
#    'gelari',
#    'sidang',
#    'Komisi',
#    'yang',
#    'membahas',
#    'arah',
#    'Partai',
#    'Golkar',
#    'selama',
#    'lima',
#    'tahun',
#    'ke',
#    'depan',
#    '.'],
#   ['Menanggapi',
#    'hal',
#    'itu',
#    ',',
#    'Wakil',
#    'Ketua',
#    'MPR',
#    'Fraksi',
#    'Demokrat',
#    'Syarief',
#    'Hasan',
#    'tegasi',
#    'sependapat',
#    'dengan',
#    'Jokowi',
#    '.'],
#   ['"',
#    'Yang',
#    'kedua',
#    'ingin',
#    'cari',
#    'muka',
#    ',',
#    'padahal',
#    'saya',
#    'sudah',
#    'punya',
#    'muka',
#    ',',
#    'yang',
#    'ketiga',
#    'ingin',
#    'jerumusi',
#    ',',
#    '"'],
#   ['Sebab',
#    ',',
#    'menurut',
#    'nya',
#    ',',
#    'saat',
#    'ini',
#    'tak',
#    'ada',
#    'urgensi',
#    'nya',
#    'laksanai',
#    'wacana',
#    'tersebut',
#    'dan',
#    'poin-poin',
#    'amandemen',
#    'yang',
#    'diusulkan',
#    'sudah',
#    'semakin',
#    'melebar',
#    '.'],
#   ['Adi',
#    'menuturkan',
#    'tidak',
#    'perlu',
#    'lah',
#    'membuka',
#    'siapa',
#    'pihak',
#    'yang',
#    'usahai',
#    'ingin',
#    'menjerumuskan',
#    'nya',
#    'dengan',
#    'wacana',
#    'amandemen',
#    'UUD',
#    '1945',
#    '.'],
#   ['Adi',
#    'menuturkan',
#    'tidak',
#    'perlu',
#    'lah',
#    'membuka',
#    'siapa',
#    'pihak',
#    'yang',
#    'berusaha',
#    'ingin',
#    'jerumusi',
#    'dengan',
#    'wacana',
#    'amandemen',
#    'UUD',
#    '1945',
#    '.'],
#   ['sebut',
#    'saja',
#    'Sekjen',
#    'PPP',
#    'Arsul',
#    'Sani',
#    '-',
#    '-',
#    'sebagai',
#    'pihak',
#    'yang',
#    'pertama',
#    'kali',
#    'mengungkapkan',
#    'wacana',
#    'tersebut',
#    ',',
#    'meski',
#    'ia',
#    'mengklaim',
#    'pihak',
#    'nya',
#    'belum',
#    'memikirkan',
#    'usulan',
#    'mengubah',
#    'masa',
#    'jabatan',
#    'presiden',
#    '-',
#    '-',
#    ',',
#    'Adi',
#    'menilai',
#    'Jokowi',
#    'harus',
#    'tetap',
#    'sikapi',
#    'tegas',
#    '.'],
#   ['Untuk',
#    'memenuhi',
#    'keinginan',
#    'pengguna',
#    'yang',
#    'selalu',
#    'ingin',
#    'ikut',
#    'tren',
#    ',',
#    'Galaxy',
#    'Watch',
#    'Active',
#    '2',
#    'menawarkan',
#    'beberapa',
#    'warna',
#    'strap',
#    'yang',
#    'dapat',
#    'dibeli',
#    'secara',
#    'terpisah',
#    'dan',
#    'memiliki',
#    'warna',
#    'agami',
#    '.'],
#   ['Mata',
#    'uang',
#    'Paman',
#    'Sam',
#    'tersebut',
#    'bukai',
#    'di',
#    'level',
#    'Rp',
#    '14.100',
#    '.'],
#   ['Buwas',
#    ',',
#    'sapaan',
#    'akrab',
#    'Budi',
#    'Waseso',
#    ',',
#    'katai',
#    'akan',
#    'memanfaatkan',
#    'beras',
#    'tersebut',
#    'seperti',
#    'untuk',
#    'konsumsi',
#    'baik',
#    'untuk',
#    'manusia',
#    'atau',
#    'hewan',
#    '.'],
#   ['Meski',
#    'begitu',
#    ',',
#    'Kim',
#    'So',
#    'Hyun',
#    'mengatakan',
#    ',',
#    'ia',
#    'merasa',
#    'tidak',
#    'canggung',
#    'saat',
#    'lakui',
#    'adegan',
#    'ciuman',
#    ',',
#    'lantaran',
#    'sutradara',
#    'dan',
#    'Jang',
#    'Dong',
#    'Yoon',
#    'sendiri',
#    'membuat',
#    'nya',
#    'merasa',
#    'tidak',
#    'terbebani',
#    '.'],
#   ['Karakter',
#    'nya',
#    'gambari',
#    'sebagai',
#    'seorang',
#    'murid',
#    'gisaeng',
#    'di',
#    'sebuah',
#    'desa',
#    'janda',
#    '.'],
#   ['Menatap',
#    'lantai',
#    'lift',
#    'yang',
#    'transparan',
#    'di',
#    'mal',
#    ',',
#    'mengintip',
#    'lantai',
#    'bawah',
#    'mal',
#    'dari',
#    'tepi',
#    'balkon',
#    'toko',
#    ',',
#    'atau',
#    'sekadar',
#    'berjalan',
#    'lewati',
#    'jembatan',
#    'penyeberangan',
#    'saja',
#    'bisa',
#    'jadi',
#    'menyulitkan',
#    '.'],
#   ['Melewati',
#    'lembah',
#    'kecokelatan',
#    'dan',
#    'juga',
#    'pepohonan',
#    'pinus',
#    'yang',
#    'sempat',
#    'bakari',
#    'dua',
#    'tahun',
#    'lalu',
#    '.'],
#   ['Meski',
#    'masih',
#    'tak',
#    'berani',
#    'menatap',
#    'ke',
#    'bawah',
#    'dan',
#    'takut',
#    'untuk',
#    'bergerak',
#    ',',
#    'perasaan',
#    'kagum',
#    'akan',
#    'keindahan',
#    'Selandia',
#    'Baru',
#    'rasai',
#    'semakin',
#    'menjadi',
#    '.'],
#   ['Sementara',
#    'itu',
#    ',',
#    'pada',
#    'Senin',
#    'sore',
#    ',',
#    'sang',
#    'sopir',
#    'Innova',
#    'yang',
#    'tak',
#    'sebuti',
#    'nama',
#    'nya',
#    'itu',
#    'tengah',
#    'melaju',
#    'cukup',
#    'kencang',
#    'di',
#    'Jalan',
#    'Sentul',
#    'dan',
#    'tak',
#    'menyadari',
#    'ada',
#    'truk',
#    'terparkir',
#    '.'],
#   ['Ma',
#    "'",
#    'ruf',
#    'juga',
#    'sebuti',
#    'situasi',
#    'di',
#    'Monas',
#    'sudah',
#    'aman',
#    'dan',
#    'berangsur',
#    'kondusif',
#    '.'],
#   ['Nah',
#    ',',
#    'jika',
#    'banguni',
#    'dan',
#    'melakukan',
#    'produksi',
#    'di',
#    'pabrik',
#    'sendiri',
#    ',',
#    'menurut',
#    'nya',
#    'tak',
#    'akan',
#    'berdampak',
#    'signifikan',
#    '.'],
#   ['Jumat',
#    '(',
#    '30/11',
#    ')',
#    '.',
#    'Dian',
#    'pun',
#    'mengaku',
#    'BF',
#    'CG',
#    'rupai',
#    'motor',
#    'modifikasi',
#    'yang',
#    'komponen-komponen',
#    'nya',
#    'diambil',
#    'dari',
#    'motor',
#    'lawas',
#    ',',
#    'terutama',
#    'motor',
#    'Honda',
#    '.'],
#   ['terlihat',
#    'hampir',
#    'mirip',
#    'dengan',
#    'motor',
#    'klasik',
#    'konvensional',
#    'bahani',
#    'bakar',
#    'bensin',
#    ',',
#    'apalagi',
#    'cover',
#    'baterai',
#    'yang',
#    'berbentuk',
#    'blok',
#    'mesin',
#    '.'],
#   ['Pemilik',
#    'Simbah',
#    'Sticker',
#    ',',
#    'Agus',
#    'Maksum',
#    ',',
#    'mengungkapkan',
#    'perbedaan',
#    'dari',
#    'kedua',
#    'jenis',
#    'stiker',
#    'ini',
#    'salah',
#    'salah',
#    'satu',
#    'nya',
#    'terletak',
#    'pada',
#    'proses',
#    'pencetakan',
#    'nya',
#    '.'],
#   ['Selanjutnya',
#    'untuk',
#    'mengonfirmasi',
#    'pelanggaran',
#    ',',
#    'pemilik',
#    'kendaraan',
#    'bisa',
#    'melakukan',
#    'nya',
#    'melalui',
#    'etle-pmj',
#    '.'],
#   ['Tampang',
#    'nya',
#    'didukung',
#    'dengan',
#    'kaca',
#    'depan',
#    'yang',
#    'lebar',
#    'agar',
#    'pengemudi',
#    'lebih',
#    'leluasa',
#    'melihat',
#    'medan',
#    '.'],
#   ['Karena',
#    'ini',
#    'juga',
#    'akan',
#    'berpengaruh',
#    'pada',
#    'handling',
#    'kendaraan',
#    '.'],
#   ['Meluncur', 'perdana', 'di', 'Indonesia', 'pada', 'tahun', '1980', ','],
#   ['Ya',
#    ',',
#    'Toyota',
#    'kala',
#    'itu',
#    'menyematkan',
#    'teknologi',
#    'camshaft',
#    'ganda',
#    'atau',
#    'yang',
#    'lebih',
#    'dikenal',
#    'dengan',
#    'TwinCam',
#    '.'],
#   ['Seperti', 'sistem', 'pengereman', 'ABS', 'dan', 'Dual', 'Airbags', '.'],
#   ['Tidak',
#    'hanya',
#    'dibekali',
#    'dengan',
#    'teknologi',
#    'hybrid',
#    'saja',
#    ',',
#    'Toyota',
#    'juga',
#    'turut',
#    'menyematkan',
#    'paket',
#    'fitur',
#    'keselamatan',
#    'Toyota',
#    'Safety',
#    'Sense',
#    'di',
#    'Corolla',
#    'Altis',
#    'terbaru',
#    'ini',
#    '.'],
#   ['Biasanya',
#    'hal',
#    'ini',
#    'terjadi',
#    'pada',
#    'kondisi',
#    'kendaraan',
#    'yang',
#    'jarang',
#    'dipakai',
#    'hingga',
#    'berhari-hari',
#    'bahkan',
#    'berminggu-minggu',
#    '.'],
#   ['Radiator',
#    'punya',
#    'fungsi',
#    'menjaga',
#    'suhu',
#    'mesin',
#    'agar',
#    'tetap',
#    'dalam',
#    'kondisi',
#    'ideal',
#    ',',
#    'dan',
#    'tak',
#    'kepanasan',
#    '.'],
#   ['Setelahnya',
#    'penggantian',
#    'air',
#    'radiator',
#    'disarankan',
#    'tiap',
#    '80',
#    'ribu',
#    'kilometer',
#    '.'],
#   ['Setelah',
#    'melakukan',
#    'soft',
#    'launching',
#    'diler',
#    'Kia',
#    'pertama',
#    'di',
#    'kawasan',
#    'MT',
#    'Haryono',
#    ',',
#    'Jakarta',
#    'Timur',
#    'pada',
#    '31',
#    'Oktober',
#    '2019',
#    ','],
#   ['"'],
#   ['Produk',
#    'tersebut',
#    'hadir',
#    'dengan',
#    'mesin',
#    'bensin',
#    'baru',
#    ',',
#    '3',
#    'silinder',
#    'berkapasitas',
#    '1.0',
#    'liter',
#    'i-Vtec',
#    'dan',
#    'ditunjang',
#    'dengan',
#    'turbocharger',
#    '.'],
#   ['Kemungkinan',
#    'terbuka',
#    'lebar',
#    ',',
#    'mengingat',
#    'Indonesia',
#    'adalah',
#    'pasar',
#    'tergemuk',
#    'ketiga',
#    'di',
#    'dunia',
#    ',',
#    'dengan',
#    'total',
#    'penjualan',
#    'motor',
#    ',',
#    'rata-rata',
#    'enam',
#    'juta',
#    'unit',
#    'per',
#    'tahun',
#    'nya',
#    '.'],
#   ['"',
#    'Jadi',
#    'awalnya',
#    'karena',
#    'beberapa',
#    'kali',
#    'saya',
#    'menemukan',
#    'mobil',
#    'balap',
#    'itu',
#    'ngejogrok',
#    'di',
#    'kampakan',
#    'atau',
#    'bengkel',
#    ',',
#    'bahkan',
#    'ada',
#    'yang',
#    'sudah',
#    'sampai',
#    'keropos',
#    '.'],
#   ['Terkadang',
#    'akan',
#    'juga',
#    'helm',
#    'yang',
#    'dijual',
#    'tidak',
#    'sesuai',
#    'dengan',
#    'standar',
#    'SNI',
#    'yang',
#    'ditetapkan',
#    'pemerintah',
#    '.'],
#   ['Lantas',
#    ',',
#    'bagaimana',
#    'memilih',
#    'model',
#    'helm',
#    'yang',
#    'tepat',
#    '?'],
#   ['ujar', 'Jusri', '.'],
#   ['Malah',
#    'parah',
#    'nya',
#    'lagi',
#    'bisa',
#    'menyebabkan',
#    'klep',
#    'dan',
#    'piston',
#    'bertabrakan',
#    '.'],
#   ['"',
#    'Melihat',
#    'dari',
#    'jumlah',
#    'waktu',
#    'yang',
#    'kami',
#    'informasikan',
#    ',',
#    'Juli',
#    'sampai',
#    'Agustus',
#    'lalu',
#    'ini',
#    'cukup',
#    'cepat',
#    'dibandingkan',
#    'recall',
#    'lain',
#    '.'],
#   ['Mitsubishi',
#    'Xpander',
#    'Cross',
#    'yang',
#    'meluncur',
#    'pada',
#    'Selasa',
#    ',',
#    '(',
#    '12/11',
#    ')',
#    'terbagi',
#    'atas',
#    'tiga',
#    'pilihan',
#    '.'],
#   ['Jadi',
#    'dia',
#    'akan',
#    'mengatur',
#    'tekanan',
#    'di',
#    'masing-masing',
#    'suspensi',
#    '.'],
#   ['Tidak',
#    'hanya',
#    'dashboard',
#    '-',
#    'nya',
#    'saja',
#    ',',
#    'jok',
#    'dari',
#    'X1',
#    'kini',
#    'juga',
#    'hadir',
#    'dengan',
#    'bahan',
#    'kulit',
#    'baru',
#    'yang',
#    'diklaim',
#    'jauh',
#    'lebih',
#    'nyaman',
#    '.'],
#   ['Terdapat',
#    'juga',
#    'panoramic',
#    'sunroof',
#    'yang',
#    'akan',
#    'menambah',
#    'kesan',
#    'lapang',
#    'di',
#    'bagian',
#    'dalam',
#    '.'],
#   ['Tren',
#    'mobil',
#    'bergaya',
#    'crossover',
#    'diprediksi',
#    'akan',
#    'semakin',
#    'nge-tren',
#    'di',
#    '2020',
#    'mendatang',
#    '.'],
#   ['Sehingga',
#    ',',
#    'kini',
#    'Yaris',
#    'Cross',
#    'memiliki',
#    'ground',
#    'clearance',
#    'hingga',
#    '190',
#    'mm',
#    '.'],
#   ['PT',
#    'Astra',
#    'Honda',
#    'Motor',
#    '(',
#    'AHM',
#    ')',
#    'menyerap',
#    'paling',
#    'besar',
#    'di',
#    'penjualan',
#    'berelasi',
#    ',',
#    'dengan',
#    'kontribusi',
#    '22,57',
#    'persen',
#    'dari',
#    'total',
#    'pendapatan',
#    ',',
#    'yang',
#    'nilai',
#    'nya',
#    'sampai',
#    'Rp',
#    '2,62',
#    'triliun',
#    'atau',
#    'naik',
#    '7,8',
#    'persen',
#    '.'],
#   ['1', '.'],
#   ['Namun',
#    'di',
#    'Indonesia',
#    ',',
#    'konsumen',
#    'memang',
#    'lebih',
#    'mengenal',
#    'istilah',
#    'Delta',
#    'Box',
#    '.'],
#   ['"'],
#   ['Sehingga',
#    ',',
#    'menjadi',
#    'bukti',
#    'keberhasilan',
#    'negara',
#    'dalam',
#    'meningkatkan',
#    'SDM',
#    'dengan',
#    'sejumlah',
#    'perkembangan',
#    'nya',
#    '.'],
#   ['Dan',
#    'kalau',
#    'bicara',
#    'ekonomi',
#    ',',
#    'sampai',
#    '30',
#    'billion',
#    'dollar',
#    ',',
#    '"'],
#   ['Hanya',
#    'sektor',
#    'utilitas',
#    ',',
#    'real',
#    'estat',
#    ',',
#    'dan',
#    'energi',
#    'yang',
#    'mengalami',
#    'kenaikan',
#    '.'],
#   ['Laporan', 'dari', 'Target', 'Corp', '(', 'TGT', '.'],
#   ['Untuk',
#    'saat',
#    'ini',
#    'bisa',
#    'kami',
#    'informasikan',
#    'bahwa',
#    'emas',
#    'yang',
#    'dipercayakan',
#    'jumlah',
#    'nya',
#    '60',
#    'ton',
#    '.'],
#   ['Emas',
#    'memang',
#    'masih',
#    'digemari',
#    'hingga',
#    'saat',
#    'ini',
#    ',',
#    'bahkan',
#    'di',
#    'saat',
#    'ekonomi',
#    'global',
#    'dihantui',
#    'ketidakpastian',
#    '.'],
#   ['Misalnya',
#    'untuk',
#    'emas',
#    'Antam',
#    '10',
#    'gram',
#    'saja',
#    'per',
#    'toko',
#    'beda-beda',
#    'harga',
#    'nya',
#    ',',
#    'tergantung',
#    'mereka',
#    'beli',
#    '.'],
#   ['Sayangnya',
#    ',',
#    'pada',
#    'peluncuran',
#    'pertama',
#    'ini',
#    ',',
#    'konsumen',
#    'belum',
#    'bisa',
#    'membeli',
#    'nya',
#    'secara',
#    'fisik',
#    'dengan',
#    'datang',
#    'ke',
#    'toko',
#    '.'],
#   ['"', 'Saya', 'antar', 'Pak', 'Prabowo', '.'],
#   ['Pak', 'Prabowo', 'dipanggil', 'ke', 'dalam', ',', 'saya', 'juga', '.'],
#   ['tambah', 'nya', '.'],
#   ['2024',
#    'berharap',
#    'PDB',
#    'per',
#    'kapita',
#    'nya',
#    'sudah',
#    'pada',
#    'USD',
#    '5.780-6.160',
#    '.'],
#   ['Menteri',
#    'ESDM',
#    'Arifin',
#    'Tasrif',
#    'mengaku',
#    'sudah',
#    'mengantongi',
#    'nama-nama',
#    'perusahaan',
#    'yang',
#    'jadi',
#    'target',
#    'investigasi',
#    ',',
#    'karena',
#    'diduga',
#    'melanggar',
#    'kuota',
#    'ekspor',
#    'nikel',
#    '.'],
#   ['Dia',
#    'juga',
#    'belum',
#    'mau',
#    'menyebutkan',
#    'apa',
#    'saja',
#    'sanksi',
#    'yang',
#    'bakal',
#    'dijatuhkan',
#    'kepada',
#    'para',
#    'penambang',
#    'nakal',
#    '.'],
#   ['Veri',
#    'menyebut',
#    'proses',
#    'penerbitan',
#    'pun',
#    'menjadi',
#    'lebih',
#    'singkat',
#    'menjadi',
#    'paling',
#    'lama',
#    'tiga',
#    'hari',
#    'serta',
#    'mencegah',
#    'gratifikasi',
#    'karena',
#    'proses',
#    'nya',
#    'sudah',
#    'online',
#    '.'],
#   ['Pantauan',
#    'kumparan',
#    ',',
#    'berdasarkan',
#    'papan',
#    'jadwal',
#    'penerbangan',
#    'di',
#    'Terminal',
#    '2',
#    'Bandara',
#    'Soetta',
#    'pada',
#    'pukul',
#    '12.45',
#    'WIB',
#    ',',
#    'tiga',
#    'penerbangan',
#    'Sriwijaya',
#    'Air',
#    'yang',
#    'terlambat',
#    'tujuan',
#    'Lampung',
#    'yang',
#    'seharusnya',
#    'berangkat',
#    'pukul',
#    '07.15',
#    'WIB',
#    ',',
#    'baru',
#    'bisa',
#    'berangkat',
#    'pukul',
#    '13.50',
#    'WIB',
#    '.'],
#   ['Ari',
#    'dipecat',
#    'dari',
#    'jabatan',
#    'nya',
#    'karena',
#    'kasus',
#    'selundupan',
#    'tersebut',
#    '.'],
#   ['"', 'Yang', 'paling', 'sering', 'modus', 'nya', 'splitting', '.'],
#   ['Adapun',
#    '15',
#    'tas',
#    'mewah',
#    'itu',
#    'terdiri',
#    'dari',
#    'empat',
#    'buah',
#    'bermerek',
#    'Hermes',
#    ',',
#    'empat',
#    'buah',
#    'tas',
#    'Chanel',
#    ',',
#    'empat',
#    'buah',
#    'tas',
#    'Louis',
#    'Vuitton',
#    ',',
#    'dua',
#    'buah',
#    'tas',
#    'Dior',
#    ',',
#    'sebuah',
#    'tas',
#    'Bvlgari',
#    ',',
#    'serta',
#    'jam',
#    'tangan',
#    ',',
#    'anting',
#    ',',
#    'hingga',
#    'cincin',
#    '.'],
#   ['Ia',
#    'memastikan',
#    'pihak',
#    'nya',
#    'ingin',
#    'mengembangkan',
#    'dunia',
#    'pasar',
#    'modal',
#    'syariah',
#    '.'],
#   ['ujar',
#    'Sulaiman',
#    'di',
#    'Ruang',
#    'Rapat',
#    'Komisi',
#    'XI',
#    'DPR',
#    'RI',
#    ',',
#    'Jakarta',
#    ',',
#    'Selasa',
#    '(',
#    '26/11',
#    ')',
#    '.',
#    'Namun',
#    'demikian',
#    ',',
#    'Sulaiman',
#    'menuturkan',
#    ',',
#    'Bank',
#    'Mandiri',
#    'tentu',
#    'telah',
#    'menyiapkan',
#    'sejumlah',
#    'upaya',
#    'pemulihan',
#    'agar',
#    'kondisi',
#    'itu',
#    'tak',
#    'terjadi',
#    '.'],
#   ['Kalau',
#    'internal',
#    'dari',
#    'jumlah',
#    'hanggar-hanggar',
#    'slot',
#    'kita',
#    'belum',
#    'cukup',
#    'hanggar',
#    'slot',
#    'di',
#    'Indonesia',
#    'ini',
#    'masih',
#    'sangat',
#    'kurang',
#    ',',
#    '"'],
#   ['"',
#    'Kami',
#    'juga',
#    'akan',
#    'terus',
#    'berupaya',
#    'mengoptimalkan',
#    'jangkauan',
#    'ke',
#    'seluruh',
#    'lapisan',
#    'masyarakat',
#    'untuk',
#    'memberikan',
#    'layanan',
#    'keuangan',
#    'yang',
#    'aman',
#    ',',
#    'mudah',
#    'dan',
#    'nyaman',
#    ',',
#    '"'],
#   ['Juru',
#    'Bicara',
#    'OJK',
#    ',',
#    'Sekar',
#    'Putih',
#    'Djarot',
#    'menegaskan',
#    ',',
#    'pihak',
#    'nya',
#    'tak',
#    'pernah',
#    'melontarkan',
#    'pengakuan',
#    'itu',
#    '.'],
#   ['"'],
#   ['Mulai',
#    'dari',
#    'KRL',
#    'Jabodetabek',
#    ',',
#    'Gojek',
#    ',',
#    'kereta',
#    'api',
#    'antar-kota',
#    ',',
#    'bus',
#    'Damri',
#    ',',
#    'taksi',
#    'Bluebird',
#    ',',
#    'Railink',
#    ',',
#    'Garuda',
#    '/',
#    'Citilink',
#    ',',
#    'dan',
#    'berbagai',
#    'transportasi',
#    'lokal',
#    'seperti',
#    'Trans',
#    'Lampung',
#    'dan',
#    'Trans',
#    'Semarang',
#    '.'],
#   ['Jumlah',
#    'nya',
#    'merchant',
#    'yang',
#    'telah',
#    'bekerja',
#    'sama',
#    ',',
#    'mencapai',
#    '250',
#    'ribu',
#    '.'],
#   ['Anhar',
#    'Adel',
#    'Ia',
#    'merupakan',
#    'Komisaris',
#    'Utama',
#    'merangkap',
#    'Komisaris',
#    'Independen',
#    'PT',
#    'Djakarta',
#    'Lloyd',
#    '.'],
#   ['Menurut',
#    'dia',
#    ',',
#    'akan',
#    'ada',
#    'sejumlah',
#    'rumah',
#    'sakit',
#    'yang',
#    'dibangun',
#    'dengan',
#    'pembiayaan',
#    'dari',
#    'IIF',
#    'pada',
#    '2020',
#    '.'],
#   ['Kemudian',
#    ',',
#    'segera',
#    'akan',
#    'dilaksanakan',
#    'penerbitan',
#    'dan',
#    'penyerahan',
#    'Polis',
#    'Asuransi',
#    'BMN',
#    'oleh',
#    'pihak',
#    'konsorsium',
#    'asuransi',
#    'BMN',
#    '.'],
#   ['Padahal',
#    ',',
#    'seharusnya',
#    'UMP',
#    '2020',
#    'harus',
#    'diserahkan',
#    'setidaknya',
#    'tanggal',
#    '1',
#    'November',
#    '2019',
#    '.'],
#   ['Lebih',
#    'lanjut',
#    ',',
#    'Haiyani',
#    'menjelaskan',
#    'sejauh',
#    'ini',
#    'belum',
#    'ada',
#    'provinsi',
#    'yang',
#    'dianggap',
#    'tidak',
#    'sesuai',
#    'dalam',
#    'menentukan',
#    'UMP',
#    '2020',
#    '.'],
#   ['"',
#    'Upah',
#    'para',
#    'pekerja',
#    'di',
#    'sini',
#    '(',
#    'Vietnam',
#    ')',
#    'relatif',
#    'lebih',
#    'murah',
#    'dibanding',
#    'di',
#    'negara',
#    'lain',
#    'nya',
#    '(',
#    'Indonesia',
#    ')',
#    '.',
#    'Selisih',
#    'nya',
#    'sekitar',
#    '73',
#    'persen',
#    '(',
#    'per',
#    'tahun',
#    ')',
#    ',',
#    '"'],
#   ['Hanya',
#    'saja',
#    'dari',
#    'sisi',
#    'produktivitas',
#    ',',
#    'Berdasarkan',
#    'catatan',
#    'Himki',
#    ',',
#    'para',
#    'pekerja',
#    'di',
#    'Vietnam',
#    'menghabiskan',
#    'waktu',
#    'lebih',
#    'lama',
#    'atau',
#    '48',
#    'jam',
#    'per',
#    'minggu',
#    '.'],
#   ['ungkap', 'Buwas', '.'],
#   ['"'],
#   ['Dengan',
#    'ada',
#    'nya',
#    'perubahan',
#    'ini',
#    ',',
#    'maka',
#    'komposisi',
#    'direksi',
#    'Bukalapak',
#    'terbaru',
#    'adalah',
#    'Rachmat',
#    'Kaimuddin',
#    'sebagai',
#    'CEO',
#    ',',
#    'Fajrin',
#    'Rasyid',
#    'sebagai',
#    'Presiden',
#    'dan',
#    'Co-Founder',
#    ',',
#    'Nugroho',
#    'Herucahyono',
#    'sebagai',
#    'Chief',
#    'Technical',
#    'Officer',
#    '(',
#    'CTO',
#    ')',
#    ',',
#    'Willix',
#    'Halim',
#    'sebagai',
#    'Chief',
#    'Operating',
#    'Officer',
#    'dan',
#    'Co-Founder',
#    ',',
#    'Natalia',
#    'Firmansyah',
#    'sebagai',
#    'Chief',
#    'Financial',
#    'Officer',
#    ',',
#    'Teddy',
#    'Oetomo',
#    'sebagai',
#    'Chief',
#    'Strategy',
#    'Officer',
#    ',',
#    'dan',
#    'Bagus',
#    'Harimawan',
#    'sebagai',
#    'Chief',
#    'of',
#    'Talent',
#    '.'],
#   ['Kemudian',
#    ',',
#    'belum',
#    'diketahui',
#    'pasti',
#    'apa',
#    'kah',
#    'kedua',
#    'nya',
#    'akan',
#    'meluncur',
#    'secara',
#    'bersamaan',
#    'dan',
#    'berapa',
#    'harga',
#    'yang',
#    'akan',
#    'dijual',
#    'di',
#    'Indonesia',
#    '.'],
#   ['Fakta',
#    'ini',
#    'akhirnya',
#    'menjawab',
#    'rasa',
#    'penasaran',
#    'An',
#    'Nguyen',
#    ',',
#    'ahli',
#    'biologi',
#    'dari',
#    'Global',
#    'Wildlife',
#    'Conservation',
#    ',',
#    'yang',
#    'mempertanyakan',
#    'apa',
#    'kah',
#    'chevrotain',
#    'selama',
#    'ini',
#    'telah',
#    'bersembunyi',
#    'di',
#    'suatu',
#    'tempat',
#    'demi',
#    'bertahan',
#    'hidup',
#    '.'],
#   ['Dari',
#    'hasil',
#    'riset',
#    'ini',
#    'pula',
#    'Syrda',
#    'mencatat',
#    'bahwa',
#    'tekanan',
#    'psikologis',
#    'tidak',
#    'akan',
#    'dirasakan',
#    'para',
#    'lelaki',
#    'meskipun',
#    'pendapatan',
#    'pasangan',
#    'mereka',
#    'lebih',
#    'tinggi',
#    '.'],
#   ['Dr', '.'],
#   ['Dalam',
#    'trailer',
#    'itu',
#    ',',
#    'kita',
#    'bisa',
#    'melihat',
#    'cuplikan',
#    'dari',
#    'Residen',
#    'Evil',
#    '2',
#    'Remake',
#    ',',
#    'tapi',
#    'kemudian',
#    'waktu',
#    'berputar',
#    'kembali',
#    'ke',
#    '24',
#    'jam',
#    'lalu',
#    'di',
#    'mana',
#    'menjadi',
#    'latar',
#    'waktu',
#    'Resident',
#    'Evil',
#    '3',
#    '.'],
#   ['"', 'Ini', 'perlu', 'diambil', 'sebelum', 'membusuk', ',', '"'],
#   ['Selain',
#    'itu',
#    ',',
#    'tidak',
#    'seperti',
#    'hepatitis',
#    'B',
#    'dan',
#    'C',
#    ',',
#    'HAV',
#    'jarang',
#    'berujung',
#    'pada',
#    'kerusakan',
#    'hati',
#    'akut',
#    'atau',
#    'penyakit',
#    'kronis',
#    '.'],
#   ['diperkirakan',
#    'ada',
#    '71',
#    'juta',
#    'orang',
#    'di',
#    'seluruh',
#    'dunia',
#    'yang',
#    'menderita',
#    'infeksi',
#    'hepatitis',
#    'C',
#    'kronis',
#    '.'],
#   ['Dalam',
#    'pidato',
#    'nya',
#    'tersebut',
#    ',',
#    'keluar',
#    'pula',
#    'nama',
#    'aktor',
#    'Hollywood',
#    'sekaligus',
#    'aktivis',
#    'lingkungan',
#    ',',
#    'Leonardo',
#    'DiCaprio',
#    '.'],
#   ["'", 'Star', 'Wars', ':', 'The', 'Rise', 'of', 'Skywalker', "'"],
#   ["'", 'Star', 'Wars', "'"],
#   ['NASA',
#    'sendiri',
#    'terus',
#    'melakukan',
#    'penelitian',
#    'untuk',
#    'menemukan',
#    'planet-planet',
#    'yang',
#    'bisa',
#    'saja',
#    'menjadi',
#    'hunian',
#    'baru',
#    'manusia',
#    'di',
#    'masa',
#    'depan',
#    '.'],
#   ['Untungnya',
#    ',',
#    'kini',
#    'layanan',
#    'OVO',
#    'telah',
#    'normal',
#    'kembali',
#    'seperti',
#    'sedia',
#    'kala',
#    '.'],
#   ['Menurut',
#    'laporan',
#    'Kota',
#    'ku',
#    ',',
#    'Bodine',
#    'juga',
#    'menyelesaikan',
#    'game'],
#   ['Seseorang',
#    'masuk',
#    'ke',
#    'akun',
#    'saya',
#    'dan',
#    'memposting',
#    'foto',
#    '(',
#    'Ray-Ban',
#    ')',
#    '.',
#    'Aku',
#    'melihat',
#    'posting',
#    'yang',
#    'sama',
#    'muncul',
#    'di',
#    'empat',
#    'akun',
#    'lain',
#    'yang',
#    'aku',
#    'ikuti',
#    'juga',
#    ',',
#    'jadi',
#    'jelas',
#    'tersebar',
#    'luas',
#    ',',
#    '"'],
#   ['"'],
#   ['"',
#    'Playlist',
#    'akan',
#    'disesuaikan',
#    'pada',
#    'apa',
#    'yang',
#    'kamu',
#    'kenal',
#    ',',
#    '"'],
#   ['Mari', 'berbagi', 'jawaban', 'kalian', 'di', 'kolom', 'komentar', '.'],
#   ['Bukan', 'kita', 'yang', 'mengadakan', '.'],
#   ['Aldio',
#    'pun',
#    'tidak',
#    'perlu',
#    'khawatir',
#    'kalau',
#    'saldo',
#    'TapCash-nya',
#    'tiba-tiba',
#    'habis',
#    'sebelum',
#    'naik',
#    'transportasi',
#    'umum',
#    '.'],
#   ['Dari',
#    'top-up',
#    'TapCash',
#    ',',
#    'top-up',
#    'LinkAja',
#    ',',
#    'hingga',
#    'pembayaran',
#    'dan',
#    'pembelian',
#    'yang',
#    'bisa',
#    'dilakukan',
#    'kapan',
#    'pun',
#    'dan',
#    'di',
#    'mana',
#    'pun',
#    '.'],
#   ['Apes',
#    'nya',
#    'lagi',
#    ',',
#    'Costa',
#    'juga',
#    'divonis',
#    'dokter',
#    'mengidap',
#    'karsinoma',
#    'sel',
#    'skuamosa',
#    '(',
#    'KSS',
#    ')',
#    'stadium',
#    '4',
#    '.'],
#   ['KSS',
#    'dikenal',
#    'sebagai',
#    'salah',
#    'satu',
#    'jenis',
#    'kanker',
#    'kulit',
#    '.'],
#   ['"',
#    'Dua',
#    'kasus',
#    'ini',
#    'benar-benar',
#    'menjadi',
#    'sebuah',
#    'penegasan',
#    'tentang',
#    'sejauh',
#    'mana',
#    'kutu',
#    'bisa',
#    'menyebarkan',
#    'infeksi',
#    ',',
#    '"'],
#   ['Bicara',
#    'soal',
#    'penularan',
#    'penyakit',
#    'ini',
#    ',',
#    'bayi',
#    'yang',
#    'jarang',
#    'dibawa',
#    'keluar',
#    'rumah',
#    'oleh',
#    'orang',
#    'tua',
#    'nya',
#    'sekalipun',
#    'sangat',
#    'mungkin',
#    'tertular',
#    'penyakit',
#    'yang',
#    'disebabkan',
#    'gigitan',
#    'kutu',
#    '.'],
#   ['Kasus',
#    'ini',
#    'pun',
#    'sempat',
#    'masuk',
#    'ke',
#    'jalur',
#    'hukum',
#    'sebelum',
#    'akhirnya',
#    'pemilik',
#    'akun'],
#   ["'", 'Ku', 'katakan', 'dengan', 'Indah', "'"],
#   ['Kalau',
#    'ada',
#    'yang',
#    'ngutang',
#    'ya',
#    'sudah',
#    ',',
#    'enggak',
#    'apa-apa',
#    ',',
#    'yang',
#    'penting',
#    'ada',
#    'pemasukan',
#    'setiap',
#    'bulan',
#    ',',
#    '"'],
#   ['Ia',
#    'pun',
#    'mengambil',
#    'risiko',
#    'untuk',
#    'membatalkan',
#    'pekerjaan',
#    'di',
#    'akhir',
#    'tahun',
#    '.'],
#   ['Cuma', ',', 'saya', 'cancel', 'supaya', 'fokus', 'ke', 'Paula', '.'],
#   ['"', 'Itu', '(', 'darah', ')', 'sudah', 'kering', '.'],
#   ['"', 'Kayak', 'kemarin', 'aku', 'sakit', 'dan', 'segala', 'macem', '.'],
#   ['Agar', 'lancar', 'dan', 'sehat', 'semuanya', 'sampai', 'lahiran', '.'],
#   ['Harus', 'lah', '(', 'selektif', 'memilih', 'teman', ')', ',', '"'],
#   ['"'],
#   ['tulis',
#    'Fadlan',
#    'seperti',
#    'dilihat',
#    'kumparan',
#    ',',
#    'Jumat',
#    '(',
#    '13/12',
#    ')',
#    '.',
#    'Untungnya',
#    ',',
#    'pihak',
#    'sekuriti',
#    'kompleks',
#    'perumahan',
#    'Fadlan',
#    'Muhammad',
#    'sempat',
#    'memfoto',
#    'pelat',
#    'motor',
#    'pelaku',
#    '.'],
#   ["'", 'kan', '.'],
#   ['1', '.'],
#   ['Dia',
#    'ke',
#    'sini',
#    'pakai',
#    'ongkos',
#    'sendiri',
#    ',',
#    'beberapa',
#    'kali',
#    'makan',
#    ',',
#    'dia',
#    'bayarin',
#    '.'],
#   ['Ya', 'kan', '?'],
#   ['Saat',
#    'bersepeda',
#    'Salah',
#    'satu',
#    'hal',
#    'yang',
#    'paling',
#    'disyukuri',
#    'oleh',
#    'Dewi',
#    'Hughes',
# ...
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM'],
#   ['NNP',
#    'VB',
#    'SC',
#    'PR',
#    'CC',
#    'NN',
#    'VB',
#    'NN',
#    'VB',
#    'JJ',
#    'IN',
#    'JJ',
#    'VB',
#    'CC',
#    'VB',
#    'NN',
#    'PR',
#    'VB',
#    'NN',
#    'JJ',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'SYM'],
#   ['NN', 'DT', 'VB', 'PR', 'ADV', 'JJ', 'SYM'],
#   ['VB',
#    'SC',
#    'ADV',
#    'VB',
#    'NN',
#    'SYM',
#    'ADV',
#    'VB',
#    'JJ',
#    'NN',
#    'PR',
#    'DT',
#    'SC',
#    'PR',
#    'VB',
#    'NN',
#    'SYM'],
#   ['CC',
#    'ADV',
#    'ADV',
#    'JJ',
#    'SC',
#    'PR',
#    'SYM',
#    'NN',
#    'VB',
#    'NN',
#    'NN',
#    'CC',
#    'VB',
#    'ADV',
#    'NN',
#    'SYM'],
#   ['NN',
#    'ADV',
#    'VB',
#    'NN',
#    'NN',
#    'SYM',
#    'VB',
#    'SC',
#    'ADV',
#    'NN',
#    'NN',
#    'JJ',
#    'SYM',
#    'IN',
#    'ADV',
#    'VB',
#    'NN',
#    'IN',
#    'NN',
#    'SYM'],
#   ['SC',
#    'NEG',
#    'VB',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'IN',
#    'JJ',
#    'SYM',
#    'NEG',
#    'NEG',
#    'ADV',
#    'PR',
#    'ADV',
#    'VB',
#    'NN',
#    'NN',
#    'PR',
#    'ADV',
#    'JJ',
#    'CC',
#    'VB',
#    'NN',
#    'PR',
#    'VB',
#    'SYM'],
#   ['NN',
#    'DT',
#    'ADV',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'FW',
#    'PR',
#    'ADV',
#    'VB',
#    'NUM',
#    'NN',
#    'IN',
#    'NN',
#    'NN',
#    'SYM'],
#   ['IN',
#    'NN',
#    'PR',
#    'ADV',
#    'JJ',
#    'SYM',
#    'DT',
#    'JJ',
#    'ADV',
#    'VB',
#    'NN',
#    'VB',
#    'SYM'],
#   ['PR', 'ADV', 'VB', 'IN', 'PR', 'SYM'],
#   ['JJ',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'PR',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'SC',
#    'PR',
#    'NEG',
#    'VB',
#    'NN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'VB',
#    'NUM',
#    'NN',
#    'SYM',
#    'NEG',
#    'VB',
#    'DT',
#    'NN',
#    'NN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'NN',
#    'SYM',
#    'CC',
#    'VB',
#    'FW',
#    'SYM'],
#   ['PR', 'JJ', 'VB', 'SC', 'NN', 'NN', 'VB', 'NN', 'SYM'],
#   ['ADV',
#    'DT',
#    'JJ',
#    'NN',
#    'PR',
#    'VB',
#    'NN',
#    'ADV',
#    'VB',
#    'NN',
#    'NN',
#    'IN',
#    'JJ',
#    'NN',
#    'NN',
#    'CC',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'NN',
#    'SYM'],
#   ['VB', 'VB'],
#   ['SYM', 'NNP', 'FW', 'FW', 'FW', 'SYM', 'SYM'],
#   ['SYM',
#    'NN',
#    'NN',
#    'NN',
#    'DT',
#    'JJ',
#    'CC',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'CC',
#    'NEG',
#    'VB',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NN',
#    'SYM'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NNP',
#    'VB',
#    'NN',
#    'IN',
#    'NUM',
#    'NN',
#    'VB',
#    'NN',
#    'NNP',
#    'NN',
#    'JJ',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM'],
#   ['NN', 'VB', 'VB', 'NN', 'VB', 'SYM', 'SYM'],
#   ['NN', 'PR', 'NN', 'NNP', 'NNP', 'NUM', 'NNP', 'SYM', 'SYM'],
#   ['VB', 'PR', 'IN', 'NNP', 'SYM'],
#   ['NNP', 'VB', 'NN', 'VB', 'NN', 'PR', 'IN', 'NNP', 'SYM'],
#   ['SYM', 'SYM'],
#   ['SYM'],
#   ['CC', 'ADV', 'ADV', 'NN', 'DT', 'SYM', 'SYM'],
#   ['SYM',
#    'SC',
#    'SC',
#    'PR',
#    'ADV',
#    'NUM',
#    'NN',
#    'NN',
#    'PR',
#    'VB',
#    'SYM',
#    'SYM'],
#   ['VB', 'NNP', 'SYM'],
#   ['NN',
#    'VB',
#    'ADV',
#    'NN',
#    'NUM',
#    'NN',
#    'IN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'NNP',
#    'NN',
#    'VB',
#    'NN',
#    'JJ',
#    'NN',
#    'NN',
#    'DT',
#    'SYM'],
#   ['NNP', 'VB', 'NN', 'ADV', 'VB', 'NN', 'DT', 'SYM'],
#   ['SYM', 'ADV', 'IN', 'NN', 'SYM', 'SYM'],
#   ['NNP', 'DT', 'IN', 'ADV', 'VB', 'FW', 'FW', 'IN', 'NNP', 'SYM'],
#   ['PR', 'NN', 'IN', 'NN', 'NNP', 'SC', 'VB', 'IN', 'NNP', 'SYM'],
#   ['VB', 'NNP', 'SYM', 'VB', 'IN', 'NN', 'JJ', 'NNP', 'SYM'],
#   ['NNP',
#    'ADV',
#    'NN',
#    'PR',
#    'NN',
#    'PR',
#    'SYM',
#    'SC',
#    'PR',
#    'SYM',
#    'JJ',
#    'IN',
#    'NNP',
#    'SYM'],
#   ['CC', 'VB', 'PR', 'VB', 'NN', 'SC', 'VB', 'NN', 'JJ', 'SYM'],
#   ['UH', 'SYM', 'NN', 'NNP', 'NNP', 'NNP', 'NNP', 'SYM'],
#   ['NNP',
#    'SYM',
#    'FW',
#    'NN',
#    'NN',
#    'NNP',
#    'SYM',
#    'JJ',
#    'ADV',
#    'IN',
#    'JJ',
#    'VB',
#    'JJ',
#    'NUM',
#    'DT',
#    'IN',
#    'NNP',
#    'SYM',
#    'JJ',
#    'DT',
#    'IN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM'],
#   ['IN',
#    'DT',
#    'NN',
#    'SYM',
#    'DT',
#    'NN',
#    'ADV',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'CC',
#    'DT',
#    'NN',
#    'JJ',
#    'FW',
#    'FW',
#    'SYM',
#    'FW',
#    'SYM',
#    'CC',
#    'FW',
#    'SC',
#    'NN',
#    'PR',
#    'VB',
#    'ADV',
#    'VB',
#    'IN',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NNP',
#    'SYM'],
#   ['SYM', 'NNP', 'NNP', 'SYM'],
#   ['CC',
#    'PR',
#    'SYM',
#    'NNP',
#    'ADV',
#    'VB',
#    'DT',
#    'NN',
#    'VB',
#    'NN',
#    'NN',
#    'PR',
#    'ADV',
#    'JJ',
#    'VB',
#    'NNP',
#    'NN',
#    'IN',
#    'NN',
#    'VB',
#    'SYM'],
#   ['PR', 'VB', 'PR', 'ADV', 'VB', 'SYM', 'SYM'],
#   ['NN',
#    'NNP',
#    'VB',
#    'NUM',
#    'NN',
#    'SC',
#    'NN',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM'],
#   ['SC',
#    'NN',
#    'NN',
#    'SYM',
#    'NN',
#    'SYM',
#    'NNP',
#    'VB',
#    'NN',
#    'SYM',
#    'NN',
#    'DT',
#    'SYM',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'PR',
#    'JJ',
#    'VB',
#    'NN',
#    'NN',
#    'NNP',
#    'SYM'],
#   ['NN',
#    'PR',
#    'DT',
#    'JJ',
#    'VB',
#    'NNP',
#    'NNP',
#    'IN',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'CC',
#    'NNP',
#    'NNP',
#    'IN',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'NN',
#    'DT',
#    'ADV',
#    'JJ',
#    'VB',
#    'NN',
#    'CC',
#    'NN',
#    'SYM'],
#   ['IN', 'NN', 'DT', 'SYM', 'NNP', 'ADV', 'VB', 'IN', 'NN', 'NN', 'SYM'],
#   ['NNP',
#    'ADV',
#    'NN',
#    'NN',
#    'NNP',
#    'NNP',
#    'JJ',
#    'SYM',
#    'NUM',
#    'NN',
#    'SYM',
#    'CC',
#    'SYM',
#    'IN',
#    'NNP',
#    'NNP',
#    'SYM',
#    'PR',
#    'ADV',
#    'VB',
#    'NN',
#    'PR',
#    'ADV',
#    'ADV',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'SYM',
#    'NUM',
#    'NN',
#    'SYM',
#    'SYM',
#    'JJ',
#    'NUM',
#    'NN',
#    'NN',
#    'IN',
#    'PR',
#    'NNP',
#    'VB',
#    'NN',
#    'ADV',
#    'IN',
#    'NUM',
#    'SYM'],
#   ['IN',
#    'PR',
#    'SYM',
#    'NN',
#    'VB',
#    'NNP',
#    'NNP',
#    'ADV',
#    'VB',
#    'VB',
#    'JJ',
#    'IN',
#    'PR',
#    'NNP',
#    'NNP',
#    'SYM'],
#   ['NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'VB',
#    'NUM',
#    'NNP',
#    'ADV',
#    'NUM',
#    'NN',
#    'ADV',
#    'VB',
#    'JJ',
#    'SC',
#    'NN',
#    'NNP',
#    'SYM'],
#   ['NN',
#    'VB',
#    'IN',
#    'NN',
#    'NNP',
#    'ADV',
#    'NN',
#    'NUM',
#    'NN',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'NN',
#    'DT',
#    'VB',
#    'NUM',
#    'NN',
#    'PR',
#    'VB',
#    'NN',
#    'NNP',
#    'SYM'],
#   ['SC',
#    'NN',
#    'IN',
#    'ADV',
#    'VB',
#    'NN',
#    'VB',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'SYM'],
#   ['SC',
#    'PR',
#    'SYM',
#    'NNP',
#    'PR',
#    'ADV',
#    'VB',
#    'IN',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'VB',
#    'IN',
#    'NN',
#    'NNP',
#    'NNP',
#    'SYM'],
#   ['SC',
#    'NNP',
#    'VB',
#    'IN',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NNP',
#    'VB',
#    'NN',
#    'IN',
#    'NN',
#    'NN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'SYM'],
#   ['VB', 'NNP', 'SYM'],
#   ['NUM', 'SYM'],
#   ['SYM',
#    'ADV',
#    'ADV',
#    'SYM',
#    'VB',
#    'SYM',
#    'SYM',
#    'FW',
#    'FW',
#    'ADV',
#    'PR',
#    'VB',
#    'SYM',
#    'JJ',
#    'PR',
#    'VB',
#    'SC',
#    'VB',
#    'NNP',
#    'PR',
#    'SYM'],
#   ['NN',
#    'SYM',
#    'IN',
#    'ADV',
#    'ADV',
#    'NUM',
#    'NN',
#    'NEG',
#    'VB',
#    'NN',
#    'JJ',
#    'SYM',
#    'IN',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'NN',
#    'VB',
#    'NN',
#    'NN',
#    'ADV',
#    'VB',
#    'FW',
#    'FW',
#    'NNP',
#    'NNP',
#    'SYM'],
#   ['IN',
#    'NN',
#    'IN',
#    'NN',
#    'SYM',
#    'NN',
#    'NNP',
#    'DT',
#    'VB',
#    'VB',
#    'NUM',
#    'NN',
#    'JJ',
#    'SC',
#    'FW',
#    'FW',
#    'NNP',
#    'NNP',
#    'JJ',
#    'IN',
#    'NN',
#    'SYM'],
#   ['NN', 'NNP', 'IN', 'NNP', 'SYM', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM'],
#   ['IN',
#    'NN',
#    'JJ',
#    'SYM',
#    'NNP',
#    'ADV',
#    'VB',
#    'NN',
#    'NNP',
#    'NUM',
#    'SC',
#    'IN',
#    'NN',
#    'ADV',
#    'SYM'],
#   ['NN',
#    'SYM',
#    'NN',
#    'NNP',
#    'CC',
#    'NNP',
#    'ADV',
#    'NUM',
#    'NN',
#    'PR',
#    'NEG',
#    'ADV',
#    'VB',
#    'SYM'],
#   ['NN',
#    'SYM',
#    'PR',
#    'ADV',
#    'VB',
#    'NNP',
#    'NNP',
#    'IN',
#    'NN',
#    'JJ',
#    'IN',
#    'NN',
#    'PR',
#    'PR',
#    'VB',
#    'NN',
#    'FW',
#    'SYM',
#    'NNP',
#    'SYM'],
#   ['SC',
#    'NEG',
#    'ADV',
#    'VB',
#    'SYM',
#    'SC',
#    'NNP',
#    'VB',
#    'NNP',
#    'ADV',
#    'VB',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'SYM'],
#   ['CC',
#    'FW',
#    'FW',
#    'PR',
#    'NUM',
#    'DT',
#    'ADV',
#    'JJ',
#    'VB',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'SYM',
#    'SC',
#    'ADV',
#    'ADV',
#    'VB',
#    'NN',
#    'SC',
#    'VB',
#    'SC',
#    'VB',
#    'SYM'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'IN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'NUM',
#    'ADV',
#    'VB',
#    'JJ',
#    'IN',
#    'NN',
#    'PR',
#    'FW'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'VB',
#    'NN',
#    'NN',
#    'FW',
#    'SYM',
#    'FW',
#    'NN',
#    'NNP',
#    'DT',
#    'ADV',
#    'VB',
#    'NN',
#    'PR',
#    'ADV',
#    'JJ',
#    'SYM'],
#   ['NN',
#    'FW',
#    'SYM',
#    'DT',
#    'PR',
#    'FW',
#    'ADV',
#    'ADV',
#    'JJ',
#    'CC',
#    'ADV',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'VB',
#    'JJ',
#    'SYM'],
#   ['DT', 'NN', 'VB', 'IN', 'ADV', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM'],
#   ['NN', 'NNP', 'SYM'],
#   ['NUM', 'SYM'],
#   ['NNP',
#    'FW',
#    'ADV',
#    'VB',
#    'VB',
#    'IN',
#    'NN',
#    'SC',
#    'VB',
#    'NN',
#    'IN',
#    'NN',
#    'NN',
#    'SYM'],
#   ['NUM', 'SYM'],
#   ['VB',
#    'NNP',
#    'IN',
#    'NN',
#    'NNP',
#    'PR',
#    'ADV',
#    'VB',
#    'IN',
#    'DT',
#    'NN',
#    'ADV',
#    'NN',
#    'JJ',
#    'NN',
#    'SYM'],
#   ['NUM', 'SYM'],
#   ['NN', 'PR', 'IN', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM', 'NN', 'SYM'],
#   ['IN',
#    'PR',
#    'SYM',
#    'NUM',
#    'NNP',
#    'NNP',
#    'VB',
#    'JJ',
#    'IN',
#    'JJ',
#    'PR',
#    'SYM',
#    'CC',
#    'NN',
#    'NN',
#    'IN',
#    'NN',
#    'DT',
#    'VB',
#    'NN',
#    'SYM'],
#   ['NNP',
#    'VB',
#    'SYM',
#    'NN',
#    'NN',
#    'NN',
#    'NN',
#    'ADV',
#    'VB',
#    'NN',
#    'PR',
#    'JJ',
#    'SYM'],
#   ['JJ', 'NNP', 'NN', 'PR', 'ADV', 'VB', 'IN', 'NNP', 'NNP', 'NNP', 'SYM'],
#   ['VB',
#    'NNP',
#    'SYM',
#    'IN',
#    'NN',
#    'PR',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'IN',
#    'NNP',
#    'SYM',
#    'NN',
#    'NN',
#    'NN',
#    'NNP',
#    'VB',
#    'NN',
#    'VB',
#    'NN',
#    'NN',
#    'SYM'],
#   ['SYM', 'ADV', 'ADV', 'NN', 'SYM', 'VB', 'IN', 'NN', 'SYM'],
#   ['NN', 'DT', 'NN', 'PR', 'SYM', 'NN', 'NN', 'PR', 'SYM'],
#   ['PR', 'ADV', 'NN', 'SC', 'ADV', 'VB', 'SYM', 'SYM'],
#   ['NNP',
#    'NNP',
#    'IN',
#    'NUM',
#    'NN',
#    'JJ',
#    'SYM',
#    'NNP',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNP',
#    'NN',
#    'NNP',
#    'ADV',
#    'VB',
#    'JJ',
#    'NUM',
#    'NN',
#    'JJ',
#    'PR',
#    'JJ',
#    'PR',
#    'VB',
#    'SYM'],
#   ['CC', 'ADV', 'VB', 'IN', 'NUM', 'SYM'],
#   ['PR', 'VB', 'SYM', 'SYM'],
#   ['PR',
#    'VB',
#    'SYM',
#    'SC',
#    'NEG',
#    'VB',
#    'FW',
#    'JJ',
#    'SYM',
#    'ADV',
#    'ADV',
#    'NN',
#    'SYM'],
#   ['ADV', 'SYM', 'NEG', 'PR', 'VB', 'NN', 'IN', 'NUM', 'NN', 'SYM'],
#   ['NN',
#    'DT',
#    'VB',
#    'VB',
#    'VB',
#    'NN',
#    'NNP',
#    'CC',
#    'NN',
#    'SYM',
#    'NUM',
#    'NUM',
#    'PR',
#    'VB',
#    'NNP',
#    'NNP',
#    'NNP',
#    'IN',
#    'NN',
#    'NN',
#    'JJ',
#    'NNP',
#    'IN',
#    'NNP',
#    'SYM'],
#   ['NN',
#    'NUM',
#    'NN',
#    'NUM',
#    'NNP',
#    'DT',
#    'VB',
#    'SC',
#    'NNP',
#    'ADV',
#    'VB',
#    'IN',
#    'NN',
#    'JJ',
#    'NUM',
#    'NN',
#    'NN',
#    'JJ',
#    'NUM',
#    'NN',
#    'NN',
#    'SYM'],
#   ['NEG',
#    'VB',
#    'NN',
#    'SYM',
#    'NEG',
#    'VB',
#    'NN',
#    'NN',
#    'JJ',
#    'PR',
#    'JJ',
#    'NUM',
#    'NN',
#    'SYM'],
#   ['UH',
#    'SC',
#    'VB',
#    'NN',
#    'SYM',
#    'VB',
#    'NN',
#    'PR',
#    'VB',
#    'ADV',
#    'CC',
#    'ADV',
#    'VB',
#    'ADV',
#    'VB',
#    'IN',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'SC',
#    'NN',
#    'NN',
#    'DT',
#    'VB',
#    'VB',
#    'NN',
#    'NN',
#    'NN',
#    'NEG',
#    'JJ',
#    'SYM',
#    'NNP',
#    'SYM',
#    'SYM',
#    'PR',
#    'ADV',
#    'VB',
#    'SYM',
#    'NN',
#    'DT',
#    'VB',
#    'JJ',
#    'IN',
#    'NN',
#    'SYM'],
#   ['VB',
#    'VB',
#    'NN',
#    'NN',
#    'NN',
#    'NEG',
#    'JJ',
#    'SYM',
#    'SC',
#    'NN',
#    'IN',
#    'NN',
#    'DT',
#    'NN',
#    'ADV',
#    'SYM'],
#   ['VB', 'NN', 'SYM'],
#   ['NN', 'NN', 'IN', 'NN', 'NN', 'VB', 'ADV', 'SYM'],
#   ['IN', 'PR', 'PR', 'ADV', 'NN', 'NN', 'PR', 'SYM'],
#   ['SYM', 'NNP', 'SYM'],
#   ['JJ',
#    'IN',
#    'PR',
#    'SYM',
#    'PR',
#    'IN',
#    'VB',
#    'PR',
#    'PR',
#    'IN',
#    'NN',
#    'IN',
#    'NUM',
#    'NN',
#    'PR',
#    'VB',
#    'IN',
#    'NN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'CC',
#    'NNP',
#    'SYM'],
#   ['NNP',
#    'VB',
#    'ADV',
#    'VB',
#    'VB',
#    'ADV',
#    'NUM',
#    'NN',
#    'CC',
#    'NUM',
#    'NN',
#    'SYM'],
#   ['SC',
#    'SYM',
#    'VB',
#    'NN',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'PR',
#    'VB',
#    'NN',
#    'CC',
#    'NN',
#    'PR',
#    'JJ',
#    'IN',
#    'NN',
#    'NN',
#    'SYM'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NUM', 'SYM'],
#   ['NN', 'SYM', 'NUM', 'SYM', 'NUM', 'NNP', 'SYM', 'NN', 'SYM'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NNP', 'SYM', 'SYM', 'NUM', 'SYM', 'NUM', 'NUM', 'SYM'],
#   ['NNP', 'SYM'],
#   ['NUM', 'SYM'],
#   ['NN',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NUM',
#    'NNP',
#    'SYM'],
#   ['NNP', 'SYM', 'SYM', 'NUM', 'SYM', 'NUM', 'NUM', 'SYM'],
#   ['NNP', 'SYM', 'SYM', 'NUM', 'SYM', 'NUM', 'NUM', 'SYM'],
#   ['NUM',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NUM',
#    'NNP',
#    'SYM'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NNP',
#    'SYM',
#    'SYM',
#    'NUM',
#    'SYM',
#    'NUM',
#    'NNP',
#    'SYM',
#    'FW',
#    'SYM',
#    'NUM',
#    'SYM'],
#   ['NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NUM',
#    'NNP',
#    'SYM'],
#   ['NUM', 'SYM'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'SYM'],
#   ['NUM', 'SYM'],
#   ['NNP', 'SYM'],
#   ['NNP', 'SYM', 'ADV', 'VB', 'NN', 'NN', 'NN', 'NN', 'SYM'],
#   ['NEG',
#    'VB',
#    'ADV',
#    'NN',
#    'NN',
#    'NN',
#    'SC',
#    'NN',
#    'JJ',
#    'IN',
#    'NN',
#    'CC',
#    'NN',
#    'NN',
#    'SYM'],
#   ['NN', 'NN', 'ADV', 'ADV', 'VB', 'SYM'],
#   ['NNP',
#    'PR',
#    'VB',
#    'IN',
#    'NNP',
#    'IN',
#    'NN',
#    'IN',
#    'NNP',
#    'NNP',
#    'CC',
#    'JJ',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM'],
#   ['IN',
#    'DT',
#    'NN',
#    'ADV',
#    'VB',
#    'VB',
#    'NN',
#    'CC',
#    'NN',
#    'VB',
#    'SYM',
#    'PR',
#    'ADV',
#    'VB',
#    'NN',
#    'VB',
#    'NN',
#    'SYM'],
#   ['SYM', 'PR', 'NN', 'SYM', 'NN', 'NN', 'NN', 'SYM', 'ADV', 'PR', 'SYM'],
#   ['CC',
#    'PR',
#    'SYM',
#    'NN',
#    'NN',
#    'PR',
#    'VB',
#    'ADV',
#    'ADV',
#    'VB',
#    'SYM',
#    'SC',
#    'DT',
#    'NN',
#    'NN',
#    'NN',
#    'PR',
#    'NEG',
#    'VB',
#    'SYM'],
#   ['UH',
#    'SYM',
#    'PR',
#    'ADV',
#    'NN',
#    'IN',
#    'PR',
#    'UH',
#    'SC',
#    'DT',
#    'NN',
#    'PR',
#    'VB',
#    'SYM',
#    'SYM'],
#   ['SYM',
#    'NN',
#    'ADV',
#    'NNP',
#    'CC',
#    'NNP',
#    'VB',
#    'NNP',
#    'NN',
#    'SC',
#    'VB',
#    'CC',
#    'VB',
#    'SC',
#    'PR',
#    'ADV',
#    'VB',
#    'NN',
#    'SYM'],
#   ['VB', 'DT', 'NN', 'PR', 'ADV', 'VB', 'IN', 'NN', 'DT', 'SYM'],
#   ['NN', 'PR', 'JJ', 'ADV', 'VB', 'IN', 'NN', 'FW', 'CC', 'NN', 'VB', 'SYM'],
#   ['VB',
#    'NN',
#    'NN',
#    'NNP',
#    'NNP',
#    'NNP',
#    'SYM',
#    'NNP',
#    'SYM',
#    'NUM',
#    'SYM',
#    'SYM',
#    'NN',
#    'NN',
#    'NNP',
#    'NN',
#    'DT',
#    'VB',
#    'JJ',
#    'SYM',
#    'NUM',
#    'IN',
#    'NN',
#    'VB',
#    'SYM',
#    'NUM',
#    'IN',
#    'NN',
#    'SYM'],
#   ['NNP',
#    'VB',
#    'PR',
#    'IN',
#    'NNP',
#    'NNP',
#    'NUM',
#    'IN',
#    'IN',
#    'NN',
#    'NN',
#    'NUM',
#    'NN',
#    'SYM'],
#   ['NN', 'DT', 'PR', 'RP', 'ADV', 'JJ', 'IN', 'NN', 'NN', 'SYM'],
#   ['VB', 'NNP', 'SC', 'VB', 'IN', 'NNP', 'NNP', 'SYM'],
#   ...])

# %%
sentence, tags = read_dataset(dataset_path, encoding='iso-8859-1')

# %%
def features(sentence, index):
    """ sentence: [w1, w2, ...], index: the index of the word """
    return {
        "word": sentence[index],
        "is_first": index == 0,
        "is_last": index == len(sentence) - 1,
        "is_capitalized": sentence[index][0].upper()
        == sentence[index][0],
        "is_all_caps": sentence[index].upper() == sentence[index],
        "is_all_lower": sentence[index].lower() == sentence[index],
        "has_hyphen": "-" in sentence[index],
        "is_numeric": sentence[index].isdigit(),
        "capitals_inside": sentence[index][1:].lower()
        != sentence[index][1:],
        "prefix-1": sentence[index][0],
        "prefix-1-lower": sentence[index][0].lower(),
        "prefix-2": sentence[index][:2],
        "prefix-2-lower": sentence[index][:2].lower(),
        "prefix-3": sentence[index][:3],
        "prefix-3-lower": sentence[index][:3].lower(),
        "suffix-1": sentence[index][-1],
        "suffix-1-lower": sentence[index][-1].lower(),
        "suffix-2": sentence[index][-2:],
        "suffix-2-lower": sentence[index][-2:].lower(),
        "suffix-3": sentence[index][-3:],
        "suffix-3-lower": sentence[index][-3:].lower(),
        "lowercase_word": sentence[index].lower(),
        "prev_word": "" if index == 0 else sentence[index - 1],
        "next_word": ""
        if index == len(sentence) - 1
        else sentence[index + 1],
        "prev_word_is_capitalized": False
        if index == 0
        else sentence[index - 1][0].upper() == sentence[index - 1][0],
        "next_word_is_capitalized": False
        if index == len(sentence) - 1
        else sentence[index + 1][0].upper() == sentence[index + 1][0],
        "2-prev-word": "" if index <= 1 else sentence[index - 2],
        "2-next-word": ""
        if index >= len(sentence) - 2
        else sentence[index + 2],
    }

# %%
def transform_to_dataset(sentences, tags):
    X, y = [], []

    for sentence_idx in range(len(sentences)):
        for index in range(len(sentences[sentence_idx])):
            X.append(features(sentences[sentence_idx], index))
            y.append(tags[sentence_idx][index])

    return X, y

# %%
clf = Pipeline(
    [
        ('vectorizer', DictVectorizer(sparse=True)),
        (
            'classifier', 
            RandomForestClassifier(
                criterion='gini', n_estimators=1, random_state=2020, verbose=2
            ),
        ),
    ]
)

# %%
def train(senteces, tags):

    clf.fit(senteces, tags)

# %%
senteces, tags = transform_to_dataset(sentence, tags)

# %%
train(senteces, tags)
# Out:
# building tree 1 of 1

# %%
def save_model(model_path):
    pickle_out = open(model_path, 'wb')
    pickle.dump(clf, pickle_out)
    pickle_out.close()

# %%
model_path = './postager_model.pkl'
save_model(model_path)

# %%
def load_model(model_path):
    pickle_in = open(model_path, 'rb')
    load_data = pickle.load(pickle_in)
    return load_data

# %%
model = load_model(model_path)

# %%
display(model)
# Out:
# Pipeline(steps=[('vectorizer', DictVectorizer()),
#                 ('classifier',
#                  RandomForestClassifier(n_estimators=1, random_state=2020,
#                                         verbose=2))])

# %%
def get_pos_tag(text):
    result = []
    sents = nltk.sent_tokenize(text)
    symbols = ['!', '&', '(', ')', '*', '?', ',', '.', '<', '>', '/', ':', ';',
                '[', ']', '\\', '^', '`', '{', '}', '|', '~', '"', '“', "'"]
    for sent in sents:
        tokenized_word = tokenizer.tokenize(sent)
        if sent:
            tags = model.predict(
                [
                    features(tokenized_word, index)
                    for index in range(len(tokenized_word))
                ]
            )
            for i in range(len(tags)):
                if tokenized_word[i] in symbols:
                    result.append((tokenized_word[i], "SYM"))
                else:
                    result.append((tokenized_word[i], tags[i]))
    return result

# %%
text = "Lionel Messi pergi ke pasar di daerah Jakarta Pusat."

# %%
get_pos_tag(text)
# Out:
# [('Lionel', 'NNP'),
#  ('Messi', 'NNP'),
#  ('pergi', 'VB'),
#  ('ke', 'IN'),
#  ('pasar', 'NN'),
#  ('di', 'IN'),
#  ('daerah', 'NN'),
#  ('Jakarta', 'NNP'),
#  ('Pusat', 'NNP'),
#  ('.', 'SYM')]

# %%
get_pos_tag('Ronaldo Ikut capres')
# Out:
# [('Ronaldo', 'NNP'), ('Ikut', 'NNP'), ('capres', 'NN')]
