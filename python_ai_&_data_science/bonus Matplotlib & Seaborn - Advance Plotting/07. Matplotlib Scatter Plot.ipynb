# %% [markdown]
# ## SCATTER PLOT

# %%
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

# %%
plt.scatter(x, y)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Setting size

# %%
plt.scatter(x, y, s=100)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Change Color

# %%
plt.scatter(x, y, s=100, c='green')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### change marker

# %%
plt.scatter(x, y, s=100, c='green', marker='x')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Add edge color

# %%
plt.scatter(x, y, s=100, c='green', edgecolor='black', linewidth=1, alpha=0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Have multiple colors and sizes. enable us to have more datasets

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

colors = [7, 4, 3, 5, 6, 7, 1, 1, 8, 5, 6, 9, 3, 5, 6, 2, 6, 2, 8, 7]

# %%
plt.scatter(x, y, s=100, c=colors, edgecolor='black', linewidth=1, alpha=0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### We can use color map

# %%
plt.scatter(x, y, s=100, c=colors, cmap='Greens', edgecolor='black',
            linewidth=1, alpha=0.75)

plt.tight_layout()
plt.show()

# %% [markdown]
# cmaps can be seen here: https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %% [markdown]
# ### Add color bar legend

# %%
plt.scatter(x, y, s=100, c=colors, cmap='Greens', edgecolor='black',
            linewidth=1, alpha=0.75)

cbar= plt.colorbar()
cbar.set_label('Satisfaction')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muh. Angga Muttaqien\AppData\Local\Temp\ipykernel_5564\289511231.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar= plt.colorbar()

# %% [markdown]
# ### Set Size

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

colors = [7, 4, 3, 5, 6, 7, 1, 1, 8, 5, 6, 9, 3, 5, 6, 2, 6, 2, 8, 7]
sizes = [117, 234, 343, 435, 556, 417, 145, 591, 518, 225, 286, 419, 373, 425, 246, 542, 196, 255, 468, 417]

# %%
plt.scatter(x, y, s=sizes, c=colors, cmap='Greens', edgecolor='black',
            linewidth=1, alpha=0.75)

cbar= plt.colorbar()
cbar.set_label('Satisfaction')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muh. Angga Muttaqien\AppData\Local\Temp\ipykernel_5564\1586222549.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar= plt.colorbar()

# %% [markdown]
# ### Use real world data

# %%
data = pd.read_csv('./data_scatter.csv')
data.head()
# Out:
#    view_count   likes  ratio
# 0     8036001  324742  96.91
# 1     9378067  562589  98.19
# 2     2182066  273650  99.38
# 3     6525864   94698  96.25
# 4     9481284  582481  97.22

# %%
view_count = data['view_count'] # X
likes = data['likes'] # Y
ratio = data['ratio']

# %%
plt.scatter(view_count, likes, edgecolor='black',
            linewidth=1, alpha=0.75)

plt.title('Trending Youtube Videos')
plt.xlabel('View Count')
plt.xlabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
plt.scatter(view_count, likes, edgecolor='black',
            linewidth=1, alpha=0.75)

plt.xscale('log')
plt.yscale('log')

plt.title('Trending Youtube Videos')
plt.xlabel('View Count')
plt.xlabel('Total Likes')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use the color for ratio

# %%
plt.scatter(view_count, likes, c=ratio, cmap='summer',
            edgecolor='black', linewidth=1, alpha=0.75)
cbar=plt.colorbar()
cbar.set_label('Like/Dislike Ratio')

plt.xscale('log')
plt.yscale('log')

plt.title('Trending Youtube Videos')
plt.xlabel('View Count')
plt.xlabel('Total Likes')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muh. Angga Muttaqien\AppData\Local\Temp\ipykernel_5564\803961866.py:3: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar=plt.colorbar()

# %% [markdown]
# ---
