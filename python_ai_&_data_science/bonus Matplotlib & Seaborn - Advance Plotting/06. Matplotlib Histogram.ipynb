# %% [markdown]
# ![](matplotlib/histogram.png)

# %% [markdown]
# ## HISTOGRAM

# %%
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

# %%
plt.hist(ages)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %%
plt.hist(ages, bins=5)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ### Add edge color

# %%
plt.hist(ages, bins=5, edgecolor='k')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ### We can pass our own list of value (bins). It allows us to have control

# %%
# plot 10yrs difference
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [10, 20, 30, 40, 50, 60]

# %%
plt.hist(ages, bins=bins, edgecolor='k')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ### We can exclude a data

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
bins = [20, 30, 40, 50, 60]

plt.hist(ages, bins=bins, edgecolor='k')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ### Let's use real world data

# %%
data = pd.read_csv('./data_histo.csv')
ids = data['Responder_id']
ages = data['Age']

bins = [10, 20, 30, 40, 50, 60, 80, 90, 100]

# %%
plt.hist(ages, bins=bins, edgecolor='k')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %%
plt.hist(ages, bins=bins, edgecolor='k', log=True)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ### Add median line

# %%
median_age = 29
color = 'red'

plt.hist(ages, bins=bins, edgecolor='k', log=True)

plt.axvline(median_age, color=color, label='Age Media')

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %%
median_age = 29
color = 'red'

plt.hist(ages, bins=bins, edgecolor='k', log=True)

plt.axvline(median_age, color=color, label='Age Media', linewidth=0.5)

plt.title('Ages of Respondents')
plt.xlabel('Ages')
plt.ylabel('Total Respondents')

plt.show()

# %% [markdown]
# ---
