# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([6, 10, 4, 13])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### Membuat dua plot secara horizontal

# %%
# Plot 1
# plt.figure(figuresize =(10, 4))
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(1, 2, 1)
plt.plot(x, y)

# Plot 2
# plt.figure(figuresize =(10, 4))
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(1, 2, 2)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Membuat dua plot secara vertical

# %%
# Plot 1
# plt.figure(figuresize =(10, 4))
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 1, 1)
plt.plot(x, y)

# Plot 2
# plt.figure(figuresize =(10, 4))
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 1, 2)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ### Membuat banyak plot

# %%
# Plot 1

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 1)
plt.plot(x, y)

# Plot 2

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 2)
plt.plot(x, y)

# Plot 3

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 3)
plt.plot(x, y)

# Plot 4

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 4)
plt.plot(x, y)

# Plot 5

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 5)
plt.plot(x, y)

# Plot 6

x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 6)
plt.plot(x, y)

plt.show()
