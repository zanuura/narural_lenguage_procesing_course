# %%
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df_airbnb = pd.read_csv('./airbnb.csv')
df_airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### Check Data Info

# %%
df_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
df_airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
df_airbnb['last_review'] = pd.to_datetime(df_airbnb['last_review'], format='%Y-%m-%d')
last_review = df_airbnb[df_airbnb['last_review'] > '2019-07-01']

last_review.head()
# Out:
#        id                                              name  host_id  \
# 3    3831                   Cozy Entire Floor of Brownstone     4869
# 13   6021  Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 23   8110                             CBG Helps Haiti Rm #2    22486
# 39  12048               LowerEastSide apt share shortterm 1     7549
# 51  14287    Cozy 1BD on Central Park West in New York City    56094
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 3   LisaRoxanne            Brooklyn     Clinton Hill  40.68514  -73.95976
# 13      Claudio           Manhattan  Upper West Side  40.79826  -73.96113
# 23        Lisel            Brooklyn       Park Slope  40.68001  -73.97865
# 39          Ben           Manhattan  Lower East Side  40.71401  -73.98917
# 51         Joya           Manhattan  Upper West Side  40.78635  -73.97008
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 3   Entire home/apt     89               1                270  2019-07-05
# 13     Private room     85               2                113  2019-07-05
# 23     Private room    110               2                 71  2019-07-02
# 39      Shared room     40               1                214  2019-07-05
# 51  Entire home/apt    151               2                 73  2019-07-07
#
#     reviews_per_month  calculated_host_listings_count  availability_365
# 3                4.64                               1               194
# 13               0.91                               1               333
# 23               0.61                               6               304
# 39               1.81                               4               188
# 51               0.63                               1               302

# %% [markdown]
# ---

# %%
last_review.tail()
# Out:
#              id                                        name    host_id  \
# 48782  36425863  Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                    No.2 with queen size bed  257683179
# 48799  36438336                             Seas The Moment  211644523
# 48805  36442252               1B-1B apartment near by Metro  273841667
# 48852  36455809     Cozy Private Room in Bushwick, Brooklyn   74162901
#
#        host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 48782      Rusaa           Manhattan  Upper East Side  40.78099  -73.95366
# 48790       H Ai              Queens         Flushing  40.75104  -73.81459
# 48799        Ben       Staten Island      Great Kills  40.54179  -74.14275
# 48805     Blaine               Bronx       Mott Haven  40.80787  -73.92400
# 48852  Christine            Brooklyn         Bushwick  40.69805  -73.92801
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48782     Private room    129               1                  1  2019-07-07
# 48790     Private room     45               1                  1  2019-07-07
# 48799     Private room    235               1                  1  2019-07-07
# 48805  Entire home/apt    100               1                  2  2019-07-07
# 48852     Private room     30               1                  1  2019-07-08
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 48782                1.0                               1               147
# 48790                1.0                               6               339
# 48799                1.0                               1                87
# 48805                2.0                               1                40
# 48852                1.0                               1                 1

# %%
last_review.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  3.366000e+03  3.366000e+03  3366.000000  3366.000000  3366.000000
# mean   2.303363e+07  9.579867e+07    40.723140   -73.939351   141.100119
# min    3.831000e+03  2.881000e+03    40.508680   -74.239860    10.000000
# 25%    1.521947e+07  1.185199e+07    40.683580   -73.980350    67.000000
# 50%    2.607292e+07  5.636679e+07    40.716770   -73.948855   100.000000
# 75%    3.272451e+07  1.820235e+08    40.762730   -73.919710   170.000000
# max    3.645581e+07  2.738417e+08    40.913060   -73.721790  7500.000000
# std    1.104753e+07  9.286883e+07     0.060752     0.060330   172.385972
#
#        minimum_nights  number_of_reviews                    last_review  \
# count     3366.000000        3366.000000                           3366
# mean         2.595960          53.438800  2019-07-04 17:40:06.417112320
# min          1.000000           1.000000            2019-07-02 00:00:00
# 25%          1.000000           9.000000            2019-07-03 00:00:00
# 50%          2.000000          28.000000            2019-07-05 00:00:00
# 75%          3.000000          73.000000            2019-07-06 00:00:00
# max        200.000000         629.000000            2019-07-08 00:00:00
# std          4.797427          67.264798                            NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# count        3366.000000                     3366.000000       3366.000000
# mean            3.372041                        2.037136        150.135769
# min             0.050000                        1.000000          0.000000
# 25%             1.650000                        1.000000         43.000000
# 50%             3.000000                        1.000000        123.000000
# 75%             4.460000                        2.000000        260.000000
# max            58.500000                       34.000000        365.000000
# std             2.559497                        2.505053        118.709651

# %%
print('Total Review', len(last_review))
# Out:
# Total Review 3366

# %% [markdown]
# ### Cek Null Values

# %%
df_airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### Drop Columns

# %%
df_airbnb = df_airbnb.drop(['id', 'name', 'host_id', 'host_name'], axis=1)

# %%
df_airbnb.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaT                NaN
# 3     89               1                270  2019-07-05               4.64
# 4     80              10                  9  2018-11-19               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
df_airbnb.describe()
# Out:
#            latitude     longitude         price  minimum_nights  \
# count  48895.000000  48895.000000  48895.000000    48895.000000
# mean      40.728949    -73.952170    152.720687        7.029962
# min       40.499790    -74.244420      0.000000        1.000000
# 25%       40.690100    -73.983070     69.000000        1.000000
# 50%       40.723070    -73.955680    106.000000        3.000000
# 75%       40.763115    -73.936275    175.000000        5.000000
# max       40.913060    -73.712990  10000.000000     1250.000000
# std        0.054530      0.046157    240.154170       20.510550
#
#        number_of_reviews                    last_review  reviews_per_month  \
# count       48895.000000                          38843       38843.000000
# mean           23.274466  2018-10-04 01:47:23.910099456           1.373221
# min             0.000000            2011-03-28 00:00:00           0.010000
# 25%             1.000000            2018-07-08 00:00:00           0.190000
# 50%             5.000000            2019-05-19 00:00:00           0.720000
# 75%            24.000000            2019-06-23 00:00:00           2.020000
# max           629.000000            2019-07-08 00:00:00          58.500000
# std            44.550582                            NaN           1.680442
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000
# std                         32.952519        131.622289

# %% [markdown]
# ### Fill Missing Value in last_review

# %%
df_airbnb['last_review'] = df_airbnb['last_review'].fillna(df_airbnb['last_review'].mode()[0])

# %%
df_airbnb[['last_review']].isnull().sum()
# Out:
# last_review    0
# dtype: int64

# %% [markdown]
# ### Fill Missing Value in review_per_month

# %%
df_airbnb['reviews_per_month'] = df_airbnb['reviews_per_month'].fillna(df_airbnb['reviews_per_month'].mean())

# %%
df_airbnb.isnull().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ### Check Column Price

# %%
df_airbnb.sort_values(by=['price'], ascending=False)
# Out:
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 9151               Queens             Astoria  40.76810  -73.91651
# 17692            Brooklyn          Greenpoint  40.73260  -73.95739
# 29238           Manhattan     Upper West Side  40.77213  -73.98665
# 40433           Manhattan     Lower East Side  40.71980  -73.98566
# 12342           Manhattan     Lower East Side  40.71355  -73.98507
# ...                   ...                 ...       ...        ...
# 25778            Brooklyn        Williamsburg  40.70838  -73.94645
# 25796            Brooklyn  Bedford-Stuyvesant  40.68258  -73.91284
# 25433               Bronx     East Morrisania  40.83296  -73.88668
# 26841            Brooklyn            Bushwick  40.69211  -73.90670
# 25795            Brooklyn  Bedford-Stuyvesant  40.68279  -73.91170
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0  2019-06-23
# 40433  Entire home/apt   9999              30                  0  2019-06-23
# 12342     Private room   9999              99                  6  2016-01-01
# ...                ...    ...             ...                ...         ...
# 25778  Entire home/apt      0               5                  3  2018-01-02
# 25796     Private room      0               1                 95  2019-06-23
# 25433     Private room      0               2                 55  2019-06-24
# 26841      Shared room      0              30                  2  2019-06-22
# 25795     Private room      0               1                 95  2019-06-21
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 9151            0.040000                               1                 0
# 17692           0.160000                               1                 0
# 29238           1.373221                               1                83
# 40433           1.373221                               1               365
# 12342           0.140000                               1                83
# ...                  ...                             ...               ...
# 25778           0.150000                               1                73
# 25796           4.350000                               6               222
# 25433           2.560000                               4               127
# 26841           0.110000                               6               333
# 25795           4.370000                               6               232
#
# [48895 rows x 12 columns]

# %%
price = df_airbnb['price']
print(f'Minimum price is {price.min()} and maximum price is {price.max()}')
# Out:
# Minimum price is 0 and maximum price is 10000

# %%
df_airbnb.groupby('neighbourhood_group')['price'].agg(['mean', 'median', 'sum'])
# Out:
#                            mean  median      sum
# neighbourhood_group
# Bronx                 87.496792    65.0    95459
# Brooklyn             124.383207    90.0  2500600
# Manhattan            196.875814   150.0  4264527
# Queens                99.517649    75.0   563867
# Staten Island        114.812332    75.0    42825

# %% [markdown]
# ### Create Column price Category

# %%
df_airbnb['price_category'] = np.where(df_airbnb['price'] < 50, 'Cheap', np.where(df_airbnb['price'] < 100, 'Medium', 'Expensive'))

# %%
df_airbnb['price_category'].unique()
# Out:
# array(['Expensive', 'Medium', 'Cheap'], dtype=object)

# %%
df_airbnb.head()
# Out:
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19           0.210000
# 1    225               1                 45  2019-05-21           0.380000
# 2    150               3                  0  2019-06-23           1.373221
# 3     89               1                270  2019-07-05           4.640000
# 4     80              10                  9  2018-11-19           0.100000
#
#    calculated_host_listings_count  availability_365 price_category
# 0                               6               365      Expensive
# 1                               2               355      Expensive
# 2                               1               365      Expensive
# 3                               1               194         Medium
# 4                               1                 0         Medium

# %% [markdown]
# ### Visualize Everything

# %%
df_Brooklyn = df_airbnb[['neighbourhood_group', 'neighbourhood']].loc[df_airbnb['neighbourhood_group'] == 'Brooklyn']

# %%
df_Brooklyn.head()
# Out:
#    neighbourhood_group       neighbourhood
# 0             Brooklyn          Kensington
# 3             Brooklyn        Clinton Hill
# 6             Brooklyn  Bedford-Stuyvesant
# 12            Brooklyn         South Slope
# 15            Brooklyn        Williamsburg

# %%
neighbourhood = []
total = []

neighbourhood_dict_ = df_Brooklyn.value_counts().to_dict()

for key in neighbourhood_dict_:
    neighbourhood.append(key[1]), total.append(neighbourhood_dict_[key])
    
print('Total neighbourhood:', len(neighbourhood))
# Out:
# Total neighbourhood: 47

# %%
num_in_plot = 15

for i in range(1, (len(neighbourhood)//num_in_plot)+1):

    plt.figure(figsize=(18, 8))

    if i is not 30:
        plt.bar(neighbourhood[i:i+num_in_plot], total[i:i+num_in_plot], color='cyan')
    else:
        plt.bar(neighbourhood[i:], total[i:], color='red')

    plt.title(f'Total neighbourhood in Brooklyn - Plot {i}')
    plt.xlabel('Neighbourhood')
    plt.ylabel('Total')

    plt.tight_layout()
    plt.savefig(f'assets/Total_Neighbourhood_in_Brooklyn_plot_{i}.png')
    plt.show()
# Out:
# <>:7: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:7: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\Hammam\AppData\Local\Temp\ipykernel_8448\2942878439.py:7: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i is not 30:

# %%
print('Maximum review', df_airbnb['number_of_reviews'].max())

plt.scatter(df_airbnb['price'], df_airbnb['number_of_reviews'], color='hotpink')
plt.xlabel('Price')
plt.ylabel('Num of reviews')

plt.savefig(f'assets/relation_price_number_of_reviews.png')
plt.show()
# Out:
# Maximum review 629

# %%
df_airbnb['is_available'] = np.where(df_airbnb['availability_365'] == 0, 'No', 'Yes')
df_airbnb['is_available'].value_counts()
# Out:
# is_available
# Yes    31362
# No     17533
# Name: count, dtype: int64

# %%
plt.pie(df_airbnb['is_available'].value_counts().tolist(), labels=['Yes', 'No'], autopct='%1.1f%%')

plt.title('Available')
plt.tight_layout()

plt.savefig('assets/available_pie_chart.png')
plt.show()

# %%
df_airbnb['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %% [markdown]
# ### Visualize Peice

# %%
price = df_airbnb['price']
bins =[25, 50, 75, 100, 125, 150, 175, 200]

plt.hist(price, bins=bins, edgecolor='y', color='cyan')

plt.savefig('assets/price_histogram.png')
plt.show()

# %%
price_category = df_airbnb['price_category'].value_counts()
price_category = pd.DataFrame(price_category)
price_category.reset_index(inplace=True)
price_category
# Out:
#   price_category  count
# 0      Expensive  27018
# 1         Medium  16850
# 2          Cheap   5027

# %%
price_category.columns = ['category', 'total']

category = price_category['category']
total = price_category['total']

# %%
plt.bar(category, total, color=(0.2, 0.2, 0.6, 0.6))

plt.title('Price Category')
plt.xlabel('Category')
plt.ylabel('Total')

plt.tight_layout()

plt.savefig('assets/price_category_bar_chart.png')
plt.show()

# %%
plt.pie(total, labels=list(price_category['category']), explode=[0, 0, 0.1], autopct='%1.1f%%')

plt.title('Price Category')
plt.tight_layout()

plt.savefig('assets/price_category_pie_chart.png')
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.bar(category, total)

plt.title("Price Category")
plt.xlabel("Category")
plt.ylabel("Total")

plt.subplot(1, 2, 2)
plt.pie(total, labels=list(price_category['category']), explode=[0, 0, 0.1], autopct='%1.1f%%')

plt.title('Price Category')

plt.suptitle('Price Category Bar & Pie Chart')

plt.tight_layout()
plt.savefig('assets/price_category_bar_pie_chart.png')
plt.show()

# %%
neighbourhood_group = df_airbnb['neighbourhood_group']
price = df_airbnb['price']

# %%
df_ = df_airbnb.groupby('neighbourhood_group')['price'].agg(['mean', 'median', 'sum'])
df_ = df_.sort_values('sum', ascending=False)

df_
# Out:
#                            mean  median      sum
# neighbourhood_group
# Manhattan            196.875814   150.0  4264527
# Brooklyn             124.383207    90.0  2500600
# Queens                99.517649    75.0   563867
# Bronx                 87.496792    65.0    95459
# Staten Island        114.812332    75.0    42825

# %%
neighbourhood_group = df_.index.tolist()
price = df_['sum'].tolist()

# %%
plt.bar(neighbourhood_group, price)

plt.title('Room Price Comparison by Group')
plt.xlabel('neighbourhood Group')
plt.ylabel('Room Price')

plt.tight_layout()
plt.savefig('assets/room_price_comparison_by_group.png')
plt.show()

# %%
df_price_lt_ld = df_airbnb.loc[df_airbnb['price'] < 500, ['price', 'longitude', 'latitude']]
price = df_price_lt_ld['price']

x = df_price_lt_ld['longitude']
y = df_price_lt_ld['latitude']

# %%
plt.figure(figsize=(10, 8))

nyc_img = plt.imread('assets/Neighbourhoods_New_York_City_Map.png')
plt.imshow(nyc_img, extent=[-74.258, -73.7, 40.49, 40.92])

plt.scatter(x, y, c=price, label='Availability', cmap='jet', alpha=0.4)

plt.grid(False)
cbar = plt.colorbar()
cbar.set_label('Price')

plt.title('Availability of New York City Room Rates Map')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.legend()
plt.tight_layout()

plt.show()
