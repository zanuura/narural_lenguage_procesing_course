# %% [markdown]
# ## Membaca file CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('assets/data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
pd.options.display.max_rows
# Out:
# 9999

# %%
pd.options.display.max_rows = 9999

# %%
df = pd.read_csv('assets/data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_json('assets/data.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_csv('assets/data__.csv')
print(df.to_string())
# Out:
#     Duration__Pulse__Maxpulse__Calories
# 0                   60__110__130__409.1
# 1                   60__117__145__479.0
# 2                   60__103__135__340.0
# 3                   45__109__175__282.4
# 4                   45__117__148__406.0
# 5                   60__102__127__300.0
# 6                   60__110__136__374.0
# 7                   45__104__134__253.3
# 8                   30__109__133__195.1
# 9                    60__98__124__269.0
# 10                  60__103__147__329.3
# 11                  60__100__120__250.7
# 12                  60__106__128__345.3
# 13                  60__104__132__379.3
# 14                   60__98__123__275.0
# 15                   60__98__120__215.2
# 16                  60__100__120__300.0
# 17                        45__90__112__
# 18                  60__103__123__323.0
# 19                   45__97__125__243.0
# 20                  60__108__131__364.2
# 21                  45__100__119__282.0
# ...

# %% [markdown]
# ### Menggunakan parameter pada Pandas Read

# %%
df = pd.read_csv('assets/data.csv', sep=',', header=1)
df
# Out:
#       60  110  130   409.1
# 0     60  117  145   479.0
# 1     60  103  135   340.0
# 2     45  109  175   282.4
# 3     45  117  148   406.0
# 4     60  102  127   300.0
# 5     60  110  136   374.0
# 6     45  104  134   253.3
# 7     30  109  133   195.1
# 8     60   98  124   269.0
# 9     60  103  147   329.3
# 10    60  100  120   250.7
# 11    60  106  128   345.3
# 12    60  104  132   379.3
# 13    60   98  123   275.0
# 14    60   98  120   215.2
# 15    60  100  120   300.0
# 16    45   90  112     NaN
# 17    60  103  123   323.0
# 18    45   97  125   243.0
# 19    60  108  131   364.2
# 20    45  100  119   282.0
# 21    60  130  101   300.0
# 22    45  105  132   246.0
# 23    60  102  126   334.5
# 24    60  100  120   250.0
# 25    60   92  118   241.0
# 26    60  103  132     NaN
# 27    60  100  132   280.0
# 28    60  102  129   380.3
# 29    60   92  115   243.0
# 30    45   90  112   180.1
# 31    60  101  124   299.0
# 32    60   93  113   223.0
# ...

# %%
df = pd.read_csv('assets/data.csv', delimiter=',', header=1)
df
# Out:
#       60  110  130   409.1
# 0     60  117  145   479.0
# 1     60  103  135   340.0
# 2     45  109  175   282.4
# 3     45  117  148   406.0
# 4     60  102  127   300.0
# 5     60  110  136   374.0
# 6     45  104  134   253.3
# 7     30  109  133   195.1
# 8     60   98  124   269.0
# 9     60  103  147   329.3
# 10    60  100  120   250.7
# 11    60  106  128   345.3
# 12    60  104  132   379.3
# 13    60   98  123   275.0
# 14    60   98  120   215.2
# 15    60  100  120   300.0
# 16    45   90  112     NaN
# 17    60  103  123   323.0
# 18    45   97  125   243.0
# 19    60  108  131   364.2
# 20    45  100  119   282.0
# 21    60  130  101   300.0
# 22    45  105  132   246.0
# 23    60  102  126   334.5
# 24    60  100  120   250.0
# 25    60   92  118   241.0
# 26    60  103  132     NaN
# 27    60  100  132   280.0
# 28    60  102  129   380.3
# 29    60   92  115   243.0
# 30    45   90  112   180.1
# 31    60  101  124   299.0
# 32    60   93  113   223.0
# ...

# %%
df = pd.read_csv('assets/data__.csv', sep='__', header=0, engine='python')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# ## Membaca custom Data

# %%
data = {
    "Duration": {
        "0": 60,
        "1": 60,
        "2": 60,
    },
    "Pulse": {
        "0": 110,
        "1": 117,
        "2": 103,
    },
    "Maxpulse": {
        "0": 130,
        "1": 145,
        "2": 135,
    },
    "Calories": {
        "0": 409,
        "1": 479,
        "2": 340,
    },
}

# %%
data
# Out:
# {'Duration': {'0': 60, '1': 60, '2': 60},
#  'Pulse': {'0': 110, '1': 117, '2': 103},
#  'Maxpulse': {'0': 130, '1': 145, '2': 135},
#  'Calories': {'0': 409, '1': 479, '2': 340}}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340

# %% [markdown]
# ### Membuat custom data

# %%
df.to_csv('assets/custom_data.csv')
